# %% [markdown]
# Execute the Following SQL queries;

# %% [markdown]
# --Postgresql Connection Details:

# %%
import psycopg2
import streamlit as st
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

import json
import toml

import sys
import os

# Load environment
try:
    with open("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project1/Tennis_Data_SportRadar/config.json", "r") as f:
        config = json.load(f)

    env = config["environment"] # 'local' or 'cloud'
except FileNotFoundError:
    raise FileNotFoundError("⚠️ 'config.json' not found. Please check the path.")
except json.JSONDecodeError:
    raise ValueError("⚠️ 'config.json' is not a valid JSON file.")
except KeyError:
    raise KeyError("⚠️ 'environment' key not found in config.json.")

# Load secrets from your custom toml file
local_secrets = toml.load("C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project1/Tennis_Data_SportRadar/.pwd/pwd.toml")



# Append the directory where db_utils.py is located
sys.path.append(os.path.abspath('C:/Users/dhars/Downloads/Dhass/codeing/GUVI/2. MainBoot/4.Project_Code/Project1/Tennis_Data_SportRadar'))


from db_utils import connect_to_postgres, connect_to_sportradar

# Connect to default DB and create target DB if needed
my_db_connection = connect_to_postgres(env, local_secrets) #connect to existing database first

# Set autocommit so CREATE DATABASE works
my_db_connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# Create cursor and check for database existence
mycursor = my_db_connection.cursor()
mycursor.execute("SELECT * FROM pg_database WHERE datname='sportradar'")
exists = mycursor.fetchone()

if not exists:
    mycursor.execute("CREATE DATABASE sportradar")   #create target DB
    print("Database 'sportradar' created")
else:
    print("Database 'sportradar' already exists")

mycursor.close()
my_db_connection.close()




# Reconnect to the newly ensured 'sportradar' database
my_db_connection = connect_to_sportradar(env, local_secrets)

my_db_connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

#I need to connect the db and the python:
mycursor = my_db_connection.cursor()

print("Connected to 'sportradar' database.")
# Out:
# Database 'sportradar' already exists
# Connected to 'sportradar' database.

# %%
import pandas as pd

# %% [markdown]
# 1.COMPETITIONS:

# %% [markdown]
# 1) List all competitions along with their category name:

# %%
sql_query = """Select comp.competition_id, comp.competition_name,comp.competition_type,comp.competition_gender,
cat.categoryname 
from 
competition_table comp full join categories_table cat 
on cat.categoryid = comp.categoryid"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#             competition_id                                   competition_name  \
# 0       sr:competition:620                                         Hopman Cup
# 1       sr:competition:660                                     World Team Cup
# 2       sr:competition:990                         ATP Challenger Tour Finals
# 3      sr:competition:1207                  Championship International Series
# 4      sr:competition:2100                                          Davis Cup
# ...                    ...                                                ...
# 6034  sr:competition:46999                                     UTR Urbana W01
# 6035  sr:competition:47045        WTA 125K San Sebastian, Spain Women Singles
# 6036  sr:competition:47047        WTA 125K San Sebastian, Spain Women Doubles
# 6037  sr:competition:47053  WTA 125K Caldas da Rainha, Portugal Women Singles
# 6038  sr:competition:47055  WTA 125K Caldas da Rainha, Portugal Women Doubles
#
#      competition_type competition_gender categoryname
# 0               mixed              mixed   Hopman Cup
# 1               mixed                men          ATP
# 2             singles                men   Challenger
# 3             singles              women          WTA
# 4               mixed                men    Davis Cup
# ...               ...                ...          ...
# 6034          singles              women    UTR Women
# 6035          singles              women     WTA 125K
# 6036          doubles              women     WTA 125K
# 6037          singles              women     WTA 125K
# 6038          doubles              women     WTA 125K
#
# [6039 rows x 5 columns]

# %% [markdown]
# 2. Count the number of competitions in each category:

# %%
sql_query = """Select count(comp.competition_id) as no_of_competitions,
cat.categoryname as category
from 
competition_table comp full join categories_table cat 
on cat.categoryid = comp.categoryid group by cat.categoryname"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#     no_of_competitions              category
# 0                   16           Wheelchairs
# 1                    1             Davis Cup
# 2                   89               UTR Men
# 3                    1            United Cup
# 4                   78             UTR Women
# 5                   32            Exhibition
# 6                 2198               ITF Men
# 7                   11               Legends
# 8                    1  Billie Jean King Cup
# 9                 2032             ITF Women
# 10                 900            Challenger
# 11                 178              WTA 125K
# 12                  16               Juniors
# 13                 223                   ATP
# 14                   1                  IPTL
# 15                 255                   WTA
# 16                   6   Wheelchairs Juniors
# 17                   1            Hopman Cup

# %% [markdown]
# 3)	Find all competitions of type 'doubles'

# %%
sql_query = """Select * from competition_table where competition_type = 'doubles'"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('sr:competition:2557',
#   'Wimbledon Men Doubles',
#   'sr:competition:2553',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2561',
#   'Wimbledon Women Doubles',
#   'sr:competition:2553',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2569',
#   'Australian Open Men Doubles',
#   'sr:competition:2565',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2573',
#   'Australian Open Women Doubles',
#   'sr:competition:2565',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2581',
#   'French Open Men Doubles',
#   'sr:competition:2577',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2585',
#   'French Open Women Doubles',
#   'sr:competition:2577',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2593',
#   'US Open Men Doubles',
#   'sr:competition:2589',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2597',
#   'US Open Women Doubles',
#   'sr:competition:2589',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2605',
#   'ATP Doha, Qatar Men Doubles',
#   'sr:competition:2601',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2615',
#   'ATP Basel, Switzerland Men Doubles',
#   'sr:competition:2611',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2621',
#   'ATP Brisbane, Australia Men Doubles',
#   'sr:competition:2617',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2627',
#   'ATP Chennai, India Men Doubles',
#   'sr:competition:2623',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2633',
#   'ATP Auckland, New Zealand Men Doubles',
#   'sr:competition:2629',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2639',
#   'ATP Sydney, Australia Men Doubles',
#   'sr:competition:2635',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2651',
#   'ATP Zagreb, Croatia Men Double',
#   'sr:competition:2647',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2663',
#   'ATP Paris, France Men Doubles',
#   'sr:competition:2659',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2669',
#   'ATP Dubai, UAE Men Doubles',
#   'sr:competition:2665',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2675',
#   'WTA Pattaya City, Thailand Women Doubles',
#   'sr:competition:2671',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2681',
#   'ATP Rotterdam, Netherlands Men Doubles',
#   'sr:competition:2677',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2699',
#   'ATP Memphis, USA Men Doubles',
#   'sr:competition:2695',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2705',
#   'WTA Bogota, Colombia Women Doubles',
#   'sr:competition:2701',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2711',
#   'ATP Acapulco, Mexico Men Doubles',
#   'sr:competition:2707',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2717',
#   'WTA Monterrey, Mexico Women Doubles',
#   'sr:competition:2713',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2723',
#   'ATP Marseille, France Men Doubles',
#   'sr:competition:2719',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2729',
#   'ATP Buenos Aires, Argentina Men Doubles',
#   'sr:competition:2725',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2735',
#   'ATP Delray Beach, USA Men Doubles',
#   'sr:competition:2731',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2741',
#   'ATP Indian Wells, USA Men Doubles',
#   'sr:competition:2737',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2747',
#   'ATP Miami, USA Men Doubles',
#   'sr:competition:2743',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2753',
#   'ATP Houston, USA Men Doubles',
#   'sr:competition:2749',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2759',
#   'ATP Casablanca, Morocco Men Doubles',
#   'sr:competition:2755',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2765',
#   'WTA Charleston, USA Women Doubles',
#   'sr:competition:2761',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2771',
#   'ATP Barcelona, Spain Men Doubles',
#   'sr:competition:2767',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2777',
#   'ATP Stuttgart, Germany Men Doubles',
#   'sr:competition:2773',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2783',
#   'ATP Rome, Italy Men Doubles',
#   'sr:competition:2779',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2789',
#   'ATP Madrid, Spain Men Doubles',
#   'sr:competition:2785',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2795',
#   'Berlin, Germany Women Doubles',
#   'sr:competition:2791',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2807',
#   'WTA Hobart, Australia Women Doubles',
#   'sr:competition:2803',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2819',
#   'WTA Marrakech, Morocco Women Doubles',
#   'sr:competition:2815',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2825',
#   'WTA Strasbourg, France Women Doubles',
#   'sr:competition:2821',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2831',
#   'ATP Challenger Amersfoort, Netherlands Men Doubles',
#   'sr:competition:2827',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:2837',
#   'ATP Munich, Germany Men Doubles',
#   'sr:competition:2833',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2855',
#   'WTA Birmingham, Great Britain Women Doubles',
#   'sr:competition:2851',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2861',
#   'ATP Halle, Germany Men Doubles',
#   'sr:competition:2857',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2867',
#   'ATP London, Great Britain Men Doubles',
#   'sr:competition:2863',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2873',
#   'ATP S-Hertogenbosch, Netherlands Men Doubles',
#   'sr:competition:2869',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2879',
#   'WTA Eastbourne, Great Britain Women Doubles',
#   'sr:competition:7629',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2885',
#   'ATP Newport, USA Men Doubles',
#   'sr:competition:2881',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2891',
#   'ATP Bastad, Sweden Men Doubles',
#   'sr:competition:2887',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2897',
#   'WTA Budapest, Hungary Women Doubles',
#   'sr:competition:2893',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2903',
#   'WTA Palermo, Italy Women Doubles',
#   'sr:competition:2899',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2909',
#   'WTA Prague, Czech Republic Women Doubles',
#   'sr:competition:2905',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2915',
#   'Portoroz, Slovenia Women Doubles',
#   'sr:competition:2911',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2937',
#   'ATP Hamburg, Germany Men Doubles',
#   'sr:competition:2933',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2943',
#   'WTA San Jose, USA Women Doubles',
#   'sr:competition:2689',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2949',
#   'WTA Istanbul, Turkey Women Doubles',
#   'sr:competition:2945',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2961',
#   'ATP Gstaad, Switzerland Men Doubles',
#   'sr:competition:2957',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2967',
#   'ATP Umag, Croatia Men Doubles',
#   'sr:competition:2963',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2973',
#   'ATP Washington, USA Men Doubles',
#   'sr:competition:2969',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2979',
#   'WTA Montreal, Canada Women Doubles',
#   'sr:competition:2975',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2985',
#   'ATP Cincinnati, USA Men Doubles',
#   'sr:competition:2981',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:2991',
#   'WTA New Haven, USA Women Doubles',
#   'sr:competition:2987',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:2997',
#   'ATP Toronto, Canada Men Doubles',
#   'sr:competition:2993',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3003',
#   'ATP Metz, France Men Doubles',
#   'sr:competition:2999',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3009',
#   'ATP Bucharest, Romania Men Doubles',
#   'sr:competition:3005',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3015',
#   'WTA Guangzhou, China Women Doubles',
#   'sr:competition:3011',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:3027',
#   'ATP Beijing, China Men Doubles',
#   'sr:competition:3023',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3033',
#   'ATP Tokyo, Japan Men Doubles',
#   'sr:competition:3029',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3039',
#   'WTA Quebec City, Canada Women Doubles',
#   'sr:competition:3035',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:3045',
#   'WTA Seoul, Korea Republic Women Doubles',
#   'sr:competition:3041',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:3051',
#   'WTA Tashkent, Uzbekistan Women Doubles',
#   'sr:competition:3047',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:3057',
#   'WTA Linz, Austria Women Doubles',
#   'sr:competition:3053',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:3063',
#   'WTA Osaka, Japan Women Doubles',
#   'sr:competition:3059',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:3069',
#   'ATP Moscow, Russia Men Doubles',
#   'sr:competition:3065',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3075',
#   'WTA Luxembourg, Luxembourg Women Doubles',
#   'sr:competition:3071',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:3087',
#   'ATP Shanghai, China Men Doubles',
#   'sr:competition:3083',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3093',
#   'ATP Stockholm, Sweden Men Doubles',
#   'sr:competition:3089',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3099',
#   'ATP Lyon, France Men Doubles',
#   'sr:competition:3095',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3105',
#   'ATP Vienna, Austria Men Doubles',
#   'sr:competition:3101',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3111',
#   'ATP St. Petersburg, Russia Men Doubles',
#   'sr:competition:3107',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3123',
#   'ATP Monte Carlo, Monaco Men Doubles',
#   'sr:competition:3119',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3147',
#   'WTA Antwerp, Belgium Women Doubles',
#   'sr:competition:3143',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:3153',
#   'ATP Kitzbuhel, Austria Men Doubles',
#   'sr:competition:3149',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3165',
#   'San Diego, USA Women Doubles',
#   'sr:competition:3161',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:3183',
#   'ATP Nottingham, Great Britain Men Doubles',
#   'sr:competition:3179',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3215',
#   'ATP Challenger Charlottesville, USA Men Doubles',
#   'sr:competition:3213',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3223',
#   'ATP Challenger Noumea, New Caledonia Men Doubles',
#   'sr:competition:3219',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3229',
#   'ATP Challenger Sao Paulo, Brazil Men Doubles',
#   'sr:competition:3225',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3235',
#   'ATP Challenger Salinas, Ecuador Men Doubles',
#   'sr:competition:3231',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3241',
#   'ATP Santiago, Chile Men Doubles',
#   'sr:competition:3237',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3247',
#   'ATP Atlanta, USA Men Doubles',
#   'sr:competition:3243',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3253',
#   'ATP Belgrade, Serbia Men Doubles',
#   'sr:competition:3249',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3259',
#   'ATP Kuala Lumpur, Malaysia Men Doubles',
#   'sr:competition:3255',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3265',
#   'ATP Nice, France Men Doubles',
#   'sr:competition:3261',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:3283',
#   'ATP Challenger Barletta, Italy Men Doubles',
#   'sr:competition:3279',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3289',
#   'ATP Challenger Bergamo, Italy Men Doubles',
#   'sr:competition:3285',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3295',
#   'ATP Challenger Floridablanca-Bucaramanga, Colombia Men Doubles',
#   'sr:competition:3291',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3301',
#   'ATP Challenger Heilbronn, Germany Men Doubles',
#   'sr:competition:3297',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3313',
#   'ATP Challenger Burnie, Australia Men Doubles',
#   'sr:competition:3309',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3323',
#   'ATP Challenger Caltanissetta, Italy Men Doubles',
#   'sr:competition:3319',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3329',
#   'ATP Challenger Cherbourg, France Men Doubles',
#   'sr:competition:3325',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3345',
#   'ATP Challenger Kazan, Russia Men Doubles',
#   'sr:competition:3341',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3351',
#   'ATP Challenger Kyoto, Japan Men Doubles',
#   'sr:competition:3347',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3369',
#   'ATP Challenger Meknes, Morocco Men Doubles',
#   'sr:competition:3365',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3381',
#   'ATP Challenger San Luis Potosi, Mexico Men Doubles',
#   'sr:competition:3377',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3393',
#   'ATP Challenger St. Brieuc, France Men Doubles',
#   'sr:competition:3389',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3427',
#   'ATP Challenger Biella, Italy Men Doubles',
#   'sr:competition:3423',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3433',
#   'ATP Challenger Blumenau, Brazil Men Doubles',
#   'sr:competition:3429',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3439',
#   'ATP Challenger Bordeaux, France Men Doubles',
#   'sr:competition:3435',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3449',
#   'ATP Challenger Busan, Korea Republic Men Doubles',
#   'sr:competition:3445',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3455',
#   'ATP Challenger Cairo, Egypt Men Doubles',
#   'sr:competition:3451',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3471',
#   'ATP Challenger Fergana, Uzbekistan Men Doubles',
#   'sr:competition:3467',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3477',
#   'ATP Challenger Furth, Germany Men Doubles',
#   'sr:competition:3473',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3483',
#   'ATP Challenger Leon, Mexico Men Doubles',
#   'sr:competition:3479',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3495',
#   'ATP Challenger Monza, Italy Men Doubles',
#   'sr:competition:3491',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3501',
#   'ATP Challenger Ostrava, Czech Republic Men Doubles',
#   'sr:competition:3497',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3507',
#   'ATP Challenger Pereira, Colombia Men Doubles',
#   'sr:competition:3503',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3513',
#   'ATP Challenger Prostejov, Czech Republic Men Doubles',
#   'sr:competition:3509',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3531',
#   'ATP Challenger Sarasota, USA Men Doubles',
#   'sr:competition:3527',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3537',
#   'ATP Challenger Savannah, USA Men Doubles',
#   'sr:competition:3533',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3543',
#   'ATP Challenger Tallahassee, USA Men Doubles',
#   'sr:competition:3539',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3549',
#   'ATP Challenger Tunis, Tunisia Men Doubles',
#   'sr:competition:3545',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3555',
#   'ATP Challenger Aptos, USA Men Doubles',
#   'sr:competition:3551',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3573',
#   'ATP Challenger Braunschweig, Germany Men Doubles',
#   'sr:competition:3569',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3583',
#   'ATP Challenger Cordenons, Italy Men Doubles',
#   'sr:competition:3579',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3589',
#   'ATP Challenger Granby, Canada Men Doubles',
#   'sr:competition:3585',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3601',
#   'ATP Challenger Lexington, USA Men Doubles',
#   'sr:competition:3597',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3611',
#   'ATP Challenger Marburg, Germany Men Doubles',
#   'sr:competition:3607',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3617',
#   'ATP Challenger Milan, Italy Men Doubles',
#   'sr:competition:3613',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3645',
#   'ATP Challenger Poznan, Poland Men Doubles',
#   'sr:competition:3641',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3651',
#   'ATP Challenger Pozoblanco, Spain Men Doubles',
#   'sr:competition:3647',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3657',
#   'ATP Challenger Recanati, Italy Men Doubles',
#   'sr:competition:3653',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3671',
#   'ATP Challenger San Benedetto, Italy Men Doubles',
#   'sr:competition:3667',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3677',
#   'ATP Challenger Scheveningen, Netherlands Men Doubles',
#   'sr:competition:3673',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3683',
#   'ATP Challenger Tampere, Finland Men Doubles',
#   'sr:competition:3679',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3689',
#   'ATP Challenger Turin, Italy Men Doubles',
#   'sr:competition:3685',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3695',
#   'ATP Challenger Winnetka, USA Men Doubles',
#   'sr:competition:3691',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3711',
#   'ATP Challenger San Marino, San Marino Men Doubles',
#   'sr:competition:3707',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3717',
#   'ATP Challenger Segovia, Spain Men Doubles',
#   'sr:competition:3713',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3723',
#   'ATP Challenger Vancouver, Canada Men Doubles',
#   'sr:competition:3719',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3729',
#   'ATP Challenger Binghamton, USA Men Doubles',
#   'sr:competition:3725',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3735',
#   'ATP Challenger Samarkand, Uzbekistan Men Doubles',
#   'sr:competition:3731',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3747',
#   'ATP Challenger Karshi, Uzbekistan Men Doubles',
#   'sr:competition:3743',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3779',
#   'ATP Challenger Como, Italy Men Doubles',
#   'sr:competition:3775',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3791',
#   'ATP Challenger Alphen aan den Rijn, Netherlands Men Doubles',
#   'sr:competition:3787',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3797',
#   'ATP Challenger Brasov, Romania Men Doubles',
#   'sr:competition:3793',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3803',
#   'ATP Challenger Genoa, Italy Men Doubles',
#   'sr:competition:3799',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3815',
#   'ATP Challenger Seville, Spain Men Doubles',
#   'sr:competition:3811',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3821',
#   'ATP Challenger St. Remy, France Men Doubles',
#   'sr:competition:3817',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3827',
#   'ATP Challenger Banja Luka, Bosnia & Herzegovina Men Doubles',
#   'sr:competition:3823',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3833',
#   'ATP Challenger Szczecin, Poland Men Doubles',
#   'sr:competition:32985',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3839',
#   'ATP Challenger Todi, Italy Men Doubles',
#   'sr:competition:3835',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3857',
#   'ATP Challenger Trnava, Slovakia Men Doubles',
#   'sr:competition:3853',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3863',
#   'ATP Challenger Cali, Colombia Men Doubles',
#   'sr:competition:3859',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3869',
#   'ATP Challenger Montevideo, Uruguay Men Doubles',
#   'sr:competition:3865',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3875',
#   'ATP Challenger Mons, Belgium Men Doubles',
#   'sr:competition:3871',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3881',
#   'ATP Challenger Quito, Ecuador Men Doubles',
#   'sr:competition:3877',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3901',
#   'ATP Challenger Rennes, France Men Doubles',
#   'sr:competition:3897',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3907',
#   'ATP Challenger Tiburon, USA Men Doubles',
#   'sr:competition:3903',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3917',
#   'ATP Challenger Orleans, France Men Doubles',
#   'sr:competition:3913',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3923',
#   'ATP Challenger Astana, Kazakhstan Men Doubles',
#   'sr:competition:3919',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3929',
#   'ATP Challenger Eckental, Germany Men Doubles',
#   'sr:competition:3925',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3935',
#   'ATP Challenger Medellin, Colombia Men Doubles',
#   'sr:competition:3931',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3947',
#   'ATP Challenger Guayaquil, Ecuador Men Doubles',
#   'sr:competition:3943',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3953',
#   'ATP Challenger Knoxville, USA Men Doubles',
#   'sr:competition:3949',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3959',
#   'ATP Challenger Ortisei, Italy Men Doubles',
#   'sr:competition:3955',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3965',
#   'ATP Challenger Bratislava, Slovakia Men Doubles',
#   'sr:competition:3961',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3977',
#   'ATP Challenger Champaign, USA Men Doubles',
#   'sr:competition:3973',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3989',
#   'ATP Challenger Helsinki, Finland Men Doubles',
#   'sr:competition:3985',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:3995',
#   'ATP Challenger Toyota, Japan Men Doubles',
#   'sr:competition:3991',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4001',
#   'ATP Montpellier, France Men Doubles',
#   'sr:competition:3997',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:4013',
#   'ATP Challenger Loughborough, Great Britain Men Doubles',
#   'sr:competition:4009',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4085',
#   'ATP Challenger Buenos Aires, Argentina Men Doubles',
#   'sr:competition:4081',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4145',
#   'Dominican Republic F2 Men Doubles',
#   'sr:competition:4141',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:4151',
#   'ATP Challenger Santiago, Chile Men Doubles',
#   'sr:competition:4147',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4187',
#   'WTA Baku, Azerbaijan Women Doubles',
#   'sr:competition:4183',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:4211',
#   'ATP Challenger Quimper, France Men Doubles',
#   'sr:competition:4207',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4223',
#   'WTA Doha, Qatar Women Doubles',
#   'sr:competition:4219',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:4301',
#   'ATP Challenger Le Gosier, Guadeloupe Men Doubles',
#   'sr:competition:4297',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4313',
#   'ATP Challenger Barranquilla, Colombia Men Doubles',
#   'sr:competition:4309',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4331',
#   'ATP Winston Salem, USA Men Doubles',
#   'sr:competition:4327',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:4395',
#   'ITF Men Stuttgart-Stammheim, Germany Men Doubles',
#   'sr:competition:4391',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:4417',
#   'ITF Women Kaarst, Germany Women Doubles',
#   'sr:competition:4413',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:4491',
#   'WTA Dubai, UAE Women Doubles',
#   'sr:competition:4487',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:4509',
#   'ATP Challenger Bogota, Colombia Men Doubles',
#   'sr:competition:4505',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4533',
#   'WTA Acapulco, Mexico Women Doubles',
#   'sr:competition:2707',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:4539',
#   'ATP Challenger Casablanca, Morocco Men Doubles',
#   'sr:competition:4535',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4561',
#   'WTA Kuala Lumpur, Malaysia Women Doubles',
#   'sr:competition:4557',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:4579',
#   'ITF Men Cherkassy, Ukraine Men Doubles',
#   'sr:competition:4575',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:4591',
#   'WTA Indian Wells, USA Women Doubles',
#   'sr:competition:2737',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:4633',
#   'ATP Challenger Guangzhou, China Men Doubles',
#   'sr:competition:4629',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4639',
#   'ITF Women Rabat, Morocco Women Doubles',
#   'sr:competition:4635',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:4663',
#   'Great Britain F4 Men Doubles',
#   'sr:competition:4659',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:4669',
#   'ITF Women Bath, Great Britain Women Doubles',
#   'sr:competition:4665',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:4687',
#   'ATP Challenger Santos, Brazil Men Doubles',
#   'sr:competition:4683',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4693',
#   'WTA Miami, USA Women Doubles',
#   'sr:competition:2743',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:4771',
#   'ATP Challenger Rome, Italy Men Doubles',
#   'sr:competition:4767',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4777',
#   'WTA Rome, Italy Women Doubles',
#   'sr:competition:4773',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:4795',
#   'ITF Men Vrsar, Croatia Men Doubles',
#   'sr:competition:4791',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:4813',
#   'ITF Women Caracas, Venezuela Women Doubles',
#   'sr:competition:4809',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:4837',
#   'ITF Women Bol, Croatia Women Doubles',
#   'sr:competition:4833',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:4849',
#   'WTA Stuttgart, Germany Women Doubles',
#   'sr:competition:4845',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:4879',
#   'Challenge Belgrade Men Doubles',
#   'sr:competition:4875',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4909',
#   'ATP Challenger Bangkok, Thailand Men Doubles',
#   'sr:competition:4905',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4927',
#   'WTA Madrid, Spain Women Doubles',
#   'sr:competition:2785',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:4933',
#   'ATP Challenger Prague, Czech Republic Men Doubles',
#   'sr:competition:4929',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:4975',
#   'ATP Challenger Zagreb, Croatia Men Doubles',
#   'sr:competition:4971',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:5169',
#   'ATP Challenger Nottingham, Great Britain Men Doubles',
#   'sr:competition:5165',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:5199',
#   'ITF Women Bangkok, Thailand Women Doubles',
#   'sr:competition:5195',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:5241',
#   'ITF Men Bytom, Poland Men Doubles',
#   'sr:competition:5237',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:5307',
#   'ATP Challenger Guadalajara, Mexico Men Doubles',
#   'sr:competition:5303',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:5409',
#   'ITF Men Frinton, Great Britain Men Doubles',
#   'sr:competition:5405',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:5525',
#   'ITF Men Izmir, Turkey Men Doubles',
#   'sr:competition:5521',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:5561',
#   'ITF Men Vierumaki, Finland Men Doubles',
#   'sr:competition:5557',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:5645',
#   'ITF Women St. Petersburg, Russia Women Doubles',
#   'sr:competition:5641',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:5695',
#   'ITF Women Vinkovci, Croatia Women Doubles',
#   'sr:competition:5691',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:5701',
#   'ITF Women Mamaia, Romania Women Doubles',
#   'sr:competition:5697',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:5757',
#   'ITF Women Alphen aan den Rijn, Netherlands Women Doubles',
#   'sr:competition:5753',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:5775',
#   'ATP Challenger Madrid, Spain Men Doubles',
#   'sr:competition:5771',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:5781',
#   'ATP Challenger Aguascalientes, Mexico Men Doubles',
#   'sr:competition:5777',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:5787',
#   'ATP Challenger Campinas, Brazil Men Doubles',
#   'sr:competition:5783',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:5793',
#   'ATP Challenger Izmir, Turkey Men Doubles',
#   'sr:competition:5789',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:5799',
#   'ATP Challenger Ningbo, China Men Doubles',
#   'sr:competition:5795',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:5805',
#   'ATP Challenger Istanbul, Turkey Men Doubles',
#   'sr:competition:5801',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:5839',
#   'ITF Women Redding, USA Women Doubles',
#   'sr:competition:5835',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:5885',
#   'USA F24 Men Doubles',
#   'sr:competition:5881',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:5901',
#   'ATP Challenger Napoli, Italy Men Doubles',
#   'sr:competition:5899',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:5945',
#   'WTA Tokyo, Japan Women Doubles',
#   'sr:competition:5941',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:5957',
#   'ITF Men Leimen, Germany Men Doubles',
#   'sr:competition:5953',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:5975',
#   'ITF Women Dobrich, Bulgaria Women Doubles',
#   'sr:competition:5971',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:5999',
#   'Turkiye F26 Men Doubles',
#   'sr:competition:5995',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6033',
#   'ITF Men Solin, Croatia Men Doubles',
#   'sr:competition:6029',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6069',
#   'ATP Challenger Shanghai, China Men Doubles',
#   'sr:competition:6065',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:6099',
#   'ITF Women Rock Hill, USA Women Doubles',
#   'sr:competition:6095',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:6105',
#   'ITF Men Mansfield, USA Men Doubles',
#   'sr:competition:6101',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6109',
#   'ATP Challenger Seoul, Korea Republic Men Doubles',
#   'sr:competition:6107',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:6129',
#   'ITF Spain F39 Men Doubles',
#   'sr:competition:6125',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6153',
#   'ATP Challenger Sao Leopoldo, Brazil Men Doubles',
#   'sr:competition:6149',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:6219',
#   'ITF Men Temuco, Chile Men Doubles',
#   'sr:competition:6215',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6253',
#   'ITF Men Osorno, Chile Men Doubles',
#   'sr:competition:6249',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6307',
#   'ITF Women Vallduxo, Spain Women Doubles',
#   'sr:competition:6303',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:6319',
#   'ITF Women Toyota, Japan Women Doubles',
#   'sr:competition:6315',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:6331',
#   'ITF Men Astana, Kazakhstan Men Doubles',
#   'sr:competition:6327',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6397',
#   'ITF Women Djibouti, Djibouti Women Doubles',
#   'sr:competition:6393',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:6451',
#   'ATP Sao Paulo, Brazil Men Doubles',
#   'sr:competition:6447',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:6457',
#   'ATP Challenger Dallas, USA Men Doubles',
#   'sr:competition:6453',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:6493',
#   'WTA Brisbane, Australia Women Doubles',
#   'sr:competition:43123',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:6499',
#   'WTA Auckland, New Zealand Women Doubles',
#   'sr:competition:6495',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:6505',
#   'WTA Sydney, Australia Women Doubles',
#   'sr:competition:43121',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:6523',
#   'ITF Men Wirral, Great Britain Men Doubles',
#   'sr:competition:6519',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6577',
#   'ITF Men Feucherolles, France Men Doubles',
#   'sr:competition:6573',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6583',
#   'ITF Men Guatemala City, Guatemala Men Doubles',
#   'sr:competition:6579',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6631',
#   'ITF Men Yuxi, China Men Doubles',
#   'sr:competition:6627',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6703',
#   'ITF Men Itajai, Brazil Men Doubles',
#   'sr:competition:6699',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6709',
#   'ATP Challenger Florianopolis, Brazil Men Doubles',
#   'sr:competition:6705',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:6811',
#   'ITF Men Bath, Great Britain Men Doubles',
#   'sr:competition:6807',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6847',
#   'ITF Men Saint-Raphael, France Men Doubles',
#   'sr:competition:6843',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6919',
#   'ITF Women Ribeirao Preto, Brazil Women Doubles',
#   'sr:competition:6915',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:6931',
#   'ITF Women Osprey, USA Women Doubles',
#   'sr:competition:6927',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:6943',
#   'ITF Men Heraklion, Greece Men Doubles',
#   'sr:competition:6939',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:6985',
#   'ITF Women Algiers, Algeria Women Doubles',
#   'sr:competition:6981',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:6997',
#   'ATP Challenger Mersin, Turkey Men Doubles',
#   'sr:competition:6993',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:7003',
#   'ITF Women Antalya-Belconti, Turkey Women Doubles',
#   'sr:competition:6999',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:7009',
#   'ITF Men Kaohsiung, Chinese Taipei Men Doubles',
#   'sr:competition:7005',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:7045',
#   'ITF Women Tlemcen, Algeria Women Doubles',
#   'sr:competition:7041',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:7057',
#   'ATP Challenger Kaohsiung, Chinese Taipei Men Doubles',
#   'sr:competition:7053',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:7087',
#   'ITF Men Cordoba, Mexico Men Doubles',
#   'sr:competition:7083',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:7117',
#   'ITF Men Madurai, India Men Doubles',
#   'sr:competition:7113',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:7183',
#   'ITF Men Chennai, India Men Doubles',
#   'sr:competition:7179',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:7201',
#   'ITF Men Villa Allende, Argentina Men Doubles',
#   'sr:competition:7197',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:7267',
#   'ITF Men Bangkok, Thailand Men Doubles',
#   'sr:competition:7263',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:7333',
#   'ITF Women Raleigh, USA Women Doubles',
#   'sr:competition:7329',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:7357',
#   'ITF Men Mersin, Turkey Men Doubles',
#   'sr:competition:7353',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:7393',
#   'ITF Women Casablanca, Morocco Women Doubles',
#   'sr:competition:7389',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:7459',
#   'ITF Women Maribor, Slovenia Women Doubles',
#   'sr:competition:7455',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:7483',
#   'ITF Men Mandya, India Men Doubles',
#   'sr:competition:7479',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:7501',
#   'ITF Men Rabat, Morocco Men Doubles',
#   'sr:competition:7497',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:7507',
#   'ITF Men Mysore, India Men Doubles',
#   'sr:competition:7503',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:7513',
#   'ITF Men Maribor, Slovenia Men Doubles',
#   'sr:competition:7509',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:7627',
#   'WTA S-Hertogenbosch, Netherlands Women Doubles',
#   'sr:competition:2869',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:7633',
#   'ATP Eastbourne, Great Britain Men Doubles',
#   'sr:competition:7629',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:7723',
#   'ITF Men Sapporo, Japan Men Doubles',
#   'sr:competition:7719',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:7795',
#   'ATP Challenger Lima, Peru Men Doubles',
#   'sr:competition:7791',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:7801',
#   'ATP Challenger Panama City, Panama Men Doubles',
#   'sr:competition:7797',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:7873',
#   'WTA Bastad, Sweden Women Doubles',
#   'sr:competition:7869',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:7951',
#   'ATP Challenger Anning, China Men Doubles',
#   'sr:competition:7947',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:7993',
#   'ITF Men Coimbatore, India Men Doubles',
#   'sr:competition:7989',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8011',
#   'ITF Men Modena, Italy Men Doubles',
#   'sr:competition:8007',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8053',
#   'ITF Men Felixstowe, Great Britain Men Doubles',
#   'sr:competition:8049',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8083',
#   'ITF Women Sao Jose do Rio Preto, Brazil Women Doubles',
#   'sr:competition:8079',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:8113',
#   'ITF Women Viserba, Italy Women Doubles',
#   'sr:competition:8109',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:8179',
#   'WTA Washington, USA Women Doubles',
#   'sr:competition:2969',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:8185',
#   'Olympic Tournament Men Doubles',
#   'sr:competition:8181',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:8189',
#   'Olympic Tournament Women Doubles',
#   'sr:competition:8181',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:8215',
#   'ITF Men Ostend, Belgium Men Doubles',
#   'sr:competition:8211',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8281',
#   'WTA Toronto, Canada Women Doubles',
#   'sr:competition:8277',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:8287',
#   'ATP Montreal, Canada Men Doubles',
#   'sr:competition:8283',
#   'doubles',
#   'men',
#   'sr:category:3'),
#  ('sr:competition:8293',
#   'ATP Challenger Sibiu, Romania Men Doubles',
#   'sr:competition:8289',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:8299',
#   'ITF Men Friedberg, Germany Men Doubles',
#   'sr:competition:8295',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8347',
#   'ITF Women Hechingen, Germany Women Doubles',
#   'sr:competition:8343',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:8365',
#   'WTA Cincinnati, USA Women Doubles',
#   'sr:competition:2981',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:8371',
#   'ITF Women Innsbruck, Austria Women Doubles',
#   'sr:competition:8367',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:8383',
#   'ITF Women Westende, Belgium Women Doubles',
#   'sr:competition:8379',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:8425',
#   'ITF Men Poertschach, Austria Men Doubles',
#   'sr:competition:8421',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8449',
#   'ITF Men Winnipeg, Canada Men Doubles',
#   'sr:competition:8445',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8455',
#   'ITF Men Medellin, Colombia Men Doubles',
#   'sr:competition:8451',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8461',
#   'ITF Women Poertschach, Austria Women Doubles',
#   'sr:competition:8457',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:8473',
#   'ITF Women San Luis Potosi, Mexico Women Doubles',
#   'sr:competition:8469',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:8497',
#   'ITF Men Kenn, Germany Men Doubles',
#   'sr:competition:8493',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8503',
#   'ITF Men St. Poelten, Austria Men Doubles',
#   'sr:competition:8499',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8587',
#   'ITF Men Alice Springs, Australia Men Doubles',
#   'sr:competition:8583',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8599',
#   'ITF Men La Rioja, Argentina Men Doubles',
#   'sr:competition:8595',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8605',
#   'ITF Men Manzanillo, Mexico Men Doubles',
#   'sr:competition:8601',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8641',
#   'ITF Women Engis, Belgium Women Doubles',
#   'sr:competition:8637',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:8647',
#   'ATP Challenger Tashkent, Uzbekistan Men Doubles',
#   'sr:competition:8643',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:8713',
#   'ITF Women Pereira, Colombia Women Doubles',
#   'sr:competition:8709',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:8737',
#   'ITF Men Danderyd-Stockholm, Sweden Men Doubles',
#   'sr:competition:8733',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8749',
#   'ITF Men Costa Mesa, USA Men Doubles',
#   'sr:competition:8745',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8779',
#   'ITF Men Markham, Canada Men Doubles',
#   'sr:competition:8775',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8797',
#   'ITF Men Hambach, Germany Men Doubles',
#   'sr:competition:8793',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8815',
#   'ITF Men Belem, Brazil Men Doubles',
#   'sr:competition:8811',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8821',
#   'ITF Men Irvine, USA Men Doubles',
#   'sr:competition:8817',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8845',
#   'WTA Beijing, China Women Doubles',
#   'sr:competition:3023',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:8869',
#   'ITF Men Villavicencio, Colombia Men Doubles',
#   'sr:competition:8865',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8887',
#   'ITF Women Gainesville, USA Women Doubles',
#   'sr:competition:8883',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:8923',
#   'ITF Men Annaba, Algeria Men Doubles',
#   'sr:competition:8919',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:8941',
#   'ITF Women Mytilini, Greece Women Doubles',
#   'sr:competition:8937',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:8965',
#   'WTA Moscow, Russia Women Doubles',
#   'sr:competition:3065',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:8977',
#   'ATP Challenger Rio de Janeiro, Brazil Men Doubles',
#   'sr:competition:8973',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:9013',
#   'ATP Challenger Porto Alegre, Brazil Men Doubles',
#   'sr:competition:9009',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:9031',
#   'ITF Men Mumbai, India Men Doubles',
#   'sr:competition:9027',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:9043',
#   'ITF Men Santa Maria, Brazil Men Doubles',
#   'sr:competition:9039',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:9079',
#   'ITF Women Victoria, Mexico Women Doubles',
#   'sr:competition:9075',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:9121',
#   'ITF Women Barnstaple, Great Britain Women Doubles',
#   'sr:competition:9117',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:9139',
#   'WTA 125K Taipei, Chinese Taipei Women Doubles',
#   'sr:competition:9135',
#   'doubles',
#   'women',
#   'sr:category:871'),
#  ('sr:competition:9175',
#   'ATP Challenger Marbella, Spain Men Doubles',
#   'sr:competition:9171',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:9181',
#   'ATP Challenger Yokohama, Japan Men Doubles',
#   'sr:competition:9177',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:9247',
#   'ITF Men Phnom Penh, Cambodia Men Doubles',
#   'sr:competition:9243',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:9301',
#   'ITF Men Porto Alegre, Brazil Men Doubles',
#   'sr:competition:9297',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:9331',
#   'WTA Shenzhen, China Women Doubles',
#   'sr:competition:9327',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:9355',
#   'ATP Challenger Maui, USA Men Doubles',
#   'sr:competition:9351',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:9421',
#   'WTA 125K Cali, Colombia Women Doubles',
#   'sr:competition:9417',
#   'doubles',
#   'women',
#   'sr:category:871'),
#  ('sr:competition:9457',
#   'WTA Florianopolis, Brazil Women Doubles',
#   'sr:competition:9453',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:9463',
#   'ATP Challenger Sydney, Australia Men Doubles',
#   'sr:competition:9459',
#   'doubles',
#   'men',
#   'sr:category:72'),
#  ('sr:competition:9469',
#   'ITF Men Pereira, Colombia Men Doubles',
#   'sr:competition:9465',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:9499',
#   'ITF Men Bogota, Colombia Men Doubles',
#   'sr:competition:9495',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:9541',
#   'ITF Women Hyderabad, India Women Doubles',
#   'sr:competition:9537',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:9565',
#   'ITF Men Taverne, Switzerland Men Doubles',
#   'sr:competition:9561',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:9631',
#   'WTA Katowice, Poland Women Doubles',
#   'sr:competition:9627',
#   'doubles',
#   'women',
#   'sr:category:6'),
#  ('sr:competition:9643',
# ...
#  ('sr:competition:16966',
#   'ITF Germany F10, Men Doubles',
#   'sr:competition:16962',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:16972',
#   'ITF Portugal F15, Men Doubles',
#   'sr:competition:16968',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:16978',
#   'ITF Romania F9, Men Doubles',
#   'sr:competition:16976',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:16984',
#   'ITF Russia F6, Men Doubles',
#   'sr:competition:16980',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:16990',
#   'ITF Serbia F1, Men Doubles',
#   'sr:competition:16986',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:16996',
#   'ITF Slovakia F3, Men Doubles',
#   'sr:competition:16992',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17002',
#   'ITF Thailand F5, Men Doubles',
#   'sr:competition:16998',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17008',
#   'ITF Turkiye F29, Men Doubles',
#   'sr:competition:17004',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17014',
#   'ITF Belgium 04A, Women Doubles',
#   'sr:competition:17010',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17020',
#   'ITF Great Britain 13A, Women Doubles',
#   'sr:competition:17016',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17026',
#   'ITF USA 25A, Women Doubles',
#   'sr:competition:17022',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17034',
#   'ITF Austria 01A, Women Doubles',
#   'sr:competition:17030',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17046',
#   'ITF Romania 08A, Women Doubles',
#   'sr:competition:17040',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17050',
#   'ITF Russia 05A, Women Doubles',
#   'sr:competition:17042',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17056',
#   'ITF Spain 12A, Women Doubles',
#   'sr:competition:17052',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17060',
#   'ITF Thailand 11A, Women Doubles',
#   'sr:competition:17058',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17068',
#   'ITF Turkey 28B, Women Doubles',
#   'sr:competition:17064',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17076',
#   'ITF Turkey F6, Men Doubles',
#   'sr:competition:15918',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17080',
#   'ITF USA F7, Men Doubles',
#   'sr:competition:15920',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17084',
#   'ITF China F2, Men Doubles',
#   'sr:competition:15922',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17088',
#   'ITF Tunisia F7, Men Doubles',
#   'sr:competition:15932',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17092',
#   'ITF Egypt F6, Men Doubles',
#   'sr:competition:15924',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17096',
#   'ITF Turkey F7, Men Doubles',
#   'sr:competition:15934',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17100',
#   'ITF USA F8, Men Doubles',
#   'sr:competition:15936',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17104',
#   'ITF Indonesia F3, Men Doubles',
#   'sr:competition:15928',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17110',
#   'ITF Canada F1, Men Doubles',
#   'sr:competition:15938',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17114',
#   'ITF France F4, Men Doubles',
#   'sr:competition:15940',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17118',
#   'ITF Italy F2, Men Doubles',
#   'sr:competition:15942',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17122',
#   'ITF China F3, Men Doubles',
#   'sr:competition:15944',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17124',
#   'ITF Egypt F7, Men Doubles',
#   'sr:competition:15946',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17128',
#   'ITF Tunisia F8, Men Doubles',
#   'sr:competition:15952',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17130',
#   'ITF Turkey F8, Men Doubles',
#   'sr:competition:15954',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17144',
#   'ITF Portugal F16, Men Doubles',
#   'sr:competition:17206',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17150',
#   'ITF Italy 22A, Women Doubles',
#   'sr:competition:17278',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17156',
#   'ITF Poland 04A, Women Doubles',
#   'sr:competition:17286',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17158',
#   'ITF Spain 07B, Women Doubles',
#   'sr:competition:17146',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17168',
#   'ITF USA F6, Men Doubles',
#   'sr:competition:15974',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17174',
#   'ITF Poland F9, Men Doubles',
#   'sr:competition:17170',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17180',
#   'ITF Belarus F2, Men Doubles',
#   'sr:competition:17176',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17186',
#   'ITF Belgium F9, Men Doubles',
#   'sr:competition:17182',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17192',
#   'ITF Finland F3, Men Doubles',
#   'sr:competition:17188',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17198',
#   'ITF Germany F11, Men Doubles',
#   'sr:competition:17194',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17204',
#   'ITF Netherlands F5, Men Doubles',
#   'sr:competition:17200',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17212',
#   'ITF Romania F10, Men Doubles',
#   'sr:competition:17208',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17218',
#   'ITF Russia F7, Men Doubles',
#   'sr:competition:17214',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17224',
#   'ITF Serbia F2, Men Doubles',
#   'sr:competition:17220',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17230',
#   'ITF Spain F25, Men Doubles',
#   'sr:competition:17226',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17236',
#   'ITF Canada 01A, Women Doubles',
#   'sr:competition:17232',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17244',
#   'ITF Germany 13A, Women Doubles',
#   'sr:competition:17238',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17250',
#   'ITF Switzerland 03A, Women Doubles',
#   'sr:competition:17246',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17256',
#   'ITF Thailand 12A, Women Doubles',
#   'sr:competition:17252',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17262',
#   'ITF Austria 02A, Women Doubles',
#   'sr:competition:17258',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17266',
#   'ITF Thailand F6, Men Doubles',
#   'sr:competition:15978',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17274',
#   'ITF Turkey F30, Men Doubles',
#   'sr:competition:17270',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17284',
#   'ITF Netherlands 04A, Women Doubles',
#   'sr:competition:17280',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17294',
#   'ITF Russia 06A, Women Doubles',
#   'sr:competition:17290',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17300',
#   'ITF Spain 13A, Women Doubles',
#   'sr:competition:17296',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17308',
#   'ITF Australia F1, Men Doubles',
#   'sr:competition:16008',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17312',
#   'ITF Canada F2, Men Doubles',
#   'sr:competition:16010',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17318',
#   'ITF Croatia F1, Men Doubles',
#   'sr:competition:16012',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17322',
#   'ITF Egypt F8, Men Doubles',
#   'sr:competition:16014',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17328',
#   'ITF France F5, Men Doubles',
#   'sr:competition:16016',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17338',
#   'ITF Japan F1, Men Doubles',
#   'sr:competition:16024',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17350',
#   'ITF Belgium F10, Men Doubles',
#   'sr:competition:17484',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17356',
#   'ITF Italy F26, Men Doubles',
#   'sr:competition:17494',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17362',
#   'ITF Portugal F17, Men Doubles',
#   'sr:competition:17512',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17368',
#   'ITF Romania F11, Men Doubles',
#   'sr:competition:17514',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17374',
#   'ITF Switzerland F4, Men Doubles',
#   'sr:competition:17516',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17380',
#   'ITF Turkiye 30A, Women Doubles',
#   'sr:competition:17518',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17384',
#   'ITF Poland 05A, Women Doubles',
#   'sr:competition:17556',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17392',
#   'ITF Turkey F12 Men Doubles',
#   'sr:competition:16110',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17394',
#   'ITF Tunisia F12 Men Doubles',
#   'sr:competition:16108',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17400',
#   'ITF Portugal F4, Men Doubles',
#   'sr:competition:16106',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17404',
#   'ITF Japan F4, Men Doubles',
#   'sr:competition:16104',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17408',
#   'ITF Israel F3, Men Doubles',
#   'sr:competition:16102',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17412',
#   'ITF Indonesia F4, Men Doubles',
#   'sr:competition:16100',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17416',
#   'ITF Greece F4, Men Doubles',
#   'sr:competition:16098',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17420',
#   'ITF Egypt F11, Men Doubles',
#   'sr:competition:16096',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17424',
#   'ITF Bahrain F2, Men Doubles',
#   'sr:competition:16092',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17428',
#   'ITF Spain F9, Men Doubles',
#   'sr:competition:16090',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17432',
#   'ITF Italy F6, Men Doubles',
#   'sr:competition:16088',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17436',
#   'ITF Turkey F11, Men Doubles',
#   'sr:competition:16086',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17440',
#   'ITF Tunisia F11, Men Doubles',
#   'sr:competition:16084',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17444',
#   'ITF Spain F8, Men Doubles',
#   'sr:competition:16082',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17448',
#   'ITF Japan F3, Men Doubles',
#   'sr:competition:16080',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17452',
#   'ITF Israel F2, Men Doubles',
#   'sr:competition:16078',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17458',
#   'ITF Poland F10, Men Doubles',
#   'sr:competition:17454',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17464',
#   'ITF Spain F26, Men Doubles',
#   'sr:competition:17460',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17470',
#   'ITF Turkey F31, Men Doubles',
#   'sr:competition:17466',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17476',
#   'ITF Argentina F4, Men Doubles',
#   'sr:competition:17472',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17482',
#   'ITF Belarus F3, Men Doubles',
#   'sr:competition:17478',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17490',
#   'ITF Germany F12, Men Doubles',
#   'sr:competition:17486',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17502',
#   'ITF Netherlands F6, Men Doubles',
#   'sr:competition:17498',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17510',
#   'ITF Serbia F3, Men Doubles',
#   'sr:competition:17506',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17524',
#   'ITF Germany 14A, Women Doubles',
#   'sr:competition:17520',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17530',
#   'ITF Hungary 06A, Women Doubles',
#   'sr:competition:17526',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17536',
#   'ITF Japan 09A, Women Doubles',
#   'sr:competition:17532',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17542',
#   'ITF Belgium 05A, Women Doubles',
#   'sr:competition:17538',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17548',
#   'ITF Italy 23A, Women Doubles',
#   'sr:competition:17544',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17554',
#   'ITF Netherlands 05A, Women Doubles',
#   'sr:competition:17550',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17562',
#   'ITF Romania 09A, Women Doubles',
#   'sr:competition:17558',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17568',
#   'ITF Serbia 04A, Women Doubles',
#   'sr:competition:17564',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17574',
#   'ITF Switzerland 04A, Women Doubles',
#   'sr:competition:17570',
#   'doubles',
#   'women',
#   'sr:category:213'),
#  ('sr:competition:17578',
#   'ITF Greece F3, Men Doubles',
#   'sr:competition:16074',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17582',
#   'ITF Egypt F10, Men Doubles',
#   'sr:competition:16070',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17586',
#   'ITF Croatia F3, Men Doubles',
#   'sr:competition:16068',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17590',
#   'ITF Bahrain F1, Men Doubles',
#   'sr:competition:16066',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17594',
#   'ITF USA F11, Men Doubles',
#   'sr:competition:16064',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17598',
#   'ITF Italy F5, Men Doubles',
#   'sr:competition:16062',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17602',
#   'ITF Australia F3, Men Doubles',
#   'sr:competition:16060',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17606',
#   'ITF Turkey F10, Men Doubles',
#   'sr:competition:16058',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17610',
#   'ITF Tunisia F10, Men Doubles',
#   'sr:competition:16056',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17614',
#   'ITF Japan F2, Men Doubles',
#   'sr:competition:16050',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17618',
#   'ITF Italy F4, Men Doubles',
#   'sr:competition:16048',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17622',
#   'ITF Israel F1, Men Doubles',
#   'sr:competition:16046',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17626',
#   'ITF India F5, Men Doubles',
#   'sr:competition:16044',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17628',
#   'ITF Portugal F2, Men Doubles',
#   'sr:competition:16026',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17634',
#   'ITF Tunisia F9, Men Doubles',
#   'sr:competition:16028',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17638',
#   'ITF France F6, Men Doubles',
#   'sr:competition:16040',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17642',
#   'ITF Egypt F9, Men Doubles',
#   'sr:competition:16038',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17646',
#   'ITF Turkey F9, Men Doubles',
#   'sr:competition:16030',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17650',
#   'ITF Croatia F2, Men Doubles',
#   'sr:competition:16036',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ('sr:competition:17654',
#   'ITF USA F10, Men Doubles',
#   'sr:competition:16034',
#   'doubles',
#   'men',
#   'sr:category:785'),
#  ...]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#             competition_id                                   competition_name  \
# 0      sr:competition:2557                              Wimbledon Men Doubles
# 1      sr:competition:2561                            Wimbledon Women Doubles
# 2      sr:competition:2569                        Australian Open Men Doubles
# 3      sr:competition:2573                      Australian Open Women Doubles
# 4      sr:competition:2581                            French Open Men Doubles
# ...                    ...                                                ...
# 2918  sr:competition:46691  ATP Challenger Nottingham 3, Great Britain Men...
# 2919  sr:competition:46955               WTA Sao Paulo, Brazil Women, Doubles
# 2920  sr:competition:46961             WTA 125K Porto, Portugal Women Doubles
# 2921  sr:competition:47047        WTA 125K San Sebastian, Spain Women Doubles
# 2922  sr:competition:47055  WTA 125K Caldas da Rainha, Portugal Women Doubles
#
#      competition_parent_id competition_type competition_gender  \
# 0      sr:competition:2553          doubles                men
# 1      sr:competition:2553          doubles              women
# 2      sr:competition:2565          doubles                men
# 3      sr:competition:2565          doubles              women
# 4      sr:competition:2577          doubles                men
# ...                    ...              ...                ...
# 2918  sr:competition:46687          doubles                men
# 2919  sr:competition:46951          doubles              women
# 2920  sr:competition:46957          doubles              women
# 2921  sr:competition:47043          doubles              women
# 2922  sr:competition:47051          doubles              women
#
#            categoryid
# 0       sr:category:3
# 1       sr:category:6
# 2       sr:category:3
# 3       sr:category:6
# 4       sr:category:3
# ...               ...
# 2918   sr:category:72
# 2919    sr:category:6
# 2920  sr:category:871
# 2921  sr:category:871
# 2922  sr:category:871
#
# [2923 rows x 6 columns]

# %% [markdown]
# 4)	Get competitions that belong to a specific category (e.g., ITF Men)

# %%
sql_query = """Select cat.categoryname, 
comp.competition_name, comp.competition_type, comp.competition_gender from 
categories_table cat full join competition_table comp on
comp.categoryid = cat.categoryid where cat.categoryname = 'ITF Men'"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('ITF Men', 'Dominican Republic F2 Men Singles', 'singles', 'men'),
#  ('ITF Men', 'Dominican Republic F2 Men Doubles', 'doubles', 'men'),
#  ('ITF Men',
#   'ITF Men Stuttgart-Stammheim, Germany Men Singles',
#   'singles',
#   'men'),
#  ('ITF Men',
#   'ITF Men Stuttgart-Stammheim, Germany Men Doubles',
#   'doubles',
#   'men'),
#  ('ITF Men', 'ITF Men Cherkassy, Ukraine Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Cherkassy, Ukraine Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'Great Britain F4 Men Singles', 'singles', 'men'),
#  ('ITF Men', 'Great Britain F4 Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Vrsar, Croatia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Vrsar, Croatia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Bytom, Poland Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Bytom, Poland Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Frinton, Great Britain Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Frinton, Great Britain Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Izmir, Turkey Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Izmir, Turkey Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Vierumaki, Finland Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Vierumaki, Finland Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'USA F24 Men Singles', 'singles', 'men'),
#  ('ITF Men', 'USA F24 Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Leimen, Germany Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Leimen, Germany Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'Turkiye F26 Men Singles', 'singles', 'men'),
#  ('ITF Men', 'Turkiye F26 Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Solin, Croatia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Solin, Croatia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Mansfield, USA Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Mansfield, USA Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F39 Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F39 Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Temuco, Chile Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Temuco, Chile Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Osorno, Chile Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Osorno, Chile Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Astana, Kazakhstan Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Astana, Kazakhstan Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Wirral, Great Britain Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Wirral, Great Britain Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Feucherolles, France Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Feucherolles, France Men Doubles', 'doubles', 'men'),
#  ('ITF Men',
#   'ITF Men Guatemala City, Guatemala Men Singles',
#   'singles',
#   'men'),
#  ('ITF Men',
#   'ITF Men Guatemala City, Guatemala Men Doubles',
#   'doubles',
#   'men'),
#  ('ITF Men', 'ITF Men Yuxi, China Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Yuxi, China Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Itajai, Brazil Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Itajai, Brazil Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Bath, Great Britain Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Bath, Great Britain Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Saint-Raphael, France Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Saint-Raphael, France Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Heraklion, Greece Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Heraklion, Greece Men Doubles', 'doubles', 'men'),
#  ('ITF Men',
#   'ITF Men Kaohsiung, Chinese Taipei Men Singles',
#   'singles',
#   'men'),
#  ('ITF Men',
#   'ITF Men Kaohsiung, Chinese Taipei Men Doubles',
#   'doubles',
#   'men'),
#  ('ITF Men', 'ITF Men Cordoba, Mexico Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Cordoba, Mexico Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Madurai, India Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Madurai, India Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Chennai, India Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Chennai, India Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Villa Allende, Argentina Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Villa Allende, Argentina Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Bangkok, Thailand Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Bangkok, Thailand Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Mersin, Turkey Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Mersin, Turkey Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Mandya, India Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Mandya, India Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Rabat, Morocco Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Rabat, Morocco Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Mysore, India Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Mysore, India Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Maribor, Slovenia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Maribor, Slovenia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Sapporo, Japan Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Sapporo, Japan Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Coimbatore, India Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Coimbatore, India Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Modena, Italy Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Modena, Italy Men Doubles', 'doubles', 'men'),
#  ('ITF Men',
#   'ITF Men Felixstowe, Great Britain Men Singles',
#   'singles',
#   'men'),
#  ('ITF Men',
#   'ITF Men Felixstowe, Great Britain Men Doubles',
#   'doubles',
#   'men'),
#  ('ITF Men', 'ITF Men Ostend, Belgium Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Ostend, Belgium Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Friedberg, Germany Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Friedberg, Germany Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Poertschach, Austria Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Poertschach, Austria Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Winnipeg, Canada Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Winnipeg, Canada Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Medellin, Colombia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Medellin, Colombia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Kenn, Germany Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Kenn, Germany Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men St. Poelten, Austria Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men St. Poelten, Austria Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Alice Springs, Australia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Alice Springs, Australia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men La Rioja, Argentina Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men La Rioja, Argentina Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Manzanillo, Mexico Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Manzanillo, Mexico Men Doubles', 'doubles', 'men'),
#  ('ITF Men',
#   'ITF Men Danderyd-Stockholm, Sweden Men Singles',
#   'singles',
#   'men'),
#  ('ITF Men',
#   'ITF Men Danderyd-Stockholm, Sweden Men Doubles',
#   'doubles',
#   'men'),
#  ('ITF Men', 'ITF Men Costa Mesa, USA Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Costa Mesa, USA Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Markham, Canada Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Markham, Canada Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Hambach, Germany Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Hambach, Germany Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Belem, Brazil Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Belem, Brazil Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Irvine, USA Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Irvine, USA Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Villavicencio, Colombia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Villavicencio, Colombia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Annaba, Algeria Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Annaba, Algeria Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Mumbai, India Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Mumbai, India Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Santa Maria, Brazil Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Santa Maria, Brazil Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Phnom Penh, Cambodia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Phnom Penh, Cambodia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Porto Alegre, Brazil Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Porto Alegre, Brazil Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Pereira, Colombia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Pereira, Colombia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Bogota, Colombia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Bogota, Colombia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Nishi Tama, Japan Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Romania F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Taverne, Switzerland Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Taverne, Switzerland Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Sharm El Sheikh, Egypt Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Sharm El Sheikh, Egypt Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Maracay, Venezuela Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Maracay, Venezuela Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Maracaibo, Venezuela Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Maracaibo, Venezuela Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Putian, China Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Putian, China Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Coimbra, Portugal Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Coimbra, Portugal Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Litija, Slovenia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Litija, Slovenia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Stara Zagora, Bulgaria Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Stara Zagora, Bulgaria Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Sibiu, Romania Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Sibiu, Romania Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Busto Arsizio, Italy Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Busto Arsizio, Italy Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Sabac, Serbia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Sabac, Serbia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Seefeld, Austria Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Seefeld, Austria Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Focsani, Romania Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Focsani, Romania Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Tallinn, Estonia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Tallinn, Estonia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Misiones, Argentina Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Misiones, Argentina Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Sleza, Poland Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Sleza, Poland Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Bejar, Spain Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Bejar, Spain Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Geneva, Switzerland Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Geneva, Switzerland Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Medias, Romania Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Medias, Romania Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Este, Italy Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Este, Italy Men Doubles', 'doubles', 'men'),
#  ('ITF Men',
#   'ITF Men Jupille-Sur-Meuse, Belgium Men Singles',
#   'singles',
#   'men'),
#  ('ITF Men',
#   'ITF Men Jupille-Sur-Meuse, Belgium Men Doubles',
#   'doubles',
#   'men'),
#  ('ITF Men', 'ITF Men Libreville, Gabon Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Libreville, Gabon Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Campos Do Jordao, Brazil Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Campos Do Jordao, Brazil Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Manizales, Colombia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Manizales, Colombia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Damme, Belgium Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Damme, Belgium Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Lausanne, Switzerland Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Lausanne, Switzerland Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Quito, Ecuador Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Quito, Ecuador Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Nis, Serbia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Nis, Serbia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Sokobanja, Serbia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Sokobanja, Serbia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Cochabamba, Bolivia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Cochabamba, Bolivia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Sant Cugat, Spain Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Sant Cugat, Spain Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Nicosia, Cyprus Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Nicosia, Cyprus Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Popayan, Colombia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Popayan, Colombia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Bol, Croatia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Bol, Croatia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Raipur, India Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Raipur, India Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Larnaca, Cyprus Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Larnaca, Cyprus Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Kish, Iran Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Kish, Iran Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Bhimavaram, India Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Bhimavaram, India Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Manila, Philippines Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Manila, Philippines Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Melbourne, Australia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Melbourne, Australia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Oran, Algeria Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Oran, Algeria Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Algiers, Algeria Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Algiers, Algeria Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Karshi, Uzbekistan Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Queretaro, Mexico Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Queretaro, Mexico Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Galati, Romania Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Galati, Romania Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Chaco, Argentina Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Chaco, Argentina Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Tehran, Iran Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Tehran, Iran Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Vsevolozhsk, Russia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Vsevolozhsk, Russia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Wollongong, Australia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Wollongong, Australia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Gwalior, India Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Gwalior, India Men Doubles', 'doubles', 'men'),
#  ('ITF Men',
#   'ITF Men Santiago de los Caballeros, Dominican Republic Men Singles',
#   'singles',
#   'men'),
#  ('ITF Men',
#   'ITF Men Santiago de los Caballeros, Dominican Republic Men Doubles',
#   'doubles',
#   'men'),
#  ('ITF Men', 'ITF Men Jassowal, India Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Jassowal, India Men Doubles', 'doubles', 'men'),
#  ('ITF Men',
#   'ITF Men Sarajevo, Bosnia/Herzegovina Men Singles',
#   'singles',
#   'men'),
#  ('ITF Men',
#   'ITF Men Sarajevo, Bosnia/Herzegovina Men Doubles',
#   'doubles',
#   'men'),
#  ('ITF Men', 'ITF Men Erzurum, Turkey Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Erzurum, Turkey Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Duino Aurisina, Italy Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Duino Aurisina, Italy Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Israel F14, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Israel F14, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Middelkerke, Belgium Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Middelkerke, Belgium Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Rancagua, Chile Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Rancagua, Chile Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Ismaning, Germany Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Ismaning, Germany Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Valledupar, Colombia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Valledupar, Colombia Men Doubles', 'doubles', 'men'),
#  ('ITF Men',
#   'ITF Men Margarita Island, Venezuela Men Singles',
#   'singles',
#   'men'),
#  ('ITF Men',
#   'ITF Men Margarita Island, Venezuela Men Doubles',
#   'doubles',
#   'men'),
#  ('ITF Men', 'ITF Romania F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men La Libertad, El Salvador Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men La Libertad, El Salvador Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Limassol, Cyprus Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Limassol, Cyprus Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men San Pedro Sula, Honduras Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men San Pedro Sula, Honduras Men Doubles', 'doubles', 'men'),
#  ('ITF Men',
#   'ITF Men Santo Domingo Este, Dominican Republic Men Singles',
#   'singles',
#   'men'),
#  ('ITF Men',
#   'ITF Men Santo Domingo Este, Dominican Republic Men Doubles',
#   'doubles',
#   'men'),
#  ('ITF Men', 'ITF Men Puerto Montt, Chile Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Puerto Montt, Chile Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Baku, Azerbaijan Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Baku, Azerbaijan Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Switzerland F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Morocco F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Morocco F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF France F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF France F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Croatia F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Croatia F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Sweden F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Sweden F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Mozambique F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Mozambique F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F12, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F12, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Brazil F9, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Brazil F9, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Mexico F22, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Mexico F22, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Bulgaria F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Bulgaria F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F14, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F14, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F9, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F9, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Ruse, Bulgaria Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Ruse, Bulgaria Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Israel F10, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Israel F10, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Japan F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Japan F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F16, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F16, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Poland F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Poland F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Buzau, Romania Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Buzau, Romania Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Poland F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Poland F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkiye F25, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkiye F25, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Skopje, FYR Macedonia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Skopje, FYR Macedonia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Korea F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Korea F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Germany F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Germany F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Brazil F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Brazil F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F20, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F20, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Germany F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Germany F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Piracicaba, Brazil Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Piracicaba, Brazil Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F21, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F21, Men Doubles', 'doubles', 'men'),
#  ('ITF Men',
#   'ITF Men Thu Dau Mot City, Vietnam Men Singles',
#   'singles',
#   'men'),
#  ('ITF Men',
#   'ITF Men Thu Dau Mot City, Vietnam Men Doubles',
#   'doubles',
#   'men'),
#  ('ITF Men', 'ITF Morocco F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Morocco F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F24, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F24, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Morocco F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Morocco F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Finland F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Finland F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Switzerland F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Switzerland F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Indonesia F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Indonesia F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men St. Petersburg, Russia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men St. Petersburg, Russia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F28, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F28, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Netherlands F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Netherlands F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F28, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F28, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Hungary F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Hungary F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Hungary F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Hungary F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Niagara, Canada Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Niagara, Canada Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F30, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F30, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Kiev, Ukraine Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Kiev, Ukraine Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Hungary F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Hungary F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Neiva, Colombia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Neiva, Colombia Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Vallduxo, Spain Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Vallduxo, Spain Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Salinas, Ecuador Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Salinas, Ecuador Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F34, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F34, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Latina, Italy Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Latina, Italy Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Almeria, Spain Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Almeria, Spain Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Great Britain F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Great Britain F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Blacktown, Australia Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Blacktown, Australia Men Doubles', 'doubles', 'men'),
#  ('ITF Men',
#   'ITF Men San Salvador, El Salvador Men Singles',
#   'singles',
#   'men'),
#  ('ITF Men',
#   'ITF Men San Salvador, El Salvador Men Doubles',
#   'doubles',
#   'men'),
#  ('ITF Men', 'ITF Czech Republic F10, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Czech Republic F10, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Talca, Chile Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Talca, Chile Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Czech Republic F12, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Czech Republic F12, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Paysandu, Uruguay Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Paysandu, Uruguay Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Salto, Uruguay Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Salto, Uruguay Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men Mayaguez, Puerto Rico Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men Mayaguez, Puerto Rico Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Switzerland F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Switzerland F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F9, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F9, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF India F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF India F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF India F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF India F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF India F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF India F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F21, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F21, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Australia F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Australia F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF India F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF India F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF China F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF China F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Mexico F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Mexico F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Greece F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Greece F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Hungary F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Hungary F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F12, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F12, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Mexico F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Mexico F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Vietnam F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Vietnam F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Singapore F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Singapore F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Greece F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Greece F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Men San Jose, Costa Rica Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Men San Jose, Costa Rica Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Mexico F21, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Mexico F21, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Poland F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Poland F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF China F10, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF China F10, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Poland F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Poland F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F10, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F10, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Hong Kong F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Hong Kong F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF France F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF France F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Germany F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Germany F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF France F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF France F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Germany F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Germany F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Germany F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Germany F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Kazakhstan F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Kazakhstan F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF France F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF France F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Belgium F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Belgium F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F11, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F11, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Kazakhstan F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Kazakhstan F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Switzerland F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Great Britain F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Indonesia F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Great Britain F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Great Britain F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF China F13, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF China F13, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Czech Republic F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Czech Republic F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Germany F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Germany F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Ireland F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Ireland F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F22, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F22, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F26, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F26, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F24, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F24, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Austria F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Austria F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Belgium F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Belgium F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Colombia F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Colombia F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F21, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F21, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF France F16, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF France F16, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Georgia F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Georgia F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F22, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F22, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Lithuania F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Lithuania F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Morocco F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Morocco F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Poland F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Poland F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F12, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F12, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF China F14, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF China F14, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF France F17, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF France F17, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Ireland F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Ireland F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F23, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F23, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F23, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F23, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F25, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F25, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Austria F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Austria F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Belgium F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Belgium F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Colombia F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Colombia F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F22, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F22, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Estonia F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Estonia F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Macedonia F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Macedonia F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Morocco F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Morocco F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Poland F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Poland F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F13, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F13, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Romania F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Romania F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Russia F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Russia F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Slovakia F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Slovakia F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkiye F27, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkiye F27, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Great Britain F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Indonesia F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Latvia F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Latvia F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F14, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F14, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Romania F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Romania F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkiye F28, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkiye F28, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F26, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F26, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Austria F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Austria F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Belgium F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Belgium F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Colombia F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Colombia F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F23, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F23, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Macedonia F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Macedonia F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Germany F9, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Germany F9, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Morocco F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Morocco F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Poland F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Poland F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Russia F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Russia F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Slovakia F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Slovakia F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Thailand F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Thailand F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF China F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF China F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Great Britain F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Great Britain F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF India F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF India F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F25, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F25, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F27, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F27, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Austria F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Austria F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Belarus F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Belarus F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Belgium F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Belgium F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Finland F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Finland F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Germany F10, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Germany F10, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F15, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F15, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Romania F9, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Romania F9, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Russia F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Russia F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Serbia F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Serbia F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Slovakia F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Slovakia F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Thailand F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Thailand F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkiye F29, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkiye F29, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF China F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF China F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Indonesia F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Indonesia F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Canada F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Canada F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF France F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF France F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF China F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF China F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F16, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F16, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Poland F9, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Poland F9, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Belarus F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Belarus F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Belgium F9, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Belgium F9, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Finland F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Finland F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Germany F11, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Germany F11, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Netherlands F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Netherlands F5, Men Doubles', 'doubles', 'men'),
# ...
#  ('ITF Men', 'ITF Turkey F12 Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F12 Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F12 Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F12 Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Japan F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Japan F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Israel F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Israel F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Indonesia F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Indonesia F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Greece F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Greece F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F11, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F11, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Bahrain F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Bahrain F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F9, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F9, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F11, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F11, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F11, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F11, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Japan F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Japan F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Israel F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Israel F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Poland F10, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Poland F10, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F26, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F26, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F31, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F31, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Argentina F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Argentina F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Belarus F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Belarus F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Germany F12, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Germany F12, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Netherlands F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Netherlands F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Serbia F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Serbia F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Greece F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Greece F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F10, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F10, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Croatia F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Croatia F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Bahrain F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Bahrain F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F11, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F11, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Australia F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Australia F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F10, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F10, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F10, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F10, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Japan F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Japan F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Israel F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Israel F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF India F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF India F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F9, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F9, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF France F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF France F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F9, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F9, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F9, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F9, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Croatia F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Croatia F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F10, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F10, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF China F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF China F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F15, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F15, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F10, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F10, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F12, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F12, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F16, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F16, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F16, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F16, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Greece F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Greece F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Indonesia F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Indonesia F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F11, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F11, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Japan F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Japan F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Kazakhstan F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Kazakhstan F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Qatar F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Qatar F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Israel F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Israel F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F13, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F13, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F15, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F15, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F13, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F13, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Uzbekistan F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Uzbekistan F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F13, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F13, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F10, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F10, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F13, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F13, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Indonesia F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Indonesia F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Kazakhstan F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Kazakhstan F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Qatar F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Qatar F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F14, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F14, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F14, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F14, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F9, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F9, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Uzbekistan F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Uzbekistan F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Egypt F14, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Egypt F14, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF France F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF France F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Kazakhstan F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Kazakhstan F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Qatar F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Qatar F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F15, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F15, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F15, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F15, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F14, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F14, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF France F9, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF France F9, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Nigeria F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Nigeria F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F12, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F12, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF France F10, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF France F10, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Israel F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Israel F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F11, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F11, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F17, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F17, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F17, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F17, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF USA F16, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF USA F16, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Nigeria F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Nigeria F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Sweden F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Sweden F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF China F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF China F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Israel F6, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Israel F6, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Mexico F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Mexico F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F13, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F13, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F18, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F18, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F18, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F18, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Ukraine F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Ukraine F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF China F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF China F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Nigeria F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Nigeria F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Sweden F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Sweden F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Czech Republic F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Czech Republic F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Hungary F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Hungary F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Israel F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Israel F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F13, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F13, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Mexico F4, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Mexico F4, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Romania F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Romania F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F14, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F14, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Tunisia F19, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Tunisia F19, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Hungary F7, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Hungary F7, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Portugal F18, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Portugal F18, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Turkey F19, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Turkey F19, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Ukraine F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Ukraine F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF China F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF China F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Romania F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Romania F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Bosnia & Herzegovina F1, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Bosnia & Herzegovina F1, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Czech Republic F2, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Czech Republic F2, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Hungary F3, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Hungary F3, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Israel F8, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Israel F8, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Canada F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Canada F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Spain F27, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Spain F27, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Argentina F5, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Argentina F5, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Belgium F11, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Belgium F11, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Italy F27, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Italy F27, Men Doubles', 'doubles', 'men'),
#  ('ITF Men', 'ITF Poland F11, Men Singles', 'singles', 'men'),
#  ('ITF Men', 'ITF Poland F11, Men Doubles', 'doubles', 'men'),
#  ...]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#      categoryname                                  competition_name  \
# 0         ITF Men                 Dominican Republic F2 Men Singles
# 1         ITF Men                 Dominican Republic F2 Men Doubles
# 2         ITF Men  ITF Men Stuttgart-Stammheim, Germany Men Singles
# 3         ITF Men  ITF Men Stuttgart-Stammheim, Germany Men Doubles
# 4         ITF Men            ITF Men Cherkassy, Ukraine Men Singles
# ...           ...                                               ...
# 2193      ITF Men                         ITF Chile F4, Men Singles
# 2194      ITF Men                  ITF South Africa F7, Men Singles
# 2195      ITF Men                  ITF South Africa F7, Men Doubles
# 2196      ITF Men                        ITF Spain F38, Men Singles
# 2197      ITF Men                        ITF Spain F38, Men Doubles
#
#      competition_type competition_gender
# 0             singles                men
# 1             doubles                men
# 2             singles                men
# 3             doubles                men
# 4             singles                men
# ...               ...                ...
# 2193          singles                men
# 2194          singles                men
# 2195          doubles                men
# 2196          singles                men
# 2197          doubles                men
#
# [2198 rows x 4 columns]

# %% [markdown]
# 5)	Identify parent competitions and their sub-competitions

# %%
sql_query = """SELECT 
    parent.competition_id AS parent_id,
    parent.competition_name AS parent_name,
    child.competition_id AS sub_competition_id,
    child.competition_name AS sub_competition_name,
    child.competition_type,
    child.competition_gender
FROM 
    competition_table AS parent
inner join
    competition_table AS child
ON 
    parent.competition_id = child.competition_parent_id"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('sr:competition:16976',
#   'ITF Romania F9, Men Singles',
#   'sr:competition:16978',
#   'ITF Romania F9, Men Doubles',
#   'doubles',
#   'men'),
#  ('sr:competition:45363',
#   'UTR Boca Raton W01',
#   'sr:competition:45971',
#   'UTR Boca Raton W03',
#   'singles',
#   'women')]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#               parent_id                  parent_name    sub_competition_id  \
# 0  sr:competition:16976  ITF Romania F9, Men Singles  sr:competition:16978
# 1  sr:competition:45363           UTR Boca Raton W01  sr:competition:45971
#
#           sub_competition_name competition_type competition_gender
# 0  ITF Romania F9, Men Doubles          doubles                men
# 1           UTR Boca Raton W03          singles              women

# %% [markdown]
# 6)	Analyze the distribution of competition types by category

# %%
sql_query = """Select cat.categoryname,comp.competition_type, count(comp.competition_id) as no_of_competitions
from categories_table cat full join competition_table comp on
comp.categoryid = cat.categoryid group by cat.categoryname, comp.competition_type 
order by cat.categoryname, comp.competition_type"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('ATP', 'doubles', 107),
#  ('ATP', 'mixed', 2),
#  ('ATP', 'mixed_doubles', 6),
#  ('ATP', 'singles', 108),
#  ('Billie Jean King Cup', 'mixed', 1),
#  ('Challenger', 'doubles', 449),
#  ('Challenger', 'singles', 451),
#  ('Davis Cup', 'mixed', 1),
#  ('Exhibition', 'doubles', 8),
#  ('Exhibition', 'mixed_doubles', 2),
#  ('Exhibition', 'singles', 22),
#  ('Hopman Cup', 'mixed', 1),
#  ('IPTL', 'singles', 1),
#  ('ITF Men', 'doubles', 1099),
#  ('ITF Men', 'singles', 1099),
#  ('ITF Women', 'doubles', 1018),
#  ('ITF Women', 'singles', 1014),
#  ('Juniors', 'doubles', 8),
#  ('Juniors', 'singles', 8),
#  ('Legends', 'doubles', 8),
#  ('Legends', 'mixed_doubles', 3),
#  ('United Cup', 'mixed', 1),
#  ('UTR Men', 'singles', 89),
#  ('UTR Women', 'singles', 78),
#  ('Wheelchairs', 'doubles', 8),
#  ('Wheelchairs', 'singles', 8),
#  ('Wheelchairs Juniors', 'doubles', 2),
#  ('Wheelchairs Juniors', 'singles', 4),
#  ('WTA', 'doubles', 127),
#  ('WTA', 'singles', 128),
#  ('WTA 125K', 'doubles', 89),
#  ('WTA 125K', 'singles', 89)]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#             categoryname competition_type  no_of_competitions
# 0                    ATP          doubles                 107
# 1                    ATP            mixed                   2
# 2                    ATP    mixed_doubles                   6
# 3                    ATP          singles                 108
# 4   Billie Jean King Cup            mixed                   1
# 5             Challenger          doubles                 449
# 6             Challenger          singles                 451
# 7              Davis Cup            mixed                   1
# 8             Exhibition          doubles                   8
# 9             Exhibition    mixed_doubles                   2
# 10            Exhibition          singles                  22
# 11            Hopman Cup            mixed                   1
# 12                  IPTL          singles                   1
# 13               ITF Men          doubles                1099
# 14               ITF Men          singles                1099
# 15             ITF Women          doubles                1018
# 16             ITF Women          singles                1014
# 17               Juniors          doubles                   8
# 18               Juniors          singles                   8
# 19               Legends          doubles                   8
# 20               Legends    mixed_doubles                   3
# 21            United Cup            mixed                   1
# 22               UTR Men          singles                  89
# 23             UTR Women          singles                  78
# 24           Wheelchairs          doubles                   8
# 25           Wheelchairs          singles                   8
# 26   Wheelchairs Juniors          doubles                   2
# 27   Wheelchairs Juniors          singles                   4
# 28                   WTA          doubles                 127
# 29                   WTA          singles                 128
# 30              WTA 125K          doubles                  89
# 31              WTA 125K          singles                  89

# %% [markdown]
# 7)	List all competitions with no parent (top-level competitions)

# %%
sql_query = """Select competition_id,competition_name from competition_table where competition_parent_id = 'NaN'"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('sr:competition:620', 'Hopman Cup'),
#  ('sr:competition:660', 'World Team Cup'),
#  ('sr:competition:1207', 'Championship International Series'),
#  ('sr:competition:2100', 'Davis Cup'),
#  ('sr:competition:2102', 'Billie Jean King Cup'),
#  ('sr:competition:12229', 'IPTL'),
#  ('sr:competition:15393', 'ITF Men San Jose, Costa Rica Men Singles'),
#  ('sr:competition:15395', 'ITF Men San Jose, Costa Rica Men Doubles'),
#  ('sr:competition:21028', 'ITF Colombia 02A, Women Singles'),
#  ('sr:competition:21228', 'ITF Australia 02B, Women Doubles'),
#  ('sr:competition:22334', 'ITF Uzbekistan 01A, Women Singles'),
#  ('sr:competition:22763', 'ITF Tunisia 39A, Women Doubles'),
#  ('sr:competition:22787', 'ITF Egypt F38, Men Doubles'),
#  ('sr:competition:22959', 'ITF USA 17A, Women Singles'),
#  ('sr:competition:22997', 'ITF Bosnia & Herzegovina 01A, Women Doubles'),
#  ('sr:competition:29204', 'ITF Mexico F13, Men Singles'),
#  ('sr:competition:29206', 'ITF Mexico F13, Men Doubles'),
#  ('sr:competition:29386', 'ITF Mexico 17A, Women Singles'),
#  ('sr:competition:31137', 'ITF Mexico F30, Men Singles'),
#  ('sr:competition:31139', 'ITF Mexico F30, Men Doubles'),
#  ('sr:competition:31263', 'ATP Cup'),
#  ('sr:competition:31481', 'NIU'),
#  ('sr:competition:32469', 'UTR Pro Match Series Men Singles'),
#  ('sr:competition:32557', 'LiveScore Cup, Women'),
#  ('sr:competition:32683', 'Battle of the Brits, Men Doubles'),
#  ('sr:competition:32685', 'Battle of the Brits, Men Singles'),
#  ('sr:competition:33007', 'WTA 125K Prague, Czech Republic'),
#  ('sr:competition:33009', 'WTA 125K Prague, Czech Republic Doubles'),
#  ('sr:competition:33107', 'ITF France 31A, Women Singles'),
#  ('sr:competition:33109', 'ITF France 31A, Women Doubles'),
#  ('sr:competition:35697', 'ITF Colombia F7, Men Doubles'),
#  ('sr:competition:37671', 'ITF Sweden 09A, Women Doubles'),
#  ('sr:competition:37933', 'ITF Sweden F9, Men Doubles'),
#  ('sr:competition:38335', 'ITF USA 53A, Women Singles'),
#  ('sr:competition:38341', 'United Cup'),
#  ('sr:competition:38755', 'ITF Tunisia F61 Men Singles'),
#  ('sr:competition:44567', 'Riyadh Exhibition'),
#  ('sr:competition:45133', 'ITF Tunisia 59A, Women Singles'),
#  ('sr:competition:45345', 'UTR Boca Raton W05'),
#  ('sr:competition:45347', 'UTR Newport Beach W03'),
#  ('sr:competition:45349', 'UTR Olomouc W01'),
#  ('sr:competition:45357', 'UTR Norman M01'),
#  ('sr:competition:45359', 'UTR Los Angeles M01'),
#  ('sr:competition:45361', 'UTR Cornella de Llobregat M01'),
#  ('sr:competition:45363', 'UTR Boca Raton W01'),
#  ('sr:competition:45365', 'UTR Norman W01'),
#  ('sr:competition:45367', 'UTR Newport Beach W01'),
#  ('sr:competition:45391', 'UTR Olomouc M01'),
#  ('sr:competition:45427', 'UTR Baton Rouge M01'),
#  ('sr:competition:45431', 'UTR Tucson M01'),
#  ('sr:competition:45437', 'UTR Noda M01'),
#  ('sr:competition:45963', 'UTR Tigre M02'),
#  ('sr:competition:45471', 'Winston-Salem M01'),
#  ('sr:competition:45473', 'UTR Cornella de Llobregat M02'),
#  ('sr:competition:45475', 'UTR Baton Rogue W01'),
#  ('sr:competition:45477', 'UTR Noda W01'),
#  ('sr:competition:45479', 'Winston-Salem W01'),
#  ('sr:competition:45481', 'UTR Newport Beach W02'),
#  ('sr:competition:45483', 'UTR Cornella de Llobregat W01'),
#  ('sr:competition:45493', 'UTR Boca Raton M01'),
#  ('sr:competition:45495', 'UTR Noda M02'),
#  ('sr:competition:45497', 'UTR Blagoevgrad M01'),
#  ('sr:competition:45499', 'UTR Newport Beach M01'),
#  ('sr:competition:45501', 'UTR Cornella de Llobregat W02'),
#  ('sr:competition:45505', 'UTR Bonita Springs W01'),
#  ('sr:competition:45595', 'UTR Noda W02'),
#  ('sr:competition:45635', 'UTR Olomouc M02'),
#  ('sr:competition:45637', 'UTR Alvor M01'),
#  ('sr:competition:45639', 'UTR Boca Raton M02'),
#  ('sr:competition:45643', 'UTR Bloomington M01'),
#  ('sr:competition:45651', 'UTR Dubai W01'),
#  ('sr:competition:45657', 'UTR Blagoevgrad W01'),
#  ('sr:competition:45659', 'UTR Boca Raton W02'),
#  ('sr:competition:45661', 'UTR Newport Beach W04'),
#  ('sr:competition:45747', 'UTR Yokohama M01'),
#  ('sr:competition:45753', 'UTR Gyor M01'),
#  ('sr:competition:45755', 'UTR Alvor M02'),
#  ('sr:competition:45757', 'UTR Newport Beach M02'),
#  ('sr:competition:45761', 'UTR Yokohama W01'),
#  ('sr:competition:45763', 'UTR Dubai W02'),
#  ('sr:competition:45835', 'UTR Yokohama M02'),
#  ('sr:competition:45837', 'UTR Dubai M01'),
#  ('sr:competition:45839', 'UTR Blagoevgrad M02'),
#  ('sr:competition:45841', 'UTR Cornella de Llobregat M03'),
#  ('sr:competition:45843', 'UTR Berkeley M01'),
#  ('sr:competition:45845', 'UTR Yokohama W02'),
#  ('sr:competition:45847', 'UTR Cornella de Llobregat W03'),
#  ('sr:competition:45849', 'UTR Pancevo W01'),
#  ('sr:competition:45889', 'UTR Dubai M02'),
#  ('sr:competition:45891', 'UTR Olomouc M03'),
#  ('sr:competition:45893', 'UTR Tigre M01'),
#  ('sr:competition:45895', 'UTR Spring M01'),
#  ('sr:competition:45897', 'UTR Stockton M01'),
#  ('sr:competition:45899', 'UTR Spring W01'),
#  ('sr:competition:45913', 'UTR Bucharest W01'),
#  ('sr:competition:45915', 'UTR Rungsted Kyst W01'),
#  ('sr:competition:45917', 'UTR Tigre W01'),
#  ('sr:competition:45959', 'UTR Kawaguchi M01'),
#  ('sr:competition:45961', 'UTR Bucharest M01'),
#  ('sr:competition:45965', 'UTR Kawaguchi W01'),
#  ('sr:competition:45967', 'UTR Olomouc W02'),
#  ('sr:competition:45969', 'UTR Tigre W02'),
#  ('sr:competition:45973', 'UTR Newport Beach W05'),
#  ('sr:competition:46017', 'UTR Cardiff M01'),
#  ('sr:competition:46019', 'UTR Zadar M01'),
#  ('sr:competition:46021', 'UTR Boca Raton M03'),
#  ('sr:competition:46023', 'UTR Newport Beach M03'),
#  ('sr:competition:46025', 'UTR Lincoln M01'),
#  ('sr:competition:46027', 'UTR Cardiff W01'),
#  ('sr:competition:46029', 'UTR Lawrenceville W01'),
#  ('sr:competition:46031', 'UTR Dubai W03'),
#  ('sr:competition:46033', 'UTR Zadar W01'),
#  ('sr:competition:46123', 'UTR Yokohama M03'),
#  ('sr:competition:46125', 'UTR Blagoevgrad M03'),
#  ('sr:competition:46127', 'UTR Lawrenceville M01'),
#  ('sr:competition:46129', 'UTR Yokohama W03'),
#  ('sr:competition:46131', 'UTR Dubai W04'),
#  ('sr:competition:46135', 'UTR Cornella de Llobregat W04'),
#  ('sr:competition:46137', 'UTR Zadar W02'),
#  ('sr:competition:46139', 'UTR Newport Beach W06'),
#  ('sr:competition:46197', 'UTR Yokohama M04'),
#  ('sr:competition:46199', 'UTR Dubai M03'),
#  ('sr:competition:46201', 'UTR Gyor M02'),
#  ('sr:competition:46203', 'UTR Newport Beach M04'),
#  ('sr:competition:46205', 'UTR Yokohama W04'),
#  ('sr:competition:46209', 'UTR Olomouc W03'),
#  ('sr:competition:46213', 'UTR Boca Raton W04'),
#  ('sr:competition:46241', 'UTR Dubai M04'),
#  ('sr:competition:46243', 'UTR Olomouc M04'),
#  ('sr:competition:46245', 'UTR Lawrenceville M02'),
#  ('sr:competition:46247', 'UTR Manzanillo M01'),
#  ('sr:competition:46249', 'UTR Gyor W01'),
#  ('sr:competition:46251', 'UTR Newport Beach W07'),
#  ('sr:competition:46253', 'UTR Manzanillo W01'),
#  ('sr:competition:46315', 'UTR Sanmin District M01'),
#  ('sr:competition:46317', 'UTR Zadar M02'),
#  ('sr:competition:46319', 'UTR Boca Raton M04'),
#  ('sr:competition:46321', 'UTR Manzanillo M02'),
#  ('sr:competition:46323', 'UTR Roseto degli Abruzzi W01'),
#  ('sr:competition:46325', 'UTR Sanmin District W01'),
#  ('sr:competition:46327', 'UTR Zadar W03'),
#  ('sr:competition:46329', 'UTR Manzanillo W02'),
#  ('sr:competition:46411', 'UTR Melbourne M01'),
#  ('sr:competition:46413', 'UTR Belgrade M01'),
#  ('sr:competition:46415', 'UTR Alvor M03'),
#  ('sr:competition:46417', 'UTR Cordoba M01'),
#  ('sr:competition:46419', 'UTR Melbourne W01'),
#  ('sr:competition:46421', 'UTR Belgrade W01'),
#  ('sr:competition:46423', 'UTR Alvor W01'),
#  ('sr:competition:46425', 'UTR Cordoba W01'),
#  ('sr:competition:46427', 'UTR Boca Raton W06'),
#  ('sr:competition:46429', 'UTR Newport Beach W08'),
#  ('sr:competition:46589', 'UTR Melbourne M02'),
#  ('sr:competition:46591', 'UTR Belgrade M02'),
#  ('sr:competition:46593', 'UTR Carvoeiro M01'),
#  ('sr:competition:46595', 'UTR Newport Beach M05'),
#  ('sr:competition:46597', 'UTR Cordoba M02'),
#  ('sr:competition:46599', 'UTR Spring M02'),
#  ('sr:competition:46603', 'UTR Melbourne W02'),
#  ('sr:competition:46609', 'UTR Belgrade W02'),
#  ('sr:competition:46611', 'UTR Carvoeiro W01'),
#  ('sr:competition:46677', 'UTR Lawrenceville M03'),
#  ('sr:competition:46679', 'UTR Gyor M03'),
#  ('sr:competition:46681', 'UTR Loughborough M01'),
#  ('sr:competition:46693', 'UTR Lawrenceville W02'),
#  ('sr:competition:46697', 'UTR Gyor W02'),
#  ('sr:competition:46699', 'UTR Loughborough W01'),
#  ('sr:competition:46701', 'UTR Newport Beach W09'),
#  ('sr:competition:46726', 'UTR Kawaguchi M02'),
#  ('sr:competition:46728', 'UTR Manzanillo M03'),
#  ('sr:competition:46730', 'UTR College Station M01'),
#  ('sr:competition:46732', 'UTR Kawaguchi W02'),
#  ('sr:competition:46734', 'UTR Bucharest W02'),
#  ('sr:competition:46789', 'UTR Kawaguchi M03'),
#  ('sr:competition:46791', 'UTR Bucharest M02'),
#  ('sr:competition:46793', 'UTR Maria Lanzendorf M01'),
#  ('sr:competition:46795', 'UTR Newport Beach M06'),
#  ('sr:competition:46797', 'UTR Manzanillo M04'),
#  ('sr:competition:46799', 'UTR Kawaguchi W03'),
#  ('sr:competition:46801', 'UTR Bucharest W03'),
#  ('sr:competition:46823', 'UTR Melbourne M03'),
#  ('sr:competition:46825', 'UTR Skopje M01'),
#  ('sr:competition:46827', 'UTR Carvoeiro M02'),
#  ('sr:competition:46829', 'UTR Boca Raton M05'),
#  ('sr:competition:46831', 'UTR Stockton M02'),
#  ('sr:competition:46835', 'UTR Melbourne W03'),
#  ('sr:competition:46837', 'UTR Maria Lanzendorf W01'),
#  ('sr:competition:46839', 'UTR Carvoeiro W02'),
#  ('sr:competition:46841', 'UTR Stockton W01'),
#  ('sr:competition:46889', 'UTR Melbourne M04'),
#  ('sr:competition:46891', 'UTR Carvoeiro M03'),
#  ('sr:competition:46901', 'UTR Newport Beach M07'),
#  ('sr:competition:46903', 'UTR Boca Raton W07'),
#  ('sr:competition:46905', 'UTR Melbourne W04'),
#  ('sr:competition:46907', 'UTR Carvoeiro W03'),
#  ('sr:competition:46983', 'UTR Boca Raton M06'),
#  ('sr:competition:46985', 'UTR Urayasu M01'),
#  ('sr:competition:46987', 'UTR Pazardzhik M01'),
#  ('sr:competition:46989', 'UTR Budapest M01'),
#  ('sr:competition:46991', 'UTR Urbana M01'),
#  ('sr:competition:46993', 'UTR Tuscaloosa M01'),
#  ('sr:competition:46995', 'UTR Pazardzhik W01'),
#  ('sr:competition:46997', 'UTR Budapest W01'),
#  ('sr:competition:46999', 'UTR Urbana W01')]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#            competition_id                   competition_name
# 0      sr:competition:620                         Hopman Cup
# 1      sr:competition:660                     World Team Cup
# 2     sr:competition:1207  Championship International Series
# 3     sr:competition:2100                          Davis Cup
# 4     sr:competition:2102               Billie Jean King Cup
# ..                    ...                                ...
# 199  sr:competition:46991                     UTR Urbana M01
# 200  sr:competition:46993                 UTR Tuscaloosa M01
# 201  sr:competition:46995                 UTR Pazardzhik W01
# 202  sr:competition:46997                   UTR Budapest W01
# 203  sr:competition:46999                     UTR Urbana W01
#
# [204 rows x 2 columns]

# %% [markdown]
# --COMPLEXES:

# %% [markdown]
# 1)	List all venues along with their associated complex name

# %%
sql_query = """Select comp.complex_name, 
venue.venue_id,venue.venue_name,venue.venue_city_name,venue.venue_country_name,venue.venue_country_code,
venue.venue_timezone from complexes_table comp inner join venues_table venue on comp.complex_id = venue.complex_id"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('Nacional',
#   'sr:venue:70045',
#   'Cancha Central',
#   'Santiago',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('Estadio de la Cartuja',
#   'sr:venue:74858',
#   'Court One',
#   'Seville',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Sibur Arena',
#   'sr:venue:62153',
#   'TC Dynamo',
#   'Saint Petersburg',
#   'Russia',
#   'RUS',
#   'Europe/Moscow'),
#  ('O2 Arena',
#   'sr:venue:77437',
#   'Campo 8',
#   'Oeiras',
#   'Portugal',
#   'PRT',
#   'Europe/Lisbon'),
#  ('Ostravar Arena',
#   'sr:venue:55223',
#   'Court 2',
#   'Ostrava',
#   'Czechia',
#   'CZE',
#   'Europe/Prague'),
#  ('Varazdin Arena',
#   'sr:venue:77285',
#   'Table 8',
#   'Varazdin',
#   'Croatia',
#   'HRV',
#   'Europe/Zagreb'),
#  ('Palais des sports de Pau',
#   'sr:venue:39934',
#   'Court 3',
#   'Montpellier',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Stade Pierre-de-Coubertin',
#   'sr:venue:74197',
#   'Court 1',
#   'Orleans',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Arena Gripe',
#   'sr:venue:72571',
#   'Pista 4',
#   'Malaga',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Arena Armeets Sofia',
#   'sr:venue:23356',
#   'Court 2',
#   'Sofia',
#   'Bulgaria',
#   'BGR',
#   'Europe/Sofia'),
#  ('Kindarena',
#   'sr:venue:74546',
#   'Court 1',
#   'Rouen',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Estadio German Becker',
#   'sr:venue:67863',
#   'Cancha 3',
#   'Temuco',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('Palais des sports de Gerland',
#   'sr:venue:58692',
#   'Court 12',
#   'Lyon',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Palais Des Sport',
#   'sr:venue:70603',
#   'Court 2',
#   'Orleans',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Palasport',
#   'sr:venue:68097',
#   'Campo Arpex',
#   'Andria',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Salle Steredenn',
#   'sr:venue:80523',
#   'Court TCSB',
#   'Saint-Brieuc',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Garanti Koza Arena',
#   'sr:venue:14874',
#   'Court Limak Enerji',
#   'Istanbul',
#   'Turkiye',
#   'TUR',
#   'Europe/Istanbul'),
#  ("Poliesportiu d'Andorra",
#   'sr:venue:77413',
#   'Court 2',
#   'Stuttgart',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Rotterdam Ahoy',
#   'sr:venue:22854',
#   'Centre Court',
#   'Rotterdam',
#   'Netherlands',
#   'NLD',
#   'Europe/Brussels'),
#  ('The O2',
#   'sr:venue:66121',
#   'Centre Court',
#   'London',
#   'England',
#   'ENG',
#   'Europe/London'),
#  ('Shlomo Group Arena',
#   'sr:venue:39717',
#   'Court 1',
#   'Bol',
#   'Croatia',
#   'HRV',
#   'Europe/Zagreb'),
#  ('Club Sonoma, Estadio Gnp Seguros',
#   'sr:venue:62341',
#   'Court 4',
#   'Monterrey',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Accor Arena',
#   'sr:venue:1522',
#   'Court 2',
#   'Paris',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Stadium Goran Ivanisevic in ITC Stella Maris',
#   'sr:venue:21868',
#   'Next Gen Arena',
#   'Umag',
#   'Croatia',
#   'HRV',
#   'Europe/Zagreb'),
#  ('Roy Emerson Arena',
#   'sr:venue:2461',
#   'Sportzentrum 3',
#   'Gstaad',
#   'Switzerland',
#   'CHE',
#   'Europe/Zurich'),
#  ('Club de Tenis Puente Romano',
#   'sr:venue:62731',
#   'Court 9',
#   'Marbella',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('National Tennis Center',
#   'sr:venue:59164',
#   'Indoor Court 3',
#   'Astana',
#   'Kazakhstan',
#   'KAZ',
#   'Asia/Almaty'),
#  ('Canberra Tennis Centre',
#   'sr:venue:75825',
#   'Court 2',
#   'Canberra',
#   'Australia',
#   'AUS',
#   'Australia/ACT'),
#  ('BT Arena',
#   'sr:venue:59478',
#   'Court 2',
#   'Cluj Napoca',
#   'Romania',
#   'ROU',
#   'Europe/Bucharest'),
#  ('Valletta Cambiaso ASD',
#   'sr:venue:66063',
#   'Campo 2',
#   'Genoa',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Porsche Arena',
#   'sr:venue:77441',
#   'Centre Court',
#   'Stuttgart',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Royal Arena',
#   'sr:venue:73245',
#   'Court 4',
#   'Copenhagen',
#   'Denmark',
#   'DNK',
#   'Europe/Copenhagen'),
#  ('Shenzhen Bay Sports Center',
#   'sr:venue:31955',
#   'Court 8',
#   'Taipei',
#   'Chinese Taipei',
#   'TPE',
#   'Asia/Taipei'),
#  ('Singapore Indoor Stadium',
#   'sr:venue:71443',
#   'Court 4',
#   'Kallang',
#   'Singapore',
#   'SGP',
#   'Asia/Singapore'),
#  ('Palais des Sports de Marseille',
#   'sr:venue:38311',
#   'Court 2',
#   'Marseille',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Caja Magica',
#   'sr:venue:68305',
#   'Court Central',
#   'Madrid',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('All England Lawn Tennis and Croquet Club',
#   'sr:venue:21642',
#   'Court 5',
#   'London',
#   'England',
#   'ENG',
#   'Europe/London'),
#  ('Complexe Al Amal',
#   'sr:venue:39589',
#   'Court Simonne Mathieu',
#   'Paris',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Melbourne Park',
#   'sr:venue:61865',
#   'Kia Arena',
#   'Melbourne',
#   'Australia',
#   'AUS',
#   'Australia/Melbourne'),
#  ('Qi zhong Forest Sports City Arena',
#   'sr:venue:24396',
#   'Indoor 1',
#   'Shanghai',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Clube de Ténis do Estoril',
#   'sr:venue:16760',
#   'Stadium',
#   'Winston Salem, NC',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('The Drive',
#   'sr:venue:61851',
#   'Centre Court',
#   'Adelaide',
#   'Australia',
#   'AUS',
#   'Australia/South'),
#  ('Atlantic Station',
#   'sr:venue:8563',
#   'AJC Grandstand Court',
#   'Atlanta, GA',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('International Tennis Hall of Fame',
#   'sr:venue:21866',
#   'Center 2',
#   'Newport, Rhode Island',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Club Jacaranda Cumbaya',
#   'sr:venue:64227',
#   'Court 13',
#   'Quito',
#   'Ecuador',
#   'ECU',
#   'America/Guayaquil'),
#  ('Hengqin International Tennis Center Zhuhai',
#   'sr:venue:74171',
#   'Center Court',
#   'Zhuhai',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('The Racquet Club of Memphis',
#   'sr:venue:81937',
#   'Court Guillermo Villas',
#   'Buenos Aires',
#   'Argentina',
#   'ARG',
#   'America/Argentina/Buenos_Aires'),
#  ('Delray Beach Tennis Center',
#   'sr:venue:15684',
#   'Court 3',
#   'Delray Beach',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Linzer Sporthalle',
#   'sr:venue:24488',
#   'Stadium',
#   'Luxembourg',
#   'Luxembourg',
#   'LUX',
#   'Europe/Paris'),
#  ('Luzhniki Olympic Complex',
#   'sr:venue:61010',
#   'Court 2',
#   'Moscow',
#   'Russia',
#   'RUS',
#   'Europe/Moscow'),
#  ('Ariake Colosseum',
#   'sr:venue:80457',
#   'Court 9',
#   'Osaka',
#   'Japan',
#   'JPN',
#   'Asia/Tokyo'),
#  ('Optics Valley International Tennis Center',
#   'sr:venue:28986',
#   'Court 7',
#   'Wuhan',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Guangzhou Tianhe Sports Center',
#   'sr:venue:34572',
#   'Court 7',
#   'Guangzhou',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Olympic Park Tennis Center',
#   'sr:venue:26447',
#   'Show Court 1',
#   'Sydney',
#   'Australia',
#   'AUS',
#   'Australia/Sydney'),
#  ('Victoria Park Tennis Court',
#   'sr:venue:31499',
#   'Indoor C2',
#   'Hong Kong',
#   'Hong Kong, China',
#   'HKG',
#   'Asia/Hong_Kong'),
#  ('Tianjin Tuanbo International Tennis Center',
#   'sr:venue:24252',
#   'Indoor 1',
#   'Tianjin',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Tashkent Tennis Centreake',
#   'sr:venue:35102',
#   'Indoor 2',
#   'Tashkent',
#   'Uzbekistan',
#   'UZB',
#   'Asia/Tashkent'),
#  ('China National Tennis Center',
#   'sr:venue:47004',
#   'Diamond',
#   'Beijing',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Utsubo Tennis Center',
#   'sr:venue:73841',
#   'Court 9',
#   'Osaka',
#   'Japan',
#   'JPN',
#   'Asia/Tokyo'),
#  ('Atlanta Athletic Club',
#   'sr:venue:82565',
#   'Court 5',
#   'Copenhagen',
#   'Denmark',
#   'DNK',
#   'Europe/Copenhagen'),
#  ('Baku Tennis Academy',
#   'sr:venue:33528',
#   'Court G',
#   'New Haven, CT',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Sobeys Stadium',
#   'sr:venue:79171',
#   'Cashmere Grandstand',
#   'Toronto, ON',
#   'Canada',
#   'CAN',
#   'Canada/Eastern'),
#  ('Taube Tennis Stadium',
#   'sr:venue:79243',
#   'Court 10',
#   'Cincinnati, OH',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Tennis Club de Strasbourg',
#   'sr:venue:58624',
#   'Indoor Court 1',
#   'Strasbourg',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Edgbaston Priory Club',
#   'sr:venue:18313',
#   'Indoor 6',
#   'Birmingham',
#   'England',
#   'ENG',
#   'Europe/London'),
#  ('Royal Tennis Club de Marrakech',
#   'sr:venue:28719',
#   'Court 9',
#   'Marrakech',
#   'Morocco',
#   'MAR',
#   'Africa/Casablanca'),
#  ('Tennis Club 1.FCN',
#   'sr:venue:18205',
#   'Court 5',
#   'Nuremberg',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Devonshire Park International Tennis Centre',
#   'sr:venue:58830',
#   'Court 12',
#   'Eastbourne',
#   'England',
#   'ENG',
#   'Europe/London'),
#  ('Club Campestre El Rancho',
#   'sr:venue:72767',
#   'Practice Court 1',
#   'Prague',
#   'Czechia',
#   'CZE',
#   'Europe/Prague'),
#  ('Khalifa International Tennis & Squash Complex',
#   'sr:venue:62259',
#   'Grandstand 4',
#   'Doha',
#   'Qatar',
#   'QAT',
#   'Asia/Qatar'),
#  ('Centre Municipal de Tennis Vall d Hebron',
#   'sr:venue:25938',
#   'Court 7',
#   'Monterrey',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Jockey Club Brasileiro',
#   'sr:venue:66903',
#   'Central',
#   'Rio de Janeiro',
#   'Brazil',
#   'BRA',
#   'Brazil/East'),
#  ('Tennis Center at Crandon Park',
#   'sr:venue:11388',
#   'Cancha 5',
#   'Acapulco',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Club Avantage Multi-Sports',
#   'sr:venue:58736',
#   'Court 20',
#   'Madrid',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('SKT Sopot',
#   'sr:venue:38886',
#   'Althea Gibson Club Court',
#   'Charleston, SC',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('St. Jakobshalle Basel',
#   'sr:venue:70493',
#   'Court 6',
#   'Basel',
#   'Switzerland',
#   'CHE',
#   'Europe/Zurich'),
#  ('Emirates Arena',
#   'sr:venue:1325',
#   'Grandstand',
#   'New York, NY',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('OMNI LA COSTA RESORT & SPA',
#   'sr:venue:17522',
#   'Court 3',
#   'Bangkok',
#   'Thailand',
#   'THA',
#   'Asia/Bangkok'),
#  ('NSW Tennis Centre',
#   'sr:venue:24824',
#   'Next Gen Court',
#   'Vienna',
#   'Austria',
#   'AUT',
#   'Europe/Vienna'),
#  ('Shenzhen Longgang Sports Center',
#   'sr:venue:13308',
#   'Center Court',
#   'Shenzhen',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Queensland Tennis Centre',
#   'sr:venue:80995',
#   'Ct 15',
#   'Brisbane',
#   'Australia',
#   'AUS',
#   'Australia/Brisbane'),
#  ('Am Rothenbaum',
#   'sr:venue:53557',
#   'Head Gravity Court',
#   'Hamburg',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Kungliga Tennishallen',
#   'sr:venue:61435',
#   'ShowCourt',
#   'Stockholm',
#   'Sweden',
#   'SWE',
#   'Europe/Stockholm'),
#  ('The Queens Club',
#   'sr:venue:78887',
#   'Court Stadtwerke',
#   'Kitzbuhel',
#   'Austria',
#   'AUT',
#   'Europe/Vienna'),
#  ('Gerry Weber Stadium',
#   'sr:venue:30715',
#   'Stadion',
#   'Halle',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Nottingham Tennis Centre',
#   'sr:venue:58776',
#   'Indoor 3',
#   'Nottingham',
#   'England',
#   'ENG',
#   'Europe/London'),
#  ('Nice Lawn Tennis Club',
#   'sr:venue:21874',
#   'Centre Court',
#   'Bastad',
#   'Sweden',
#   'SWE',
#   'Europe/Stockholm'),
#  ('Country Time Club',
#   'sr:venue:52597',
#   'Court 12',
#   'Palermo',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Tennis Club Weissenhof',
#   'sr:venue:16173',
#   'Court 4',
#   'Geneva',
#   'Switzerland',
#   'CHE',
#   'Europe/Zurich'),
#  ('Autotron Rosmalen',
#   'sr:venue:1896',
#   'Court 4',
#   "'s-Hertogenbosch",
#   'Netherlands',
#   'NLD',
#   'Europe/Brussels'),
#  ('BNR arena',
#   'sr:venue:22948',
#   'Court 9',
#   'Bucharest',
#   'Romania',
#   'ROU',
#   'Europe/Bucharest'),
#  ('MTTC Iphitos e.V.',
#   'sr:venue:16065',
#   'Court 2',
#   'Munich',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Real Club de Tenis Barcelona',
#   'sr:venue:70759',
#   'Pista Andres Gimeno',
#   'Barcelona',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Lanxess Arena',
#   'sr:venue:55021',
#   'MKG 2',
#   'Cologne',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Nemzeti Edzes Kozpont',
#   'sr:venue:34228',
#   'Indoor Court 19',
#   'Hiroshima',
#   'Japan',
#   'JPN',
#   'Asia/Tokyo'),
#  ('Lyon Tennis Club',
#   'sr:venue:58712',
#   'Court 23',
#   'Lyon',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Sichuan International Tennis Center',
#   'sr:venue:34608',
#   'Center Court',
#   'Chengdu',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Tiburon Peninsula Club',
#   'sr:venue:80217',
#   'Backer Mckenzie',
#   'Tiburon',
#   'USA',
#   'USA',
#   'America/Los_Angeles'),
#  ('Country Club de Bogota',
#   'sr:venue:82271',
#   'Cancha Central',
#   'Bogota',
#   'Colombia',
#   'COL',
#   'America/Bogota'),
#  ('Rochusclub',
#   'sr:venue:38279',
#   'Swiss Tennis Arena',
#   'Biel',
#   'Switzerland',
#   'CHE',
#   'Europe/Zurich'),
#  ('Shenzhen Luohu Tennis Centre',
#   'sr:venue:74652',
#   'Centre Court',
#   'Shenzhen',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Yang-Ming Tennis Centre',
#   'sr:venue:82221',
#   'Yang-Ming Tennis Center - Court 8',
#   'Kaohsiung',
#   'Chinese Taipei',
#   'TPE',
#   'Asia/Taipei'),
#  ("Ligue d'Alsace de Tennis",
#   'sr:venue:22362',
#   'Court A',
#   'Portoroz',
#   'Slovenia',
#   'SVN',
#   'Europe/Ljubljana'),
#  ('The Tennis Center at College Park',
#   'sr:venue:64279',
#   'Grandstand',
#   'Mallorca',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Tennis Center Novak',
#   'sr:venue:58524',
#   'Practice Court 1',
#   'Belgrade',
#   'Serbia',
#   'SRB',
#   'Europe/Belgrade'),
#  ('Almaty Tennis Center',
#   'sr:venue:24082',
#   'Indoor 2',
#   'Almaty',
#   'Kazakhstan',
#   'KAZ',
#   'Asia/Almaty'),
#  ('Sociedade Hipica de Campinas',
#   'sr:venue:66743',
#   'Indoors',
#   'Campinas',
#   'Brazil',
#   'BRA',
#   'Brazil/East'),
#  ('Warszawianka Tennis Centre',
#   'sr:venue:77739',
#   'Court 3',
#   'Prague',
#   'Czechia',
#   'CZE',
#   'Europe/Prague'),
#  ('Amelia Island Plantation Resort',
#   'sr:venue:58758',
#   'Steffi Graf Stadion',
#   'Berlin',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Impact Arena',
#   'sr:venue:78749',
#   'Grand Court',
#   'Budapest',
#   'Hungary',
#   'HUN',
#   'Europe/Budapest'),
#  ('Tokyo Metropolitan Gymnasium',
#   'sr:venue:48783',
#   'Table 1',
#   'Tokyo',
#   'Japan',
#   'JPN',
#   'Asia/Tokyo'),
#  ('Pörtschach Werzer Arena',
#   'sr:venue:80329',
#   'Pista Pablo Andujar',
#   'Valencia',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Circolo del Tennis Firenze 1898',
#   'sr:venue:81935',
#   'Eve Zimmerman Tennis Center - Court 3',
#   'Stockton, CA',
#   'USA',
#   'USA',
#   'America/Los_Angeles'),
#  ('Sanchez-Casal Tennis Academy',
#   'sr:venue:60714',
#   'Pista 2',
#   'Barcelona',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Baku Tennis Academy',
#   'sr:venue:35806',
#   'Court 5',
#   'Vina del Mar',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('Solano Community College Tennis Center',
#   'sr:venue:79245',
#   'Estadio Brugal',
#   'Santo Domingo',
#   'Dominican Republic',
#   'DOM',
#   'America/Santo_Domingo'),
#  ('Lotto Arena',
#   'sr:venue:24318',
#   'Court 3',
#   'Antwerp',
#   'Belgium',
#   'BEL',
#   'Europe/Brussels'),
#  ('TC Ismaning',
#   'sr:venue:61257',
#   'Court 1',
#   'Ismaning',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Osten & Victor Alberta Tennis Centre',
#   'sr:venue:67609',
#   'Rogers Court',
#   'Calgary',
#   'Canada',
#   'CAN',
#   'America/Edmonton'),
#  ('Ningbo Tennis Center of WTA Ningbo, China w42',
#   'sr:venue:80661',
#   'Indoor court 9',
#   'Ningbo',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Club Tennis Las Terrazas de Miraflores',
#   'sr:venue:35080',
#   'Court 17',
#   'Lima',
#   'Peru',
#   'PER',
#   'America/Lima'),
#  ('Shree Shiv Chhatrapati Sports Complex',
#   'sr:venue:47508',
#   'Court 5',
#   'Liuzhou',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ("The Boar's Head Sports Club",
#   'sr:venue:35514',
#   'Brenda Meyers Court',
#   'Charlottesville, VA',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('AXA Arena NTC',
#   'sr:venue:56292',
#   'Court 10',
#   'Guayaquil',
#   'Ecuador',
#   'ECU',
#   'America/Guayaquil'),
#  ('Vendéspace',
#   'sr:venue:15294',
#   'Court Annexe',
#   'Mouilleron-le-Captif',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Carrasco Lawn Tennis Club',
#   'sr:venue:15387',
#   'Cancha 15',
#   'Montevideo',
#   'Uruguay',
#   'URY',
#   'America/Montevideo'),
#  ('Goodfriend Indoor Tennis Center',
#   'sr:venue:61463',
#   'Stadium',
#   'Knoxville, TN',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Palais des sports de Beaublanc',
#   'sr:venue:17280',
#   'Court 2',
#   'Limoges',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Miki Disaster Management Park',
#   'sr:venue:67729',
#   'Court C',
#   'Kobe',
#   'Japan',
#   'JPN',
#   'Asia/Tokyo'),
#  ('Karnataka State Lawn Tennis Association',
#   'sr:venue:33464',
#   'KSLTA Signature - Kingfisher Stadium',
#   'Bangalore',
#   'India',
#   'IND',
#   'Asia/Kolkata'),
#  ('Racket Club, Argentina',
#   'sr:venue:74526',
#   'Cancha 7',
#   'Buenos Aires',
#   'Argentina',
#   'ARG',
#   'America/Argentina/Buenos_Aires'),
#  ('Atkins Tennis Center',
#   'sr:venue:81021',
#   'The Goldenberg Court',
#   'Champaign, IL',
#   'USA',
#   'USA',
#   'America/Chicago'),
#  ('Rice Stadium (Brian Patterson Sports Performance Center)',
#   'sr:venue:35912',
#   'Indoor 2',
#   'Houston, TX',
#   'USA',
#   'USA',
#   'America/Chicago'),
#  ('Mhalunge Balewadi Tennis Complex',
#   'sr:venue:36371',
#   'Court 5',
#   'Pune',
#   'India',
#   'IND',
#   'Asia/Kolkata'),
#  ('Palazzetto dello Sport',
#   'sr:venue:15373',
#   'Via Delle Querce',
#   'Andria',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('ASB Tennis Arena',
#   'sr:venue:81619',
#   'Indoor 6',
#   'Auckland',
#   'New Zealand',
#   'NZL',
#   'Pacific/Auckland'),
#  ('Domain Tennis Centre',
#   'sr:venue:26481',
#   'West Court',
#   'Hobart',
#   'Australia',
#   'AUS',
#   'Australia/Tasmania'),
#  ('Ohio State Varsity Tennis Center',
#   'sr:venue:39862',
#   'Indoor Court 1',
#   'Columbus, OH',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('EPG Arena',
#   'sr:venue:81777',
#   'Centre Court',
#   'Koblenz',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Newport Beach Tennis Club',
#   'sr:venue:50251',
#   'Court 8',
#   'Newport Beach',
#   'USA',
#   'USA',
#   'America/Los_Angeles'),
#  ('Burnie Tennis Club',
#   'sr:venue:35960',
#   'West Park Oval',
#   'Burnie',
#   'Australia',
#   'AUS',
#   'Australia/Tasmania'),
#  ('Israel Tennis Center',
#   'sr:venue:80157',
#   'Indoor 3',
#   'Lisbon',
#   'Portugal',
#   'PRT',
#   'Europe/Lisbon'),
#  ('Francoise Savatier',
#   'sr:venue:36789',
#   'Cancha 3',
#   'Punta del Este',
#   'Uruguay',
#   'URY',
#   'America/Montevideo'),
#  ('True Arena Hua Hin',
#   'sr:venue:26741',
#   'Tennis Club De Bruz 5',
#   'Rennes',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Launceston Regional Tennis Centre',
#   'sr:venue:27033',
#   'Court 8',
#   'Launceston',
#   'Australia',
#   'AUS',
#   'Australia/Tasmania'),
#  ('True Arena Hua Hin',
#   'sr:venue:25372',
#   'Court 1',
#   'Hua Hin',
#   'Thailand',
#   'THA',
#   'Asia/Bangkok'),
#  ('Parc des Expositions Quimper Cornouaille',
#   'sr:venue:81737',
#   'Court Fred Le Bian',
#   'Quimper',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Cleveland Racquet Club',
#   'sr:venue:76147',
#   'Stadium',
#   'Cleveland, OH',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Sud de France Arena',
#   'sr:venue:80699',
#   'Infinity Arena',
#   'Montpellier',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Estadio Mario Alberto Kempes',
#   'sr:venue:29878',
#   'Cancha 3',
#   'Cordoba',
#   'Argentina',
#   'ARG',
#   'America/Argentina/Cordoba'),
#  ('T Bar M Racquet Club',
#   'sr:venue:17754',
#   'Court 2',
#   'Dallas, TX',
#   'USA',
#   'USA',
#   'America/Chicago'),
#  ('SYMA Sports and Conference Centre',
#   'sr:venue:19517',
#   'Temesvari Court',
#   'Budapest',
#   'Hungary',
#   'HUN',
#   'Europe/Budapest'),
#  ('SDAT Tennis Stadium',
#   'sr:venue:15481',
#   'Court 4',
#   'Chennai',
#   'India',
#   'IND',
#   'Asia/Kolkata'),
#  ('Club Campestre Sede Llanogrande',
#   'sr:venue:72027',
#   'Cancha 3',
#   'Medellin',
#   'Colombia',
#   'COL',
#   'America/Bogota'),
#  ('Complexe Sportif Chantereyne',
#   'sr:venue:35056',
#   'Court 5',
#   'Cherbourg-Octeville',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Dubai Duty Free Tennis Stadium',
#   'sr:venue:1674',
#   'Court 2',
#   'Dubai',
#   'United Arab Emirates',
#   'ARE',
#   'Asia/Dubai'),
#  ('Hotel Racquet Cuernavaca',
#   'sr:venue:82291',
#   'Cancha 2',
#   'Morelos',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Indian Wells Tennis Garden',
#   'sr:venue:76087',
#   'PC2',
#   'Indian Wells',
#   'USA',
#   'USA',
#   'America/Los_Angeles'),
#  ('Mamushidani Tennis Courts, Keio University',
#   'sr:venue:81289',
#   'Indoors 2',
#   'Yokohama',
#   'Japan',
#   'JPN',
#   'Asia/Tokyo'),
#  ('Manquehue Sports Club',
#   'sr:venue:62269',
#   'Court 3',
#   'Pau',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('The Phoenix Country Club',
#   'sr:venue:27991',
#   'Court 11',
#   'Shenzhen',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('The Phoenix Country Club',
#   'sr:venue:62521',
#   'Court 1',
#   'Phoenix, AZ',
#   'USA',
#   'USA',
#   'America/Phoenix'),
#  ('Hard Rock Stadium',
#   'sr:venue:38772',
#   'Butch Buchholz',
#   'Miami, FL',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Centro Panamericano de Tenis',
#   'sr:venue:66869',
#   'Grandstand Caliente',
#   'Guadalajara',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Club Los Lagartos',
#   'sr:venue:18037',
#   'Campo Estadio',
#   'Bogota',
#   'Colombia',
#   'COL',
#   'America/Bogota'),
#  ('TK Sparta Praha',
#   'sr:venue:78885',
#   'Court 14',
#   'Prague',
#   'Czechia',
#   'CZE',
#   'Europe/Prague'),
#  ('Hot Springs Tennis Center',
#   'sr:venue:36527',
#   'Court 8',
#   'An-Ning',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Club des Cheminots',
#   'sr:venue:18135',
#   'Court 3',
#   'Rabat',
#   'Morocco',
#   'MAR',
#   'Africa/Casablanca'),
#  ('Tennis Club Kastela',
#   'sr:venue:30621',
#   'Court 3',
#   'Madrid',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('River Oaks Country Club',
#   'sr:venue:46548',
#   'Court 11',
#   'Houston, TX',
#   'USA',
#   'USA',
#   'America/Chicago'),
#  ('National Tennis Center',
#   'sr:venue:31329',
#   'Court 3',
#   'Budapest',
#   'Hungary',
#   'HUN',
#   'Europe/Budapest'),
#  ('Clube de Ténis do Estoril',
#   'sr:venue:70599',
#   'Court CTE',
#   'Estoril',
#   'Portugal',
#   'PRT',
#   'Europe/Lisbon'),
#  ("Parc De La TeTe D'or",
#   'sr:venue:21570',
#   'Court 3',
#   'Lyon',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('TC Weissenhof, Stuttgart',
#   'sr:venue:71581',
#   'Colosseum',
#   'Stuttgart',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ("The Queen's Club",
#   'sr:venue:71757',
#   'Court 10',
#   'London',
#   'England',
#   'ENG',
#   'Europe/London'),
#  ('Kaya Palazzo Belek',
#   'sr:venue:21714',
#   'Duygu Aksit Oal',
#   'Antalya',
#   'Turkiye',
#   'TUR',
#   'Europe/Istanbul'),
#  ('Complejo Polideportivo de Cuidad Merliot',
#   'sr:venue:38734',
#   'Court 1',
#   'Lille',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('JC Ferrero Equelite Sport Academy',
#   'sr:venue:74276',
#   'Pista Carlos Alcaraz',
#   'Alicante',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Mouratoglou Tennis Academy',
#   'sr:venue:38984',
#   'Indoor 1',
#   'Sophia Antipolis',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('National Taiwan University Sports Center',
#   'sr:venue:26891',
#   'Stadium',
#   'Taipei',
#   'Chinese Taipei',
#   'TPE',
#   'Asia/Taipei'),
#  ('Circolo Tennis Barletta',
#   'sr:venue:18049',
#   'Altitud (C2)',
#   'Barletta',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Murcia Tennis Club 1919',
#   'sr:venue:62889',
#   'Pista 4',
#   'Murcia',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('El Club el Carmel',
#   'sr:venue:61098',
#   'Grandstand',
#   'Bogota',
#   'Colombia',
#   'COL',
#   'America/Bogota'),
#  ('Laurel Oak Country Club',
#   'sr:venue:17590',
#   'Ed Smith Stadium',
#   'Sarasota',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Club Deportivo Potosino',
#   'sr:venue:82384',
#   'Grandstand',
#   'San Luis de Potosi',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Au Tennis Club De Tunis',
#   'sr:venue:71123',
#   'Court 6',
#   'Tunis',
#   'Tunisia',
#   'TUN',
#   'Africa/Tunis'),
#  ('Tali Tennis Center',
#   'sr:venue:32874',
#   'Court 6',
#   'Helsinki',
#   'Finland',
#   'FIN',
#   'Europe/Helsinki'),
#  ('Jinwol International Tennis Court',
#   'sr:venue:77415',
#   'Court 8',
#   'Gwangju',
#   'Republic of Korea',
#   'KOR',
#   'Asia/Seoul'),
#  ('Tennis Club Dinamo',
#   'sr:venue:14038',
#   'Court 4',
#   'Samarkand',
#   'Uzbekistan',
#   'UZB',
#   'Asia/Tashkent'),
#  ('Tennisclub Heilbronn am Trappensee',
#   'sr:venue:29526',
#   'Court 4',
#   'Heilbronn',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Fitzerald Tennis Center Rock Creek Park',
#   'sr:venue:43938',
#   'Court 5',
#   'Washington, D.C.',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Delmar International School',
#   'sr:venue:32315',
#   'Estadio Pegaso',
#   'Los Cabos',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('National Tennis Centre Lielupe',
#   'sr:venue:42902',
#   'Court 2',
#   'Lausanne',
#   'Switzerland',
#   'CHE',
#   'Europe/Zurich'),
#  ('TC Rüppurr',
#   'sr:venue:78561',
#   'Court 2',
#   'Karlsruhe',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('San José State University Tennis Center',
#   'sr:venue:65219',
#   'Court 3',
#   'San Jose, CA',
#   'USA',
#   'USA',
#   'America/Los_Angeles'),
#  ('Stade Iga',
#   'sr:venue:2028',
#   'Court Central',
#   'Montreal, QC',
#   'Canada',
#   'CAN',
#   'America/Toronto'),
#  ('Palexpo',
#   'sr:venue:78117',
#   'Indoor 6',
#   'Vicenza',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Club de Campo Villa de Madrid',
#   'sr:venue:82325',
#   'Pista Mercedes-Benz',
#   'Madrid',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Istiklol Tennis Club',
#   'sr:venue:30675',
#   'Court 7',
#   'Fergana',
#   'Uzbekistan',
#   'UZB',
#   'Asia/Tashkent'),
#  ('AAJB Tennis',
#   'sr:venue:78389',
#   'Indoor 5',
#   'Blois',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Tenis Club Parma',
#   'sr:venue:77901',
#   'Court 2',
#   'Parma',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Ilkley Lawn Tennis and Squash Club',
#   'sr:venue:71935',
#   'Indoor Court 4',
#   'Ilkley',
#   'England',
#   'ENG',
#   'Europe/London'),
#  ('RT Torax Arena',
#   'sr:venue:32633',
#   'Court 10',
#   'Bratislava',
#   'Slovakia',
#   'SVK',
#   'Europe/Bratislava'),
#  ('Aspria Harbor Club',
#   'sr:venue:78551',
#   'Court 15',
#   'Milan',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Francesco Guzzini Recanati Tennis Club',
#   'sr:venue:40792',
#   'Court 2',
#   'Recanati',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Cary Leeds Center for Tennis & Learning',
#   'sr:venue:65879',
#   'Court 6',
#   'New York, NY',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('National Sport Center Nanchang',
#   'sr:venue:38443',
#   'CC',
#   'Nanchang',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Center Plains Tennis Center',
#   'sr:venue:28711',
#   'Court 12',
#   'Zhengzhou',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Les Arenes de Metz',
#   'sr:venue:44132',
#   'Court 2',
#   'Metz',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Ariake Tennis Forest Park Ariake Colesseum',
#   'sr:venue:80733',
#   'Indoor 6',
#   'Tokyo',
#   'Japan',
#   'JPN',
#   'Asia/Tokyo'),
#  ('Qi Zhong Tennis Center',
#   'sr:venue:80371',
#   'Indoor A3',
#   'Shanghai',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Olympic Tennis Courts',
#   'sr:venue:9485',
#   'Court 12',
#   'Seoul',
#   'Republic of Korea',
#   'KOR',
#   'Asia/Seoul'),
#  ('Olympic Tennis School',
#   'sr:venue:2085',
#   'Court 2',
#   'Tashkent',
#   'Uzbekistan',
#   'UZB',
#   'Asia/Tashkent'),
#  ('Hakons Hall',
#   'sr:venue:72873',
#   'Serena Maniva Centre',
#   'Cordenons',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('National Tennis Center',
#   'sr:venue:33578',
#   'Capital Group Diamond',
#   'Beijing',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Palais des Sports',
#   'sr:venue:15054',
#   'La Foret 1',
#   'Orleans',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Circolo del Tennis Firenze 1898',
#   'sr:venue:34868',
#   'Grandstand',
#   'Florence',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Tips Arena Linz',
#   'sr:venue:35086',
#   'Show Court',
#   'Linz',
#   'Austria',
#   'AUT',
#   'Europe/Vienna'),
#  ('Solano Community College',
#   'sr:venue:74536',
#   'Tad Taube Court',
#   'Fairfield, CT',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Ice Palace Krylatskoye',
#   'sr:venue:949',
#   'Luzhniki Stadium',
#   'Moscow',
#   'Russia',
#   'RUS',
#   'Europe/Moscow'),
#  ('DTB-Stutzpunkt',
#   'sr:venue:24342',
#   'Court 4',
#   'Ismaning',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Playford City Tennis Centre',
#   'sr:venue:26353',
#   'Court 5',
#   'Playford City',
#   'Australia',
#   'AUS',
#   'Australia/Adelaide'),
#  ('House of Sports',
#   'sr:venue:25170',
#   'Court 2',
#   'Eckental',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Guayaquil Tennis Club',
#   'sr:venue:44702',
#   'Cancha 3',
#   'Guayaquil',
#   'Ecuador',
#   'ECU',
#   'America/Guayaquil'),
#  ('Tennis Center, Roncaddizza',
#   'sr:venue:48601',
#   'Allianz Cloud Court',
#   'Milan',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Complexo Municipal de Tenis da Maia',
#   'sr:venue:48957',
#   'Court 4',
#   'Maia',
#   'Portugal',
#   'PRT',
#   'Europe/Lisbon'),
#  ('Stan Sheriff Center',
#   'sr:venue:42104',
#   'Court 9',
#   'Honolulu, HI',
#   'USA',
#   'USA',
#   'Pacific/Honolulu'),
#  ('Bendigo Tennis Centre',
#   'sr:venue:49653',
#   'Court 2',
#   'Canberra',
#   'Australia',
#   'AUS',
#   'Australia/ACT'),
#  ('University of Michigan Varsity Tennis Center',
#   'sr:venue:81579',
#   'Court Hertz',
#   'Noumea',
#   'New Caledonia',
#   'NCL',
#   'Pacific/Noumea'),
#  ('Kooyong Lawn Tennis Club',
#   'sr:venue:49805',
#   'Centre Court',
#   'Melbourne',
#   'Australia',
#   'AUS',
#   'Australia/Melbourne'),
#  ('Club Deportivo Universidad Catolica',
#   'sr:venue:76925',
#   'Court Jaime Fillol',
#   'Santiago',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('Pakistan Sports Complex',
#   'sr:venue:57824',
#   'Campo 2',
#   'Cagliari',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Elite Tennis Club',
#   'sr:venue:57326',
#   'Court 2',
#   'Saint Petersburg',
#   'Russia',
#   'RUS',
#   'Europe/Moscow'),
#  ('Cordoba Lawn Tennis Club',
#   'sr:venue:82061',
#   'Cancha Central',
#   'Cordoba',
#   'Argentina',
#   'ARG',
#   'America/Argentina/Cordoba'),
#  ('Siauliai Tennis Academy',
#   'sr:venue:67281',
#   'Cancha Central',
#   'Santa Cruz de la Sierra',
#   'Bolivia',
#   'BOL',
#   'America/La_Paz'),
#  ('Istanbul Tennis Center',
#   'sr:venue:63225',
#   'Court 3',
#   'Istanbul',
#   'Turkiye',
#   'TUR',
#   'Europe/Istanbul'),
#  ('Tenis Centar Maksimir',
#   'sr:venue:58386',
#   'Court 17',
#   'Zagreb',
#   'Croatia',
#   'HRV',
#   'Europe/Zagreb'),
#  ('Alex Metreveli Tennis Club',
#   'sr:venue:77121',
#   'Cancha 4',
#   'Asuncion',
#   'Paraguay',
#   'PRY',
#   'America/Asuncion'),
#  ('TK Magnet',
#   'sr:venue:52287',
#   'Teren 10',
#   'Zajecar',
#   'Serbia',
#   'SRB',
#   'Europe/Belgrade'),
#  ('COMUNIDAD VALENCIANA',
#   'sr:venue:35798',
#   'Pista 14',
#   'Castellon',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Sparta Prague Tennis Complex',
#   'sr:venue:29542',
#   'Court 9',
#   'Prague',
#   'Czechia',
#   'CZE',
#   'Europe/Prague'),
#  ('National Tennis Centre',
#   'sr:venue:52561',
#   'Center Court',
#   'Roehampton',
#   'England',
#   'ENG',
#   'Europe/London'),
#  ('TOP SEED TENNIS CLUB',
#   'sr:venue:52697',
#   'Center Court',
#   'Lexington, KY',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Henan Provincial Sports Centre Stadium',
#   'sr:venue:74490',
#   'Grandstand',
#   'Zhengzhou',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('TC Bad Homburg',
#   'sr:venue:58802',
#   'Court 2',
#   'Bad Homburg',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Foro Italico',
#   'sr:venue:82507',
#   'Court 15',
#   'Rome',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Forte Village Resort',
#   'sr:venue:55027',
#   'Court 5',
#   'Sardinia',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Limak Arcadia Sport Resort',
#   'sr:venue:56908',
#   'Court 2',
#   'Antalya',
#   'Turkiye',
#   'TUR',
#   'Europe/Istanbul'),
#  ('Zayed Sports City International Tennis Centre',
#   'sr:venue:76201',
#   'ADCB Court 1',
#   'Abu Dhabi',
#   'United Arab Emirates',
#   'ARE',
#   'Asia/Dubai'),
#  ('North-West University Tennis Complex',
#   'sr:venue:51941',
#   'Court 8',
#   'Potchefstroom',
#   'South Africa',
#   'ZAF',
#   'Africa/Johannesburg'),
#  ('Circolo Tennis I Faggi',
#   'sr:venue:57158',
#   'Jocker Court',
#   'Biella',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Club De Campo Bellavista',
#   'sr:venue:57194',
#   'Cancha 2',
#   'Concepcion',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('OCBC Arena',
#   'sr:venue:57250',
#   'Center Court',
#   'Kallang',
#   'Singapore',
#   'SGP',
#   'Asia/Singapore'),
#  ('Halle Tony Garnier',
#   'sr:venue:39775',
#   'Court 12',
#   'Lyon',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('President Tennis Club',
#   'sr:venue:58578',
#   'Court 1',
#   'Parma',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Rebsamen Tennis Center',
#   'sr:venue:39753',
#   'Indoor Ct3',
#   'Little Rock, AR',
#   'USA',
#   'USA',
#   'America/Chicago'),
#  ('Complexo Tenis Monte Aventino',
#   'sr:venue:79055',
#   'Central Eupago',
#   'Porto',
#   'Portugal',
#   'PRT',
#   'Europe/Lisbon'),
#  ('Tennis Club Perugia',
#   'sr:venue:31393',
#   'Center Court',
#   'Perugia',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('TC GM Sports Anif',
#   'sr:venue:59006',
#   'Center Court',
#   'Anif',
#   'Austria',
#   'AUT',
#   'Europe/Vienna'),
#  ('Braunschweiger Tennis und Hockeyclub',
#   'sr:venue:21808',
#   'Court 12',
#   'Braunschweig',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Ciric Sport Base',
#   'sr:venue:65323',
#   'Court 6',
#   'Iasi',
#   'Romania',
#   'ROU',
#   'Europe/Bucharest'),
#  ('Amersfoort Lawn Tennis Club',
#   'sr:venue:59094',
#   'Schoonderbeekbouw Court',
#   'Amersfoort',
#   'Netherlands',
#   'NLD',
#   'Europe/Brussels'),
#  ('Tennis Club Todi 1971',
#   'sr:venue:64667',
#   'Court 4',
#   'Todi',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Arka Tennis Club',
#   'sr:venue:59210',
#   'Court 2',
#   'Gydnia',
#   'Poland',
#   'POL',
#   'Europe/Warsaw'),
#  ('Cabo Sports Complex',
#   'sr:venue:65327',
#   'Stadium CSC',
#   'Los Cabos',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('ATP Stadion Goran Ivanisevic',
#   'sr:venue:78889',
#   'Studenac Arena',
#   'Umag',
#   'Croatia',
#   'HRV',
#   'Europe/Zagreb'),
#  ('Cary Tennis Park',
#   'sr:venue:79205',
#   'Court 10',
#   'Cary, NC',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Tennis Club Triestino',
#   'sr:venue:45558',
#   'Center Court Giorgi',
#   'Trieste',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Tennis Club Triestino',
#   'sr:venue:34046',
#   'Court 9',
#   'Trieste',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Gezira Sporting Club',
#   'sr:venue:79653',
#   'Court 10',
#   'Giza',
#   'Egypt',
#   'EGY',
#   'Africa/Cairo'),
#  ('LTP Tennis Mount Pleasant',
#   'sr:venue:81237',
#   'Court 7',
#   'Charleston, SC',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Adani Arena Rockhampton',
#   'sr:venue:82295',
#   'Sporting 2',
#   'Barletta',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Winners Sports Club',
#   'sr:venue:59634',
#   'Court 2',
#   'Concord, MA',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Liberec Tennis Club',
#   'sr:venue:73095',
#   'INDOOR C',
#   'Liberec',
#   'Czechia',
#   'CZE',
#   'Europe/Prague'),
#  ('Centro Tennis Cassa di Risparmio',
#   'sr:venue:14722',
#   'Court 3',
#   'San Marino',
#   'San Marino',
#   'SMR',
#   'Europe/San_Marino'),
#  ('Associazione Tennis Verona',
#   'sr:venue:78917',
#   'Grandstand',
#   'Verona',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('LTV 1899',
#   'sr:venue:72963',
#   'Indoor 2',
#   'Luedenscheid',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('XS Tennis Village',
#   'sr:venue:72299',
#   'Indoor 6',
#   'Chicago, IL',
#   'USA',
#   'USA',
#   'America/Chicago'),
#  ('Jacobs Pavilion at Nautica',
#   'sr:venue:65703',
#   'Indoor 2',
#   'Cleveland, OH',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Legia Tenis & Golf',
#   'sr:venue:72755',
#   'Indoor 3',
#   'Warsaw',
#   'Poland',
#   'POL',
#   'Europe/Warsaw'),
#  ('Tennis Club Ruppurr 1929 e. V.',
#   'sr:venue:60260',
#   'Court 1',
#   'Karlsruhe',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Park Mladen Stojanovic',
#   'sr:venue:30073',
#   'Court 1',
#   'Banja Luka',
#   'Bosnia & Herzegovina',
#   'BIH',
#   'Europe/Sarajevo'),
#  ('Tennis Sporting Club de Cassis Les Gorguettes',
#   'sr:venue:65911',
#   'Court 2',
#   'Cassis',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Tennis Club "Tennispark"',
#   'sr:venue:60218',
#   'Court 11',
#   'Kiev',
#   'Ukraine',
#   'UKR',
#   'Europe/Kyiv'),
#  ('Real Club de Tenis Betis',
#   'sr:venue:60222',
#   'Pista 3',
#   'Seville',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Tennis Club Tulln',
#   'sr:venue:73717',
#   'Grandstand',
#   'Tulln',
#   'Austria',
#   'AUT',
#   'Europe/Berlin'),
#  ('TED Tenis Eskrim Dagcilik Spor Kulubu',
#   'sr:venue:73697',
#   'Grand Tarabaya Court',
#   'Istanbul',
#   'Turkiye',
#   'TUR',
#   'Europe/Istanbul'),
#  ('Club Rancho San Francisco',
#   'sr:venue:60354',
#   'Cancha 8',
#   'Quito',
#   'Ecuador',
#   'ECU',
#   'America/Guayaquil'),
#  ('Wojska Polskiego',
#   'sr:venue:52547',
#   'Court 7',
#   'Szczecin',
#   'Poland',
#   'POL',
#   'Europe/Warsaw'),
#  ('Rakiura Resort',
#   'sr:venue:65953',
#   'Court Saint Gregoire 1',
#   'Rennes',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Jan Group Arena',
#   'sr:venue:66321',
#   'Match Court',
#   'Biel',
#   'Switzerland',
#   'CHE',
#   'Europe/Zurich'),
#  ('Club Campestre de Aguacalientes A.C.C.',
#   'sr:venue:63053',
#   'Cancha 4',
#   'Aguascalientes',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('National Tennis Centre',
#   'sr:venue:58482',
#   'Court 21',
#   'Heraklion',
#   'Greece',
#   'GRC',
#   'Europe/Athens'),
#  ('Centrul National de Tenis',
#   'sr:venue:82455',
#   'Court 9',
#   'Bucharest',
#   'Romania',
#   'ROU',
#   'Europe/Bucharest'),
#  ('Clube de Tenis de Braga',
#   'sr:venue:80279',
#   'Indoor 2',
#   'Braga',
#   'Portugal',
#   'PRT',
#   'Europe/Lisbon'),
#  ('Club Tungurahua',
#   'sr:venue:60466',
#   'Court 4',
#   'Ambato',
#   'Ecuador',
#   'ECU',
#   'America/Guayaquil'),
#  ('Tennis Club Pamira',
#   'sr:venue:18703',
#   'Court 7',
#   'Sibiu',
#   'Romania',
#   'ROU',
#   'Europe/Bucharest'),
#  ('Barnes Tennis Center',
#   'sr:venue:73869',
#   'Court 2',
#   'San Diego, CA',
#   'USA',
#   'USA',
#   'America/Los_Angeles'),
#  ('Club de Polo y Equitacion San Cristobal',
#   'sr:venue:82141',
#   'Centre Court',
#   'Naples',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Sporting Poseidon',
#   'sr:venue:60884',
#   'Court 3',
#   'Naples, FL',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Abama Tennis Academy',
#   'sr:venue:69613',
#   'Court 6',
#   'Santa Cruz de Tenerife',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Ljubicic Tennis Academy',
#   'sr:venue:61012',
#   'Tennis Centar Punta',
#   'Losinj',
#   'Croatia',
#   'HRV',
#   'Europe/Zagreb'),
#  ('PalaNorda',
#   'sr:venue:67367',
#   'Palaintred',
#   'Bergamo',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Greater Midland Tennis Center',
#   'sr:venue:67397',
#   'Court 4',
#   'Midland, Michigan',
#   'USA',
#   'USA',
#   'UTC'),
#  ('Le Scarabee',
#   'sr:venue:61467',
#   'Court 1',
#   'Roanne',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Pala Alpitour',
#   'sr:venue:61499',
#   'Centre Court',
#   'Turin',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Iate Club de Brasilia',
#   'sr:venue:61639',
#   'Indoor 4',
#   'Brasilia',
#   'Brazil',
#   'BRA',
#   'Brazil/East'),
#  ('Public Security Officers Club',
#   'sr:venue:61603',
#   'Court 2',
#   'Manama',
#   'Bahrain',
#   'BHR',
#   'Asia/Bahrain'),
#  ('New Country Tennis Academy',
#   'sr:venue:61659',
#   'Indoor Court',
#   'Bari',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Parque Parota',
#   'sr:venue:70143',
#   'Cancha Vino America',
#   'Puerto Vallarta',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Circolo Tennis Villa Carpena',
#   'sr:venue:61841',
#   'Gencom',
#   'Forli',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Clube Hipico Santo Amaro',
#   'sr:venue:47374',
#   'Quadra 2',
#   'Sao Paulo',
#   'Brazil',
#   'BRA',
#   'America/Sao_Paulo'),
#  ('Megasaray Tennis Academy',
#   'sr:venue:57028',
#   'Court 24',
#   'Antalya',
#   'Turkiye',
#   'TUR',
#   'Europe/Istanbul'),
#  ('Arena Loire Trelaze',
#   'sr:venue:57982',
#   'Court 6',
#   'Angers',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Parque Olimpico do Rio de Janeiro',
#   'sr:venue:61743',
#   'Court 2',
#   'Rio de Janeiro',
#   'Brazil',
#   'BRA',
#   'Brazil/East'),
#  ('Seoul Olympic Park Tennis Center',
#   'sr:venue:79923',
#   'Court 1',
#   'Seoul',
#   'Republic of Korea',
#   'KOR',
#   'Asia/Seoul'),
#  ('Styslinger Altec Tennis Complex',
#   'sr:venue:62191',
#   'Grandstand',
#   'Dallas, TX',
#   'USA',
#   'USA',
#   'America/Chicago'),
#  ('Multisport Sports Club',
#   'sr:venue:61006',
#   'Central Court',
#   'Moscow',
#   'Russia',
#   'RUS',
#   'Europe/Moscow'),
#  ('Tennis Academy El Cortijo Club De Campo',
#   'sr:venue:58190',
#   'Court 1',
#   'Las Palmas de Gran Canaria',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Teniski Klub Split',
#   'sr:venue:63207',
#   'Court 2',
#   'Split',
#   'Croatia',
#   'HRV',
#   'Europe/Zagreb'),
#  ('Forestmeadows Tennis Center',
#   'sr:venue:51857',
#   'Gene Cox Stadium',
#   'Tallahassee, FL',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Toto Hakriya Ashdod Arena',
#   'sr:venue:77903',
#   'Campo 3',
#   'Turin',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('TTF Istanbul Tenis Merkezi',
#   'sr:venue:60348',
#   'Court 9',
#   'Istanbul',
#   'Turkiye',
#   'TUR',
#   'Europe/Istanbul'),
#  ('Ace Tennis Club',
#   'sr:venue:75829',
#   'Court B',
#   'Nonthaburi',
#   'Thailand',
#   'THA',
#   'Asia/Bangkok'),
#  ('Tennis Club Roseto',
#   'sr:venue:62417',
#   'Court 3',
#   'Roseto Degli Abruzzi',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Club Manquehue de Vitacura',
#   'sr:venue:57598',
#   'Cancha 11',
#   'Santiago',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('Club Campestre de Pereira',
#   'sr:venue:62703',
#   'Cancha Santiago Giraldo',
#   'Pereira',
#   'Colombia',
#   'COL',
#   'America/Bogota'),
#  ('Padiglione Conza',
#   'sr:venue:39008',
#   'Indoor 1',
#   'Lugano',
#   'Switzerland',
#   'CHE',
#   'Europe/Zurich'),
#  ('Tennis Club Saint-Brieuc',
#   'sr:venue:62629',
#   'Court 4',
#   'Saint-Brieuc',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Centro Deportivo Chapultepec',
#   'sr:venue:62821',
#   'Cancha 4',
#   'Mexico City',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Salinas Golf & Tennis Club',
#   'sr:venue:72593',
#   'Cancha P. Segura',
#   'Salinas',
#   'Ecuador',
#   'ECU',
#   'America/Guayaquil'),
#  ('Tennis Sanremo',
#   'sr:venue:70553',
#   'Campo 2',
#   'Sanremo',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Monte-Carlo Country Club',
#   'sr:venue:57920',
#   'Court 13',
#   'Monte Carlo',
#   'Monaco',
#   'MCO',
#   'Europe/Paris'),
#  ('Payne Park Tennis Facility',
#   'sr:venue:70721',
#   'Court 10',
#   'Sarasota',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('SC Ostrava',
#   'sr:venue:77487',
#   'Court 4',
#   'Ostrava',
#   'Czechia',
#   'CZE',
#   'Europe/Prague'),
#  ('Tennis Club Garden',
#   'sr:venue:77473',
#   'SICEurope Court',
#   'Rome',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Franklin Creek Tennis Center',
#   'sr:venue:70873',
#   'Atlantic Radiology Court',
#   'Savannah',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Parc ded Sports de Marville',
#   'sr:venue:77563',
#   'Indoor 2',
#   'Saint Malo',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Danubis Tenniscenter Mauthausen',
#   'sr:venue:82491',
#   'Stadium',
#   'Mauthausen',
#   'Austria',
#   'AUT',
#   'Europe/Vienna'),
#  ('Country Club Aixois',
#   'sr:venue:70975',
#   'Court Eiffage',
#   'Aix-en-Provence',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Costa Verde Tenis Clube',
#   'sr:venue:63373',
#   'Court 4',
#   'Salvador',
#   'Brazil',
#   'BRA',
#   'America/Bahia'),
#  ('Villa Primrose',
#   'sr:venue:82581',
#   'COURT 11 OCI INFORMATIQUE',
#   'Bordeaux',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Club de Tenis Coquimbo',
#   'sr:venue:66901',
#   'Cancha 3',
#   'Coquimbo',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('National Tennis Center',
#   'sr:venue:57068',
#   'Court 1',
#   'Shymkent',
#   'Kazakhstan',
#   'KAZ',
#   'Asia/Almaty'),
#  ('Lagardere Paris Racing Club',
#   'sr:venue:71141',
#   'Court 3',
#   'Paris',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Circolo Tennis Francavilla al Mare Sporting Club',
#   'sr:venue:19929',
#   'Center Court',
#   'Francavilla al Mare',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('TC RW-Troisdorf e.V',
#   'sr:venue:63675',
#   'B and B Court',
#   'Troisdorf',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('TK Slovan Bratislava',
#   'sr:venue:71691',
#   'Court 11',
#   'Bratislava',
#   'Slovakia',
#   'SVK',
#   'Europe/Bratislava'),
#  ('USTA National Campus',
#   'sr:venue:61997',
#   'Indoor 2',
#   'Orlando, FL',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Tenisovy Klub Prostejov',
#   'sr:venue:63905',
#   'Prostejov Arena',
#   'Prostejov',
#   'Czechia',
#   'CZE',
#   'Europe/Prague'),
#  ('The Queen’s Club',
#   'sr:venue:71839',
#   'Owl Arena',
#   'Halle',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('CTC Corrientes Tennis Club',
#   'sr:venue:64217',
#   'Estadio Leonardo Mayer',
#   'Corrientes',
#   'Argentina',
#   'ARG',
#   'America/Argentina/Cordoba'),
#  ('Steffi-Graf Stadium',
#   'sr:venue:58728',
#   'Centre Court',
#   'Berlin',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Tennis Club Gaiba - Gaibledon',
#   'sr:venue:64261',
#   'Court 3',
#   'Gaiba',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Tenis Club Argentino',
#   'sr:venue:75899',
#   'Cancha 3',
#   'Buenos Aires',
#   'Argentina',
#   'ARG',
#   'America/Argentina/Buenos_Aires'),
#  ('AELTC Wimbledon Qualifying and Community Sports Ground',
#   'sr:venue:78503',
#   'Court 11',
#   'London',
#   'England',
#   'ENG',
#   'Europe/London'),
#  ('Inacua Malaga',
#   'sr:venue:64377',
#   'Court 3',
#   'Malaga',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Tennis Club de Troyes',
#   'sr:venue:78587',
#   'Court Amplitude',
#   'Troyes',
#   'France',
#   'FRA',
#   'US/Pacific'),
#  ('Salzburg Tennis Club',
#   'sr:venue:78681',
#   'Court 3',
#   'Salzburg',
#   'Austria',
#   'AUT',
#   'Europe/Vienna'),
#  ('Contrexeville Tennis Club',
#   'sr:venue:59034',
#   'Court 4',
#   'Contrexeville',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Rome Tennis Center',
#   'sr:venue:64795',
#   'Court 5',
#   'Rome',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Am Rothenbaum',
#   'sr:venue:72609',
#   'M5',
#   'Hamburg',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Pearson Automotive Tennis Club',
#   'sr:venue:64881',
#   'Court 4',
#   'Indianapolis, IN',
#   'USA',
#   'USA',
#   'America/Indiana/Indianapolis'),
#  ('C.D. Open Tenis Ciudad de Pozoblanco',
#   'sr:venue:59228',
#   'Center Court',
#   'Pozoblanco',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Tampereen Tenniskeskus Oy',
#   'sr:venue:31963',
#   'Court 3',
#   'Tampere',
#   'Finland',
#   'FIN',
#   'Europe/Helsinki'),
#  ('Circolo Tennis Maggioni',
#   'sr:venue:14410',
#   'Campo 3',
#   'San Benedetto',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Winnipeg Lawn Tennis Club',
#   'sr:venue:65187',
#   'Court 1',
#   'Winnipeg',
#   'Canada',
#   'CAN',
#   'America/Chicago'),
#  ('Tennisclub Zug',
#   'sr:venue:78959',
#   'Tramondo Court 2',
#   'Zug',
#   'Switzerland',
#   'CHE',
#   'Europe/Zurich'),
#  ('Hilary J. Boone Tennis Center',
#   'sr:venue:79053',
#   'Court 7',
#   'Lexington, KY',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Baza Sportiva Ciric',
#   'sr:venue:65287',
#   'Stadium 6',
#   'Iasi',
#   'Romania',
#   'ROU',
#   'Europe/Bucharest'),
#  ('Jockey Club del Peru',
#   'sr:venue:61014',
#   'Cancha 13',
#   'Lima',
#   'Peru',
#   'PER',
#   'America/Lima'),
#  ('Hollyburn Country Club',
#   'sr:venue:44680',
#   'Polygon Court',
#   'West Vancouver',
#   'Canada',
#   'CAN',
#   'America/Vancouver'),
#  ('Akademia Tenisowa Tenis Kozerki',
#   'sr:venue:73217',
#   'Indoor Court 2',
#   'Kozerki',
#   'Poland',
#   'POL',
#   'Europe/Warsaw'),
#  ('Tennis St-Luc - Les Loisirs De Granby',
#   'sr:venue:64071',
#   'Indoor 2',
#   'Granby',
#   'Canada',
#   'CAN',
#   'Canada/Eastern'),
#  ('TK Spoje Praha',
#   'sr:venue:65765',
#   'Court 8',
#   'Prague',
#   'Czechia',
#   'CZE',
#   'Europe/Prague'),
#  ('Nacionalni Trening Centar Teniskog',
#   'sr:venue:73147',
#   'Court 2',
#   'Banja Luka',
#   'Bosnia & Herzegovina',
#   'BIH',
#   'Europe/Sarajevo'),
#  ('A.S.D. Tennis Club Como',
#   'sr:venue:73585',
#   'TC Giussano Indoors 5',
#   'Como',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Rafa Nadal Academy',
#   'sr:venue:65737',
#   'Center Court',
#   'Mallorca',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Etihad Arena',
#   'sr:venue:65749',
#   'Court 4',
#   'Toulouse',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Tennis Academy SET',
#   'sr:venue:73779',
#   'Tato Paride Court',
#   'Bari',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('The Lawn Tennis Association of Thailand',
#   'sr:venue:66887',
#   'Centre Court',
#   'Vilnius',
#   'Lithuania',
#   'LTU',
#   'Europe/Vilnius'),
#  ('National Tennis Centre',
#   'sr:venue:77885',
#   'Court 2',
#   'Taipei',
#   'Chinese Taipei',
#   'TPE',
#   'Asia/Taipei'),
#  ('Ohio State University',
#   'sr:venue:65995',
#   'Court 4',
#   'Columbus, OH',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Sport Social Club',
#   'sr:venue:57744',
#   'Court Central',
#   'Villa Maria',
#   'Argentina',
#   'ARG',
#   'America/Argentina/Cordoba'),
#  ('Tel Aviv International Convention Center',
#   'sr:venue:66097',
#   'Centre Court',
#   'Tel Aviv',
#   'Israel',
#   'ISR',
#   'Asia/Jerusalem'),
#  ('Rio Tennis Academy',
#   'sr:venue:35602',
#   'Court 8',
#   'Monastir',
#   'Tunisia',
#   'TUN',
#   'Africa/Tunis'),
#  ('Tennis Club Saint Tropez',
#   'sr:venue:74165',
#   'Court 6',
#   'Saint-Tropez',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Spo1 Park',
#   'sr:venue:66879',
#   'Center Court',
#   'Busan',
#   'Republic of Korea',
#   'KOR',
#   'Asia/Seoul'),
#  ('Hamburger Tennis Verband e.V',
#   'sr:venue:74726',
#   'Court 2',
#   'Hamburg',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Tennis Club Ortisei',
#   'sr:venue:24056',
#   'Court 3',
#   'Ortisei',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Centro Libanes Mexicano de Tampico',
#   'sr:venue:67231',
#   'Estadio',
#   'Tampico',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Olme Sport',
#   'sr:venue:67315',
#   'Center Court',
#   'Bergamo',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Ehime Prefectural Sports Complex',
#   'sr:venue:75088',
#   'Court Indoor 11',
#   'Matsuyama',
#   'Japan',
#   'JPN',
#   'Asia/Tokyo'),
#  ('Tennis Interieur Rene Verrier',
#   'sr:venue:54901',
#   'Centre Marcel Dionne',
#   'Drummondville',
#   'Canada',
#   'CAN',
#   'America/Toronto'),
#  ('Yokkaichi Tennis Center',
#   'sr:venue:68163',
#   'Indoor Court 15',
#   'Yokkaichi',
#   'Japan',
#   'JPN',
#   'Asia/Tokyo'),
#  ('Conde Jackson Tennis Club Maspalomas',
#   'sr:venue:68263',
#   'Canary Islands Court',
#   'Maspalomas',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Club Nautico Hacoaj',
#   'sr:venue:81925',
#   'Club Nautico Hacoaj - Center Court',
#   'Tigre',
#   'Argentina',
#   'ARG',
#   'America/Argentina/Buenos_Aires'),
#  ('CLUBE CRISTOVAO COLOMBO',
#   'sr:venue:81843',
#   'Indoor 4',
#   'Piracicaba',
#   'Brazil',
#   'BRA',
#   'America/Sao_Paulo'),
#  ('Complexe Sportif du Blocry',
#   'sr:venue:69279',
#   'Court 1',
#   'Ottignies-Louvain-la-Neuve',
#   'Belgium',
#   'BEL',
#   'Europe/Brussels'),
#  ('Estadio Espanol Chiguayante',
#   'sr:venue:77493',
#   'Cancha 3',
#   'Concepcion',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('Complexe Jean Jaures',
#   'sr:venue:69771',
#   'Jean Jaures',
#   'Cherbourg-en-Cotentin',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Rome Tennis Center at Berry College',
#   'sr:venue:69787',
#   'Court 3',
#   'Rome',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Circolo Tennis Rovereto',
#   'sr:venue:69797',
#   'Court 3',
#   'Rovereto',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Yucatan Country Club',
#   'sr:venue:69893',
#   'Estadio Akron',
#   'Mérida',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Hurd Tennis Center',
#   'sr:venue:70071',
#   'Grandstand',
#   'Waco, TX',
#   'USA',
#   'USA',
#   'America/Chicago'),
#  ('Westwood Country Club',
#   'sr:venue:82003',
#   'Court 11',
#   'Austin, TX',
#   'USA',
#   'USA',
#   'America/Chicago'),
#  ('Utilita Arena Birmingham',
#   'sr:venue:77057',
#   '12BET COURT',
#   'Birmingham',
#   'England',
#   'ENG',
#   'Europe/London'),
#  ('Club Tennis Els Gorchs',
#   'sr:venue:67191',
#   'Pista 3',
#   'Les Franqueses Del Valles',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Club Tennis Girona',
#   'sr:venue:66965',
#   'Court 2',
#   'Girona',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Club Campestre',
#   'sr:venue:70713',
#   'Court 1',
#   'Leon',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Tenis Centar Firule',
#   'sr:venue:70803',
#   'Indoor Court',
#   'Split',
#   'Croatia',
#   'HRV',
#   'Europe/Zagreb'),
#  ('Tennis Club Rot Weiss Troisdorf E. V.',
#   'sr:venue:71409',
#   'B&B Court',
#   'Troisdorf',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Club de Tennis La Bisbal Centre Esportiu',
#   'sr:venue:58388',
#   'Pista Central',
#   'La Bisbal D Emporda',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Salle Omnisport de Rades',
#   'sr:venue:71931',
#   'Table 4',
#   'Tunis',
#   'Tunisia',
#   'TUN',
#   'Africa/Tunis'),
#  ('Club La Meridiana',
#   'sr:venue:72003',
#   'Court 3',
#   'Modena',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Cranbrook Kingswood Tennis Complex',
#   'sr:venue:78573',
#   'Court 1',
#   'Bloomfield Hills',
#   'USA',
#   'USA',
#   'UTC'),
#  ('Nice Lawn Tennis Club',
#   'sr:venue:72527',
#   'Court 1',
#   'Nice',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Complejo Deportivo Pedro Muñoz',
#   'sr:venue:65139',
#   'Pista 4',
#   'Segovia',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Corredor Turistico SJC-CSL',
#   'sr:venue:72883',
#   'Estadio Mextenis',
#   'Los Cabos',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Stanford Taube Tennis Center',
#   'sr:venue:73177',
#   'Court 4',
#   'Stanford, CA',
#   'USA',
#   'USA',
#   'America/Los_Angeles'),
#  ('National Bank Tennis Hub @ West St Paul',
#   'sr:venue:73189',
#   'Court 3',
#   'Winnipeg',
#   'Canada',
#   'CAN',
#   'America/Chicago'),
#  ('Parque Distrital de Raquetas',
#   'sr:venue:73201',
#   'Court 4',
#   'Barranquilla',
#   'Colombia',
#   'COL',
#   'America/Bogota'),
#  ('AO Arena',
#   'sr:venue:74043',
#   'AO Arena',
#   'Manchester',
#   'England',
#   'ENG',
#   'Europe/London'),
#  ('Academy Zhangjiagang',
#   'sr:venue:23414',
#   'Indoor 12',
#   'Zhangjiagang',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Tivoli Tennis Center',
#   'sr:venue:79835',
#   'Court 7',
#   'Ljubljana',
#   'Slovenia',
#   'SVN',
#   'Europe/Ljubljana'),
#  ('Guangzhou Nansha International Tennis Center',
#   'sr:venue:77715',
#   'Indoor Court',
#   'Guangzhou',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Country Club Las Palmas',
#   'sr:venue:74039',
#   'Cancha 2',
#   'Santa Cruz de la Sierra',
#   'Bolivia',
#   'BOL',
#   'America/La_Paz'),
#  ('ILT Stadium',
#   'sr:venue:73825',
#   'Center Court',
#   'Szczecin',
#   'Poland',
#   'POL',
#   'Europe/Warsaw'),
#  ('Autoclub Antofagasta',
#   'sr:venue:74005',
#   'Court 3',
#   'Antofagasta',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('Sportaktivpark Bad Waltersdorf',
#   'sr:venue:74015',
#   'Court 3',
#   'Bad Waltersdorf',
#   'Austria',
#   'AUT',
#   'Europe/Vienna'),
#  ('Complejo de Tenis Marcelo Arevalo',
#   'sr:venue:74025',
#   'Court 3',
#   'Columbus, OH',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('National Tennis Center (Beeline Arena)',
#   'sr:venue:78771',
#   'Court 4',
#   'Astana',
#   'Kazakhstan',
#   'KAZ',
#   'Asia/Almaty'),
#  ('Club Compensar Sede 220',
#   'sr:venue:74191',
#   'Court 3',
#   'Bogota',
#   'Colombia',
#   'COL',
#   'America/Bogota'),
#  ("Arena Co'Met",
#   'sr:venue:80093',
#   'St Cyr En Val No.2',
#   'Orleans',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Playford Tennis Centre',
#   'sr:venue:26347',
#   'Court 2',
#   'Playford City',
#   'Australia',
#   'AUS',
#   'Australia/Adelaide'),
#  ('Graciosa Country Club',
#   'sr:venue:74952',
#   'Indoor 12',
#   'Curitiba',
#   'Brazil',
#   'BRA',
#   'Brazil/East'),
#  ('Ciudad Deportiva de Tampico',
#   'sr:venue:74812',
#   'Stadium 1',
#   'Tampico',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Hengqin Tennis Center',
#   'sr:venue:74826',
#   'Huafa Center Court',
#   'Zhuhai',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Estadio Paradisus Cancun Quintana Roo',
#   'sr:venue:74910',
#   'Estadio Paradisus',
#   'Cancun',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Arena Sofia',
#   'sr:venue:74970',
#   'Court 3',
#   'Sofia',
#   'Bulgaria',
#   'BGR',
#   'Europe/Sofia'),
#  ('Tennis Intérieur René Verrier',
#   'sr:venue:75150',
#   'Court 1',
#   'Danderyd',
#   'Sweden',
#   'SWE',
#   'Europe/Stockholm'),
#  ('Carrasco Lawn Tennis Club',
#   'sr:venue:75108',
#   'Court C',
#   'Kobe',
#   'Japan',
#   'JPN',
#   'Asia/Tokyo'),
#  ('Hacienda Chicureo',
#   'sr:venue:75120',
#   'Grandstand',
#   'Colina',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('Arena BRB',
#   'sr:venue:75338',
#   'Quadra 4',
#   'Brasilia',
#   'Brazil',
#   'BRA',
#   'Brazil/East'),
#  ('Jurerê Sports Center',
#   'sr:venue:81423',
#   'Indoor Court',
#   'Florianopolis',
#   'Brazil',
#   'BRA',
#   'America/Sao_Paulo'),
#  ('Bezirksstützpunkt Biberach',
#   'sr:venue:75615',
#   'Platz 4',
#   'Baden-Wurttemberg',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Hala Ricany',
#   'sr:venue:75735',
#   'Kurt 2',
#   'Prague',
#   'Czechia',
#   'CZE',
#   'Europe/Prague'),
#  ('Vitality Slezsko',
#   'sr:venue:76185',
#   'Match Court',
#   'Trinec',
#   'Czechia',
#   'CZE',
#   'Europe/Prague'),
#  ('Jockey Club de Rosario',
#   'sr:venue:81869',
#   'Cancha 2',
#   'Rosario',
#   'Argentina',
#   'ARG',
#   'America/Argentina/Buenos_Aires'),
#  ('Design Center Linz',
#   'sr:venue:1386',
#   'Match Court 1',
#   'Linz',
#   'Austria',
#   'AUT',
#   'Europe/Vienna'),
#  ('Guangzhou Development District International Tennis School',
#   'sr:venue:79789',
#   'Court 6',
#   'Guangzhou',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Delhi Lawn Tennis Association',
#   'sr:venue:76933',
#   'Court 2',
#   'New Delhi',
#   'India',
#   'IND',
#   'Asia/Kolkata'),
#  ('Emilio Sanchez Academy',
#   'sr:venue:77261',
#   'Court 2',
#   'Barcelona',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Tiriac Stadium',
#   'sr:venue:2086',
#   'Center Court',
#   'Bucharest',
#   'Romania',
#   'ROU',
#   'Europe/Bucharest'),
#  ('Tucumán Lawn Tennis Club',
#   'sr:venue:77435',
#   'Cancha 9',
#   'San Miguel de Tucuman',
#   'Argentina',
#   'ARG',
#   'America/Argentina/Cordoba'),
#  ('Arena GNP Seguros',
#   'sr:venue:51479',
#   'Estadio Arena GNP Seguros (Acapulco, MEXICO)',
#   'Acapulco',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Club Tennis Lleida',
#   'sr:venue:77583',
#   'Court 2',
#   'Lleida',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Wuxi International Tennis Center',
#   'sr:venue:77717',
#   'Center Court',
#   'Wuxi',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Tênis Clube de Santos',
#   'sr:venue:82575',
#   'Indoor 1',
#   'Santos',
#   'Brazil',
#   'BRA',
#   'Brazil/East'),
#  ('Tennis Club De Tunis',
#   'sr:venue:82408',
#   'Court 10',
#   'Oeiras',
#   'Portugal',
#   'PRT',
#   'Europe/Lisbon'),
#  ('Kachreti Golf Resort',
#   'sr:venue:70997',
#   'Court 2',
#   'Kachreti',
#   'Georgia',
#   'GEO',
#   'Asia/Tbilisi'),
#  ('Community Sport Centre',
#   'sr:venue:78141',
#   'Court 8',
#   'Zagreb',
#   'Croatia',
#   'HRV',
#   'Europe/Zagreb'),
#  ('Baza Sportiva Olimpia',
#   'sr:venue:78625',
#   'Court 4',
#   'Brasov',
#   'Romania',
#   'ROU',
#   'Europe/Bucharest'),
#  ('Sporting Club Verona',
#   'sr:venue:78965',
#   'Grandstand',
#   'Verona',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Victoria Park Tennis Stadium',
#   'sr:venue:80261',
#   'Court 2',
#   'Hong Kong',
#   'Hong Kong, China',
#   'HKG',
#   'Asia/Hong_Kong'),
#  ('Bonn Tennis and Hockey Club',
#   'sr:venue:79153',
#   'Court 2',
#   'Bonn',
#   'Germany',
#   'DEU',
#   'Europe/Berlin'),
#  ('Sid And Hazel Dillon Tennis Center',
#   'sr:venue:80959',
#   'Court 5',
#   'Lincoln, NE',
#   'USA',
#   'USA',
#   'America/Chicago'),
#  ('Tennis Club Izida',
#   'sr:venue:34570',
#   'Court 3',
#   'Dobrich',
#   'Bulgaria',
#   'BGR',
#   'Europe/Sofia'),
#  ('Omega Sport Center',
#   'sr:venue:81529',
#   'Omega Sport - Court 3',
#   'Olomouc',
#   'Czechia',
#   'CZE',
#   'Europe/Prague'),
#  ('Clube de Tenis do Porto',
#   'sr:venue:72933',
#   'Court 1',
#   'Porto',
#   'Portugal',
#   'PRT',
#   'Europe/Lisbon'),
#  ('Montreux Tennis Club',
#   'sr:venue:33974',
#   'Court 1',
#   'Montreux',
#   'Switzerland',
#   'CHE',
#   'Europe/Zurich'),
#  ('Tennis Club de Avenir Sportif de la Marsa',
#   'sr:venue:79949',
#   'Cancha 2',
#   'Santiago de Cali',
#   'Colombia',
#   'COL',
#   'America/Bogota'),
#  ('International Tennis Center',
#   'sr:venue:80811',
#   'Indoor 1',
#   'Jiujiang',
#   'China',
#   'CHN',
#   'Asia/Shanghai'),
#  ('Inalpi Arena',
#   'sr:venue:80875',
#   'Grandstand',
#   'Belgrade',
#   'Serbia',
#   'SRB',
#   'Europe/Belgrade'),
#  ('All In Country Club Decines',
#   'sr:venue:81015',
#   'COURT 2',
#   'Decines-Charpieu',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Las Hadas Golf & Country Club',
#   'sr:venue:81321',
#   'Cancha 3',
#   'Manzanillo',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Headington Family Tennis Center',
#   'sr:venue:81581',
#   'Headington Family Tennis Center - Court 6',
#   'Norman, OK',
#   'USA',
#   'USA',
#   'America/Chicago'),
#  ('Royal SC Tennis',
#   'sr:venue:81611',
#   'Royal SC Tennis - Court 01',
#   'Noda',
#   'Japan',
#   'JPN',
#   'Asia/Tokyo'),
#  ('LSU',
#   'sr:venue:81691',
#   'LSU - Court 06',
#   'Baton Rouge, LA',
#   'USA',
#   'USA',
#   'America/Chicago'),
#  ('Robson Tennis Center',
#   'sr:venue:81649',
#   'Robson Tennis Center - Court 3',
#   'Tucson, AZ',
#   'USA',
#   'USA',
#   'America/Phoenix'),
#  ('Wake Forest Tennis Center',
#   'sr:venue:81415',
#   'Wake Forest Tennis Center - Indoor - Court 05',
#   'Winston Salem, NC',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Palmira Tennis Club',
#   'sr:venue:81697',
#   'Court 4',
#   'Florida City (FL)',
#   'USA',
#   'USA',
#   'America/Mexico_City'),
#  ('Tennis Courts of the SW University Neofit Rilski',
#   'sr:venue:81689',
#   'Tennis Courts of the SW University Neofit Rilski - Court 2',
#   'Blagoevgrad',
#   'Bulgaria',
#   'BGR',
#   'Europe/Sofia'),
#  ('Penina Hotel & Golf Resort',
#   'sr:venue:81759',
#   'Penina Hotel and Golf Resort - 1. Court Penina',
#   'Alvor',
#   'Portugal',
#   'PRT',
#   'Europe/Lisbon'),
#  ('Clube Tenis Portimao',
#   'sr:venue:81725',
#   'Bloomington - Court 5',
#   'Bloomington, IN',
#   'USA',
#   'USA',
#   'America/Indiana/Indianapolis'),
#  ('Atlantis The Palm',
#   'sr:venue:81831',
#   'Atlantis The Palm - Court 4',
#   'Dubai',
#   'United Arab Emirates',
#   'ARE',
#   'Asia/Dubai'),
#  ('Kallang Tennis Centre',
#   'sr:venue:81767',
#   'Court 1',
#   'Singapore City',
#   'Singapore',
#   'SGP',
#   'Asia/Singapore'),
#  ('Coque Luxenbourg',
#   'sr:venue:81791',
#   'KPI Park - Court 06',
#   'Yokohama',
#   'Japan',
#   'JPN',
#   'Asia/Tokyo'),
#  ('Boulevard de las Naciones and Paseo de los Manglares',
#   'sr:venue:81983',
#   'Green Tennis Plaza - Court 04',
#   'Kawaguchi',
#   'Japan',
#   'JPN',
#   'Asia/Tokyo'),
#  ('Georgia Gwinnett',
#   'sr:venue:82410',
#   'Georgia Gwinnett - Court 06',
#   'Lawrenceville, GA',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Sport Center Visnjik (Clay)',
#   'sr:venue:82195',
#   'Sport Center Visnjik (Clay) - Court 2',
#   'Zadar',
#   'Croatia',
#   'HRV',
#   'Europe/Zagreb'),
#  ('Spot - Salle Jean Burger',
#   'sr:venue:82059',
#   'Court Central',
#   'Thionville',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Raquet Village',
#   'sr:venue:82103',
#   'Cancha 1',
#   'Cap Cana',
#   'Dominican Republic',
#   'DOM',
#   'America/Santo_Domingo'),
#  ('Manzanillo',
#   'sr:venue:82117',
#   'Manzanillo - Court 04',
#   'Manzanillo',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Club de Golf Tres Marias',
#   'sr:venue:82211',
#   'Grandstand Pablo Arroyo',
#   'Morelia',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Sheraton Buganvilias Resort and Convention Center',
#   'sr:venue:82217',
#   'Sheraton Buganvilias',
#   'Puerto Vallarta',
#   'Mexico',
#   'MEX',
#   'America/Mexico_City'),
#  ('Tennis Club Porto Rose',
#   'sr:venue:82251',
#   'Tennis Club Porto Rose - Court 2',
#   'Roseto Degli Abruzzi',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Complejo Deportivo San Carlos De Apoquindo',
#   'sr:venue:82231',
#   'C4 Skechers',
#   'Santiago',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('Club Tenis Ciutadella',
#   'sr:venue:82277',
#   'Joma Court 3',
#   'Menorca',
#   'Spain',
#   'ESP',
#   'Europe/Madrid'),
#  ('Tenis Club Crvena Zvezda',
#   'sr:venue:82285',
#   'Tenis Club Crvena Zvezda - Court 03',
#   'Belgrade',
#   'Serbia',
#   'SRB',
#   'Europe/Belgrade'),
#  ('Villa Reale Tennis Monza',
#   'sr:venue:82321',
#   'Court 1',
#   'Monza',
#   'Italy',
#   'ITA',
#   'Europe/Rome'),
#  ('Carvoeiro Clube de Tenis',
#   'sr:venue:82333',
#   'Carvoeiro Clube de Tenis - 08. Court Details',
#   'Carvoeiro',
#   'Portugal',
#   'PRT',
#   'Europe/Lisbon'),
#  ('Sarasota Sports Club',
#   'sr:venue:82341',
#   'Court 7',
#   'Sarasota',
#   'USA',
#   'USA',
#   'America/New_York'),
#  ('Le Central Tennis Club',
#   'sr:venue:82382',
#   'Central KAYDAN',
#   'Abidjan',
#   'Cote d’Ivoire',
#   'CIV',
#   'Africa/Abidjan'),
#  ('Dan Maskell Tennis Centre',
#   'sr:venue:82392',
#   'Loughborough University - Court 05',
#   'Loughborough',
#   'England',
#   'ENG',
#   'Europe/London'),
#  ('George P Mitchell 40 Tennis Center',
#   'sr:venue:82451',
#   'Mitchell Tennis Center - Texas AM - Court 04',
#   'College Station, TX',
#   'USA',
#   'USA',
#   'America/Chicago'),
#  ('National Tennis Center',
#   'sr:venue:82479',
#   'National Tennis Center - Outdoor - Court 06',
#   'Bucharest',
#   'Romania',
#   'ROU',
#   'Europe/Bucharest'),
#  ('Tcja Saint-Malo',
#   'sr:venue:82495',
#   'Court 2',
#   'Saint Malo',
#   'France',
#   'FRA',
#   'Europe/Paris'),
#  ('Club Tennis Vic',
#   'sr:venue:82499',
#   'Court 3',
#   'Vic',
#   'Spain',
#   'ESP',
#   'Europe/Madrid')]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#                            complex_name        venue_id  \
# 0                              Nacional  sr:venue:70045
# 1                 Estadio de la Cartuja  sr:venue:74858
# 2                           Sibur Arena  sr:venue:62153
# 3                              O2 Arena  sr:venue:77437
# 4                        Ostravar Arena  sr:venue:55223
# ..                                  ...             ...
# 504           Dan Maskell Tennis Centre  sr:venue:82392
# 505  George P Mitchell 40 Tennis Center  sr:venue:82451
# 506              National Tennis Center  sr:venue:82479
# 507                     Tcja Saint-Malo  sr:venue:82495
# 508                     Club Tennis Vic  sr:venue:82499
#
#                                        venue_name      venue_city_name  \
# 0                                  Cancha Central             Santiago
# 1                                       Court One              Seville
# 2                                       TC Dynamo     Saint Petersburg
# 3                                         Campo 8               Oeiras
# 4                                         Court 2              Ostrava
# ..                                            ...                  ...
# 504            Loughborough University - Court 05         Loughborough
# 505  Mitchell Tennis Center - Texas AM - Court 04  College Station, TX
# 506   National Tennis Center - Outdoor - Court 06            Bucharest
# 507                                       Court 2           Saint Malo
# 508                                       Court 3                  Vic
#
#     venue_country_name venue_country_code    venue_timezone
# 0                Chile                CHL  America/Santiago
# 1                Spain                ESP     Europe/Madrid
# 2               Russia                RUS     Europe/Moscow
# 3             Portugal                PRT     Europe/Lisbon
# 4              Czechia                CZE     Europe/Prague
# ..                 ...                ...               ...
# 504            England                ENG     Europe/London
# 505                USA                USA   America/Chicago
# 506            Romania                ROU  Europe/Bucharest
# 507             France                FRA      Europe/Paris
# 508              Spain                ESP     Europe/Madrid
#
# [509 rows x 7 columns]

# %% [markdown]
# 2)	Count the number of venues in each complex

# %%
sql_query = """Select comp.complex_name, count(venue.venue_id) as venue_count
from complexes_table comp left join venues_table venue on comp.complex_id = venue.complex_id 
group by comp.complex_name order by complex_name asc"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('A.S.D. Tennis Club Como', 1),
#  ('AAJB Tennis', 1),
#  ('Abama Tennis Academy', 1),
#  ('Academy Zhangjiagang', 1),
#  ('Acapulco Princess Mundo Imperial', 0),
#  ('Accor Arena', 1),
#  ('Ace Tennis Club', 1),
#  ('Adani Arena Rockhampton', 1),
#  ('AELTC Wimbledon Qualifying and Community Sports Ground', 1),
#  ('Akademia Tenisowa Tenis Kozerki', 1),
#  ('Alex Metreveli Tennis Club', 1),
#  ('All England Lawn Tennis and Croquet Club', 1),
#  ('All In Country Club Decines', 1),
#  ('Almaty Tennis Center', 1),
#  ('Am Rothenbaum', 2),
#  ('Amelia Island Plantation Resort', 1),
#  ('Amersfoort Lawn Tennis Club', 1),
#  ('Anexo Guayaquil Tenis Club', 0),
#  ('AO Arena', 1),
#  ('Arena Armeets Sofia', 1),
#  ('Arena BRB', 1),
#  ("Arena Co'Met", 1),
#  ('Arena GNP Seguros', 1),
#  ('Arena Gripe', 1),
#  ('Arena Loire Trelaze', 1),
#  ('Arena Montpellier', 0),
#  ('Arena Sofia', 1),
#  ('Arenes de Metz', 0),
#  ('Ariake Colosseum', 1),
#  ('Ariake Tennis Forest Park Ariake Colesseum', 1),
#  ('Arka Tennis Club', 1),
#  ('ASB Tennis Arena', 1),
#  ('ASB Tennis Centre', 0),
#  ('Aspria Harbor Club', 1),
#  ('Associazione Tennis Verona', 1),
#  ('Atkins Tennis Center', 1),
#  ('Atlanta Athletic Club', 1),
#  ('Atlantic Station', 1),
#  ('Atlantis The Palm', 1),
#  ('ATP Stadion Goran Ivanisevic', 1),
#  ('Au Tennis Club De Tunis', 1),
#  ('Autoclub Antofagasta', 1),
#  ('Automobile and Touring Club of Lebanon', 0),
#  ('Autotron Rosmalen', 1),
#  ('Aviation Club Tennis Centre', 0),
#  ('AXA Arena NTC', 1),
#  ('Baku Tennis Academy', 2),
#  ('Barnes Tennis Center', 1),
#  ('Bastad Tennis Stadium', 0),
#  ('Baza Sportiva Ciric', 1),
#  ('Baza Sportiva Olimpia', 1),
#  ('Beeline Arena', 0),
#  ('Bendigo Tennis Centre', 1),
#  ('Beograndska Arena', 0),
#  ('Bezirksstützpunkt Biberach', 1),
#  ('Bloomington', 0),
#  ('Bluesun Tennis Center', 0),
#  ('BNR arena', 1),
#  ('Bonn Tennis and Hockey Club', 1),
#  ('Boulevard de las Naciones and Paseo de los Manglares', 1),
#  ('Braunschweiger Tennis und Hockeyclub', 1),
#  ('BT Arena', 1),
#  ('Buenos Aires Lawn Tennis Club', 0),
#  ('Burnie Tennis Club', 1),
#  ('C.D. Open Tenis Ciudad de Pozoblanco', 1),
#  ('Cabo Sports Complex', 1),
#  ('Caja Magica', 1),
#  ('Canberra Tennis Centre', 1),
#  ('Cantegril Country Club', 0),
#  ('Carrasco Lawn Tennis Club', 2),
#  ('Carvoeiro Clube de Tenis', 1),
#  ('Cary Leeds Center for Tennis & Learning', 1),
#  ('Cary Tennis Park', 1),
#  ('Center Plains Tennis Center', 1),
#  ('Centre Municipal de Tennis Vall d Hebron', 1),
#  ('Centro Cultural de Viana do Castelo', 0),
#  ('Centro Deportivo Chapultepec', 1),
#  ('Centro Libanes Mexicano de Tampico', 1),
#  ('Centro Panamericano de Tenis', 1),
#  ('Centro Tennis Cassa di Risparmio', 1),
#  ('Centrul National de Tenis', 1),
#  ('China National Tennis Center', 1),
#  ('Circolo del Tennis Firenze 1898', 2),
#  ('Circolo Della Stampa Sporting', 0),
#  ('Circolo Tennis Bari', 0),
#  ('Circolo Tennis Barletta', 1),
#  ('Circolo Tennis Francavilla al Mare Sporting Club', 1),
#  ('Circolo Tennis Hugo Simmen', 0),
#  ('Circolo Tennis I Faggi', 1),
#  ('Circolo Tennis Maggioni', 1),
#  ('Circolo Tennis Rovereto', 1),
#  ('Circolo Tennis Villa Carpena', 1),
#  ('Ciric Sport Base', 1),
#  ('Ciudad Deportiva de Tampico', 1),
#  ('CK Sportcenter Kockelscheuer', 0),
#  ('Cleveland Racquet Club', 1),
#  ('Club Avantage Multi-Sports', 1),
#  ('Club Campestre', 1),
#  ('Club Campestre de Aguacalientes A.C.C.', 1),
#  ('Club Campestre de Pereira', 1),
#  ('Club Campestre El Rancho', 1),
#  ('Club Campestre Farallones', 0),
#  ('Club Campestre Sede Llanogrande', 1),
#  ('Club Compensar Sede 220', 1),
#  ('Club De Campo Bellavista', 1),
#  ('Club de Campo Villa de Madrid', 1),
#  ('Club de Golf Tres Marias', 1),
#  ('Club de Polo y Equitacion San Cristobal', 1),
#  ('Club de Tenis Coquimbo', 1),
#  ('Club de Tenis Puente Romano', 1),
#  ('Club de Tenis Santa Cruz', 0),
#  ('Club de Tennis La Bisbal Centre Esportiu', 1),
#  ('Club Deportivo Potosino', 1),
#  ('Club Deportivo Universidad Catolica', 1),
#  ('Club des Cheminots', 1),
#  ('Club Internacional de Foot-ball', 0),
#  ('Club Internacional de Tenis', 0),
#  ('Club Jacaranda Cumbaya', 1),
#  ('Club La Meridiana', 1),
#  ('Club Lawn Tennis de la Exposicion', 0),
#  ('Club Los Lagartos', 1),
#  ('Club Manquehue de Vitacura', 1),
#  ('Club Megasaray Tennis Centre', 0),
#  ('Club Nautico Hacoaj', 1),
#  ('Club Naval de Campo las Salinas', 0),
#  ('Club Rancho San Francisco', 1),
#  ('Club Sonoma', 0),
#  ('Club Sonoma, Estadio Gnp Seguros', 1),
#  ('Club Tenis Ciutadella', 1),
#  ('Club Tennis Els Gorchs', 1),
#  ('Club Tennis Girona', 1),
#  ('Club Tennis Las Terrazas de Miraflores', 1),
#  ('Club Tennis Lleida', 1),
#  ('Club Tennis Vic', 1),
#  ('Club Tungurahua', 1),
#  ('CLUBE CRISTOVAO COLOMBO', 1),
#  ('Clube de Tenis de Braga', 1),
#  ('Clube de Ténis do Estoril', 2),
#  ('Clube de Tenis do Porto', 1),
#  ('Clube Hipico Santo Amaro', 1),
#  ('Clube Tenis Portimao', 1),
#  ('Community Sport Centre', 1),
#  ('Complejo de Raquetas', 0),
#  ('Complejo de Tenis Marcelo Arevalo', 1),
#  ('Complejo Deportivo Pedro Muñoz', 1),
#  ('Complejo Deportivo San Carlos De Apoquindo', 1),
#  ('Complejo Polideportivo de Cuidad Merliot', 1),
#  ('Complexe Al Amal', 1),
#  ('Complexe Jean Jaures', 1),
#  ('Complexe Sportif Chantereyne', 1),
#  ('Complexe Sportif du Blocry', 1),
#  ('Complexe Tennistique Marie-Louise Lhuillier', 0),
#  ('Complexo de Tenis do Jamor', 0),
#  ('Complexo Desportivo do Jamor', 0),
#  ('Complexo Municipal de Tenis da Maia', 1),
#  ('Complexo Tenis Monte Aventino', 1),
#  ('COMUNIDAD VALENCIANA', 1),
#  ('Conde Jackson Tennis Club Maspalomas', 1),
#  ('Connecticut Tennis Center', 0),
#  ('Contrexeville Tennis Club', 1),
#  ('Coque Luxenbourg', 1),
#  ('Cordoba Lawn Tennis Club', 1),
#  ('Corredor Turistico SJC-CSL', 1),
#  ('Costa Rica Country Club', 0),
#  ('Costa Verde Tenis Clube', 1),
#  ('Country Club Aixois', 1),
#  ('Country Club de Bogota', 1),
#  ('Country Club Las Palmas', 1),
#  ('Country Club Santa Ponsa', 0),
#  ('Country Time Club', 1),
#  ('Courts De Tennis De La Cité Nationale Sportive El Menza', 0),
#  ('Cranbrook Kingswood Tennis Complex', 1),
#  ('CTC Corrientes Tennis Club', 1),
#  ('Dan Maskell Tennis Centre', 1),
#  ('Danubis Tenniscenter Mauthausen', 1),
#  ('Delhi Gymkhana Club', 0),
#  ('Delhi Lawn Tennis Association', 1),
#  ('Delmar International School', 1),
#  ('Delray Beach Tennis Center', 1),
#  ('Design Center Linz', 1),
#  ('Devonshire Park International Tennis Centre', 1),
#  ('DLTA Complex', 0),
#  ('Domain Tennis Centre', 1),
#  ('DTB-Stutzpunkt', 1),
#  ('Dubai Duty Free Tennis Stadium', 1),
#  ('Edgbaston Priory Club', 1),
#  ('Ehime Prefectural Sports Complex', 1),
#  ('El Club el Carmel', 1),
#  ('El Recinto Ferial Casa de Campo', 0),
#  ('Elite Tennis Club', 1),
#  ('Emilio Sanchez Academy', 1),
#  ('Emirates Arena', 1),
#  ('EPG Arena', 1),
#  ('Estadio de la Cartuja', 1),
#  ('Estadio Espanol Chiguayante', 1),
#  ('Estadio German Becker', 1),
#  ('Estadio Mario Alberto Kempes', 1),
#  ('Estadio Paradisus Cancun Quintana Roo', 1),
#  ('Etihad Arena', 1),
#  ('Europe Tennis Center', 0),
#  ('Eurosporting Cordenons', 0),
#  ('Eve Zimmermann Tennis Center', 0),
#  ('Family Circle Tennis Center', 0),
#  ('Fangcun Tennis Sports Center', 0),
#  ('Farum Arena', 0),
#  ('Federacion Nacional De Tenis', 0),
#  ('Fes Country Club', 0),
#  ('Fiera Milano stadium', 0),
#  ('Fitzerald Tennis Center Rock Creek Park', 1),
#  ('Fly Palmy Arena', 0),
#  ('Forestmeadows Tennis Center', 1),
#  ('Formula Tennisa Lakhta', 0),
#  ('Foro Italico', 1),
#  ('Forte Village Resort', 1),
#  ('Forus Tenniscenter', 0),
#  ('Francesco Guzzini Recanati Tennis Club', 1),
#  ('Francoise Savatier', 1),
#  ('Franklin Creek Tennis Center', 1),
#  ('Garanti Koza Arena', 1),
#  ('Garikula Tennis Club', 0),
#  ('George P Mitchell 40 Tennis Center', 1),
#  ('Georgia Gwinnett', 1),
#  ('Gerry Weber Stadium', 1),
#  ('Gezira Sporting Club', 1),
#  ('Good To Great Tennis Academy', 0),
#  ('Goodfriend Indoor Tennis Center', 1),
#  ('Graciosa Country Club', 1),
#  ('Greater Midland Tennis Center', 1),
#  ('Green Tennis Plaza', 0),
#  ('Guangzhou Development District International Tennis School', 1),
#  ('Guangzhou Nansha International Tennis Center', 1),
#  ('Guangzhou Tianhe Sports Center', 1),
#  ('Guayaquil Tennis Club', 1),
#  ('Hacienda Chicureo', 1),
#  ('Hakons Hall', 1),
#  ('Hala Na Skarpie', 0),
#  ('Hala Ricany', 1),
#  ('Halle Tony Garnier', 1),
#  ('Hamburger Tennis Verband e.V', 1),
#  ('Hard Rock Stadium', 1),
#  ('Headington Family Tennis Center', 1),
#  ('Helikon Teniszcentrum', 0),
#  ('Henan Provincial Sports Centre Stadium', 1),
#  ('Hengqin International Tennis Center Zhuhai', 1),
#  ('Hengqin Tennis Center', 1),
#  ('Hilary J. Boone Tennis Center', 1),
#  ('Hilton DFW Lakes', 0),
#  ('Hiroshima Regional Park', 0),
#  ('Holiday Inn Crowne Plaza Hotel Asheville', 0),
#  ('Hollyburn Country Club', 1),
#  ('Hot Springs Tennis Center', 1),
#  ('Hotel Racquet Cuernavaca', 1),
#  ('House of Sports', 1),
#  ('Hurd Tennis Center', 1),
#  ('I. Czech Lawn Tennis Club Praha', 0),
#  ('Iate Club de Brasilia', 1),
#  ('Ice Palace Krylatskoye', 1),
#  ('Ilkley Lawn Tennis and Squash Club', 1),
#  ('ILT Stadium', 1),
#  ('Impact Arena', 1),
#  ('Inacua Malaga', 1),
#  ('Inalpi Arena', 1),
#  ('Indian Wells Tennis Garden', 1),
#  ('Indianapolis Tennis Center', 0),
#  ('International Tennis Center', 1),
#  ('International Tennis Hall of Fame', 1),
#  ('Israel Tennis Center', 1),
#  ('Istanbul Tennis Center', 1),
#  ('Istiklol Tennis Club', 1),
#  ('Jacobs Pavilion at Nautica', 1),
#  ('Jan Group Arena', 1),
#  ('JC Ferrero Equelite Sport Academy', 1),
#  ('Jinwol International Tennis Court', 1),
#  ('Jockey Club Brasileiro', 1),
#  ('Jockey Club de Rosario', 1),
#  ('Jockey Club del Peru', 1),
#  ('Jurerê Sports Center', 1),
#  ('Kachreti Golf Resort', 1),
#  ('Kallang Tennis Centre', 1),
#  ('Karnataka State Lawn Tennis Association', 1),
#  ('Kaya Palazzo Belek', 1),
#  ('Khalifa International Tennis & Squash Complex', 1),
#  ('Kindarena', 1),
#  ('Kitzbuehel Tennis Club Sportfeld 2', 0),
#  ('Kooyong Lawn Tennis Club', 1),
#  ('Korty Mosrir', 0),
#  ('Koza World of Sport Complex', 0),
#  ('KPI Park', 0),
#  ('Kungliga Tennishallen', 1),
#  ("L'Agora", 0),
#  ('La Caja Magica', 0),
#  ('Lagardere Paris Racing Club', 1),
#  ('Lanxess Arena', 1),
#  ('Las Hadas Golf & Country Club', 1),
#  ('Launceston Regional Tennis Centre', 1),
#  ('Laurel Oak Country Club', 1),
#  ('Le Central Tennis Club', 1),
#  ('Le Liberte', 0),
#  ('Le Scarabee', 1),
#  ('Legia Tenis & Golf', 1),
#  ('Les Arenes de Metz', 1),
#  ('Liberec Tennis Club', 1),
#  ("Ligue d'Alsace de Tennis", 1),
#  ('Limak Arcadia Sport Resort', 1),
#  ('Lindner Family Tennis Center', 0),
#  ('Linzer Sporthalle', 1),
#  ('Liuzhou Tennis Center', 0),
#  ('Ljubicic Tennis Academy', 1),
#  ('Lotto Arena', 1),
#  ('Louisville Boat Club', 0),
#  ('LSU', 1),
#  ('LTP Tennis Mount Pleasant', 1),
#  ('LTTC Rot-Weiss', 0),
#  ('LTV 1899', 1),
#  ('Luzhniki Olympic Complex', 1),
#  ('Lyon Tennis Club', 1),
#  ('Lyttos Sportscenter', 0),
#  ('Madrid Arena', 0),
#  ('Mamushidani Tennis Courts, Keio University', 1),
#  ('Manquehue Sports Club', 1),
#  ('Manzanillo', 1),
#  ('Megasaray Tennis Academy', 1),
#  ('Melbourne Park', 1),
#  ('Mhalunge Balewadi Tennis Complex', 1),
#  ('Miki Disaster Management Park', 1),
#  ('Mini Stadium', 0),
#  ('Monte-Carlo Country Club', 1),
#  ('Montreux Tennis Club', 1),
#  ('Mouratoglou Tennis Academy', 1),
#  ('MTTC Iphitos e.V.', 1),
#  ('Multisport Sports Club', 1),
#  ('Multiversum Schwechat', 0),
#  ('Murcia Tennis Club 1919', 1),
#  ('Nacional', 1),
#  ('Nacionalni Trening Centar Teniskog', 1),
#  ('Nanchang International Tennis Center', 0),
#  ('National Bank Tennis Hub @ West St Paul', 1),
#  ('National Sport Center Nanchang', 1),
#  ('National Taiwan University Sports Center', 1),
#  ('National Tennis Center', 5),
#  ('National Tennis Center (Beeline Arena)', 1),
#  ('National Tennis Centre', 3),
#  ('National Tennis Centre Lielupe', 1),
#  ('Nemzeti Edzes Kozpont', 1),
#  ('Netaji Indoor Stadium', 0),
#  ('New Country Tennis Academy', 1),
#  ('New Sport Palace', 0),
#  ('Newport Beach Tennis Club', 1),
#  ('Nice Lawn Tennis Club', 2),
#  ('Ningbo Tennis Center of WTA Ningbo, China w42', 1),
#  ('North-West University Tennis Complex', 1),
#  ('Nottingham Tennis Centre', 1),
#  ('NSW Tennis Centre', 1),
#  ('NTC Arena', 0),
#  ('O2 Arena', 1),
#  ('OCBC Arena', 1),
#  ('Ohio State University', 1),
#  ('Ohio State University GC', 0),
#  ('Ohio State Varsity Tennis Center', 1),
#  ('Olme Sport', 1),
#  ('Olympic Park Tennis Center', 1),
#  ('Olympic Tennis Courts', 1),
#  ('Olympic Tennis School', 1),
#  ('Omega Sport Center', 1),
#  ('OMNI LA COSTA RESORT & SPA', 1),
#  ('Optics Valley International Tennis Center', 1),
#  ('Oslo Tennis Arena', 0),
#  ('Osten & Victor Alberta Tennis Centre', 1),
#  ('Ostravar Arena', 1),
#  ('OWL Arena', 0),
#  ('Pabellon Municipal Fuente San Luis', 0),
#  ('Padiglione Conza', 1),
#  ('Pakistan Sports Complex', 1),
#  ('Pala Alpitour', 1),
#  ('Palacio de Deportes Jose Maria Martin Carpena', 0),
#  ('Palais Des Sport', 1),
#  ('Palais des Sports', 1),
#  ('Palais des sports de Beaublanc', 1),
#  ('Palais des sports de Gerland', 1),
#  ('Palais Des Sports De Gerland', 0),
#  ('Palais des Sports de Marseille', 1),
#  ('Palais des sports de Pau', 1),
#  ('Palais des Sports de Pau', 0),
#  ('Palais des Sports Orleans', 0),
#  ('Palalido Allianz Cloud', 0),
#  ('PalaNorda', 1),
#  ('Palasport', 1),
#  ('Palasport Biella', 0),
#  ('Palazzetto dello Sport', 1),
#  ('Palexpo', 1),
#  ('Palm Hills Sports Club', 0),
#  ('Palmira Tennis Club', 1),
#  ("Parc De La TeTe D'or", 1),
#  ('Parc ded Sports de Marville', 1),
#  ('Parc des Expositions Quimper Cornouaille', 1),
#  ('Park Mladen Stojanovic', 1),
#  ('Parque Distrital de Raquetas', 1),
#  ('Parque Olimpico do Rio de Janeiro', 1),
#  ('Parque Parota', 1),
#  ('Payne Park Tennis Facility', 1),
#  ('Pearson Automotive Tennis Club', 1),
#  ('Penina Hotel & Golf Resort', 1),
#  ('Playford City Tennis Centre', 1),
#  ('Playford Tennis Centre', 1),
#  ("Poliesportiu d'Andorra", 1),
#  ('Porsche-Arena', 0),
#  ('Porsche Arena', 1),
#  ('Pörtschach Werzer Arena', 1),
#  ('President Tennis Club', 1),
#  ('Public Security Officers Club', 1),
#  ('Qi zhong Forest Sports City Arena', 1),
#  ('Qi Zhong Tennis Center', 1),
#  ('Queensland Tennis Centre', 1),
#  ('Racket Club, Argentina', 1),
#  ('Racquet Club of the South', 0),
#  ('Rafa Nadal Academy', 1),
#  ('Rakiura Resort', 1),
#  ('Rama Gardens Hotel', 0),
#  ('Raquet Village', 1),
#  ('Real Club de Tenis Barcelona', 1),
#  ('Real Club de Tenis Betis', 1),
#  ('Rebsamen Tennis Center', 1),
#  ('Rice Stadium (Brian Patterson Sports Performance Center)', 1),
#  ('Rio Tennis Academy', 1),
#  ('River Oaks Country Club', 1),
#  ('Rixos Premium Belek', 0),
#  ('Robson Tennis Center', 1),
#  ('Rochusclub', 1),
#  ('Romai Tennis Academy', 0),
#  ('Rome Tennis Center', 1),
#  ('Rome Tennis Center at Berry College', 1),
#  ('Rotterdam Ahoy', 1),
#  ('Roy Emerson Arena', 1),
#  ('Royal Arena', 1),
#  ('Royal Primerose Tennis Club', 0),
#  ('Royal SC Tennis', 1),
#  ('Royal Stage', 0),
#  ('Royal Tennis Club de Marrakech', 1),
#  ('RT Torax Arena', 1),
#  ('Sala Polivalenta Craiova', 0),
#  ('Sala Polivalenta Piatra Neamt', 0),
#  ('Salinas Golf & Tennis Club', 1),
#  ('Salle Collete-Benson', 0),
#  ('Salle Omnisport de Rades', 1),
#  ('Salle Steredenn', 1),
#  ('Salzburg Tennis Club', 1),
#  ('San Jose State University Tennis Center', 0),
#  ('San José State University Tennis Center', 1),
#  ('Sanchez-Casal Tennis Academy', 1),
#  ('Santa Catarina Tennis Federation', 0),
#  ('Santo Domingo Tennis Club La Bocha', 0),
#  ('Sarasota Sports Club', 1),
#  ('SC Ostrava', 1),
#  ('SDAT Tennis Stadium', 1),
#  ('SEB Arena', 0),
#  ('Seoul Olympic Park Tennis Center', 1),
#  ('Shenzhen Bay Sports Center', 1),
#  ('Shenzhen International Tennis Center', 0),
#  ('Shenzhen Longgang Sports Center', 1),
#  ('Shenzhen Luohu Tennis Centre', 1),
#  ('Sheraton Buganvilias Resort and Convention Center', 1),
#  ('Shlomo Group Arena', 1),
#  ('Shree Shiv Chhatrapati Sports Complex', 1),
#  ('Siauliai Tennis Academy', 1),
#  ('Sibur Arena', 1),
#  ('Sichuan International Tennis Center', 1),
#  ('Sid And Hazel Dillon Tennis Center', 1),
#  ('Singapore Indoor Stadium', 1),
#  ('Singapore Sports Hub', 0),
#  ('Skanes Family Hotel Monastir', 0),
#  ('SKT Sopot', 1),
#  ('Sobeys Stadium', 1),
#  ('Sociedade Hipica de Campinas', 1),
#  ('Solano Community College', 1),
#  ('Solano Community College Tennis Center', 1),
#  ('Sparta Prague Tennis Complex', 1),
#  ('Spo1 Park', 1),
#  ('Sport Center Visnjik (Clay)', 1),
#  ('Sport Social Club', 1),
#  ('Sportaktivpark Bad Waltersdorf', 1),
#  ('Sporting Club de Tenis Valencia', 0),
#  ('Sporting Club Verona', 1),
#  ('Sporting Milano 3', 0),
#  ('Sporting Poseidon', 1),
#  ('Sportingclub Bokkeduinen', 0),
#  ('Sportpark Ismaning', 0),
#  ('Sports Center Salata', 0),
#  ('Spot - Salle Jean Burger', 1),
#  ('ŠRC MARINA PORTOROŽ', 0),
#  ('St. Jakobshalle Basel', 1),
#  ('Stade Iga', 1),
#  ('Stade Pierre-de-Coubertin', 1),
#  ('Stade Roland Garros', 0),
#  ('Stade Toulousain Tennis Club', 0),
#  ('Stadium Goran Ivanisevic in ITC Stella Maris', 1),
#  ('Stan Sheriff Center', 1),
#  ('Stanford Taube Tennis Center', 1),
#  ('Steffi-Graf Stadium', 1),
#  ('Styslinger Altec Tennis Complex', 1),
#  ('Sud de France Arena', 1),
#  ('Swiss Tennis Arena', 0),
#  ('SYMA Sports and Conference Centre', 1),
#  ('T Bar M Racquet Club', 1),
#  ('Taipei Arena', 0),
#  ('Taipei Tennis Center', 0),
#  ('Tali Tennis Center', 1),
#  ('Tampereen Tenniskeskus Oy', 1),
#  ('Tashkent Tennis Centreake', 1),
#  ('Taube Tennis Stadium', 1),
#  ('TC Bad Homburg', 1),
#  ('TC GM Sports Anif', 1),
#  ('TC Ismaning', 1),
#  ('TC Rüppurr', 1),
#  ('TC RW-Troisdorf e.V', 1),
#  ('TC Weissenhof, Stuttgart', 1),
#  ('Tcja Saint-Malo', 1),
#  ('TED Tenis Eskrim Dagcilik Spor Kulubu', 1),
#  ('Tel Aviv International Convention Center', 1),
#  ('Tenis Centar Firule', 1),
#  ('Tenis Centar Maksimir', 1),
#  ('Tenis Club Argentino', 1),
#  ('Tenis Club Crvena Zvezda', 1),
#  ('Tenis Club IDU', 0),
#  ('Tenis Club Parma', 1),
#  ('Tênis Clube de Santos', 1),
#  ('TENIS ESKRIM DAGCILIK KULÜBÜ', 0),
#  ('Teniski Klub Split', 1),
#  ('Tenisovy Klub Prostejov', 1),
#  ('Tennis Academy El Cortijo Club De Campo', 1),
#  ('Tennis Academy SET', 1),
#  ('Tennis Center at Crandon Park', 1),
#  ('Tennis Center Novak', 1),
#  ('Tennis Center, Roncaddizza', 1),
#  ('Tennis Centre Portoroz', 0),
#  ('Tennis Club "Tennispark"', 1),
#  ('Tennis Club 1.FCN', 1),
#  ('Tennis Club Cagliari', 0),
#  ('Tennis Club de Avenir Sportif de la Marsa', 1),
#  ('Tennis Club de Geneve', 0),
#  ('Tennis Club de Strasbourg', 1),
#  ('Tennis Club de Troyes', 1),
#  ('Tennis Club De Tunis', 1),
#  ('Tennis Club Dinamo', 1),
#  ('Tennis Club du Stade-Lausanne', 0),
#  ('Tennis Club Gaiba - Gaibledon', 1),
#  ('Tennis Club Garden', 1),
#  ('Tennis Club Izida', 1),
#  ('Tennis Club Kastela', 1),
#  ('Tennis Club Lido Lugano', 0),
#  ('Tennis Club Lillois Lille Metropole', 0),
#  ('Tennis Club Lokomotiv', 0),
#  ('Tennis Club Mostar', 0),
#  ('Tennis Club Napoli', 0),
#  ('Tennis Club Ortisei', 1),
#  ('Tennis Club Pamira', 1),
#  ('Tennis Club Perugia', 1),
#  ('Tennis Club Porto Rose', 1),
#  ('Tennis Club Roseto', 1),
#  ('Tennis Club Rot Weiss Troisdorf E. V.', 1),
#  ('Tennis Club Ruppurr 1929 e. V.', 1),
#  ('Tennis Club Saint-Brieuc', 1),
#  ('Tennis Club Saint Tropez', 1),
#  ('Tennis Club Sparta Praha', 0),
#  ('Tennis Club Todi 1971', 1),
#  ('Tennis Club Triestino', 2),
#  ('Tennis Club Tulln', 1),
#  ('Tennis Club Weissenhof', 1),
#  ('Tennis Courts of the SW University Neofit Rilski', 1),
#  ('Tennis Interieur Rene Verrier', 1),
#  ('Tennis Intérieur René Verrier', 1),
#  ('Tennis Palladio 98', 0),
#  ('Tennis Sanremo', 1),
#  ('Tennis Sporting Club de Cassis Les Gorguettes', 1),
#  ('Tennis St-Luc - Les Loisirs De Granby', 1),
#  ('Tennisclub Heilbronn am Trappensee', 1),
#  ('Tennisclub Zug', 1),
#  ("The Boar's Head Sports Club", 1),
#  ('The Drive', 1),
#  ('The Lawn Tennis Association of Thailand', 1),
#  ('The National Tennis Development Center', 0),
#  ('The O2', 1),
#  ('The Phoenix Country Club', 2),
#  ("The Queen's Club", 1),
#  ('The Queen’s Club', 1),
#  ('The Queens Club', 1),
#  ('The Racquet Club of Memphis', 1),
#  ('The Tennis Center at College Park', 1),
#  ('The Thoreau Club', 0),
#  ('Tianjin Tuanbo International Tennis Center', 1),
#  ('Tiburon Peninsula Club', 1),
#  ('Tips Arena Linz', 1),
#  ('Tiriac Stadium', 1),
#  ('Tivoli Tennis Center', 1),
#  ('TK As Timok', 0),
#  ('TK Magnet', 1),
#  ('TK Slovan Bratislava', 1),
#  ('TK Sparta Praha', 1),
#  ('TK Spoje Praha', 1),
#  ('Tokyo Metropolitan Gymnasium', 1),
#  ('TOP SEED TENNIS CLUB', 1),
#  ('Toto Hakriya Ashdod Arena', 1),
#  ('True Arena Hua Hin', 2),
#  ('TTF Istanbul Tenis Merkezi', 1),
#  ('Tucumán Lawn Tennis Club', 1),
#  ('Ty Tucker Tennis Center', 0),
#  ('Uber Arena', 0),
#  ('Unipol Arena', 0),
#  ('University of Michigan Varsity Tennis Center', 1),
#  ('USTA Billie Jean King National Tennis Center', 0),
#  ('USTA National Campus', 1),
#  ('Utilita Arena Birmingham', 1),
#  ('Utsubo Tennis Center', 1),
#  ('Valletta Cambiaso ASD', 1),
#  ('Varazdin Arena', 1),
#  ('Vendéspace', 1),
#  ('Victoria Park Tennis Court', 1),
#  ('Victoria Park Tennis Stadium', 1),
#  ('Villa Primrose', 1),
#  ('Villa Reale Tennis Monza', 1),
#  ('Vitality Slezsko', 1),
#  ('Wake Forest Tennis Center', 1),
#  ('Wake Forest University Tennis Complex', 0),
#  ('Warszawianka Tennis Centre', 1),
#  ('Westwood Country Club', 1),
#  ('Wien, Wiener Stadthalle', 0),
#  ('Winners Sports Club', 1),
#  ('Winnipeg Lawn Tennis Club', 1),
#  ('Wojska Polskiego', 1),
#  ('Wuxi International Tennis Center', 1),
#  ('XS Tennis Village', 1),
#  ('Yang-Ming Tennis Centre', 1),
#  ('Yokkaichi Tennis Center', 1),
#  ('Yucatan Country Club', 1),
#  ('Zayed Sports City International Tennis Centre', 1)]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#                                       complex_name  venue_count
# 0                          A.S.D. Tennis Club Como            1
# 1                                      AAJB Tennis            1
# 2                             Abama Tennis Academy            1
# 3                             Academy Zhangjiagang            1
# 4                 Acapulco Princess Mundo Imperial            0
# ..                                             ...          ...
# 629                              XS Tennis Village            1
# 630                        Yang-Ming Tennis Centre            1
# 631                        Yokkaichi Tennis Center            1
# 632                           Yucatan Country Club            1
# 633  Zayed Sports City International Tennis Centre            1
#
# [634 rows x 2 columns]

# %% [markdown]
# 3)	Get details of venues in a specific country (e.g., Chile)

# %%
sql_query = """Select * from venues_table where venue_country_name = 'Chile'"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('sr:complex:705',
#   'sr:venue:70045',
#   'Cancha Central',
#   'Santiago',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('sr:complex:11769',
#   'sr:venue:67863',
#   'Cancha 3',
#   'Temuco',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('sr:complex:33492',
#   'sr:venue:35806',
#   'Court 5',
#   'Vina del Mar',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('sr:complex:50605',
#   'sr:venue:76925',
#   'Court Jaime Fillol',
#   'Santiago',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('sr:complex:57188',
#   'sr:venue:57194',
#   'Cancha 2',
#   'Concepcion',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('sr:complex:62419',
#   'sr:venue:57598',
#   'Cancha 11',
#   'Santiago',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('sr:complex:63409',
#   'sr:venue:66901',
#   'Cancha 3',
#   'Coquimbo',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('sr:complex:69183',
#   'sr:venue:77493',
#   'Cancha 3',
#   'Concepcion',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('sr:complex:73997',
#   'sr:venue:74005',
#   'Court 3',
#   'Antofagasta',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('sr:complex:75070',
#   'sr:venue:75120',
#   'Grandstand',
#   'Colina',
#   'Chile',
#   'CHL',
#   'America/Santiago'),
#  ('sr:complex:82223',
#   'sr:venue:82231',
#   'C4 Skechers',
#   'Santiago',
#   'Chile',
#   'CHL',
#   'America/Santiago')]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#           complex_id        venue_id          venue_name venue_city_name  \
# 0     sr:complex:705  sr:venue:70045      Cancha Central        Santiago
# 1   sr:complex:11769  sr:venue:67863            Cancha 3          Temuco
# 2   sr:complex:33492  sr:venue:35806             Court 5    Vina del Mar
# 3   sr:complex:50605  sr:venue:76925  Court Jaime Fillol        Santiago
# 4   sr:complex:57188  sr:venue:57194            Cancha 2      Concepcion
# 5   sr:complex:62419  sr:venue:57598           Cancha 11        Santiago
# 6   sr:complex:63409  sr:venue:66901            Cancha 3        Coquimbo
# 7   sr:complex:69183  sr:venue:77493            Cancha 3      Concepcion
# 8   sr:complex:73997  sr:venue:74005             Court 3     Antofagasta
# 9   sr:complex:75070  sr:venue:75120          Grandstand          Colina
# 10  sr:complex:82223  sr:venue:82231         C4 Skechers        Santiago
#
#    venue_country_name venue_country_code    venue_timezone
# 0               Chile                CHL  America/Santiago
# 1               Chile                CHL  America/Santiago
# 2               Chile                CHL  America/Santiago
# 3               Chile                CHL  America/Santiago
# 4               Chile                CHL  America/Santiago
# 5               Chile                CHL  America/Santiago
# 6               Chile                CHL  America/Santiago
# 7               Chile                CHL  America/Santiago
# 8               Chile                CHL  America/Santiago
# 9               Chile                CHL  America/Santiago
# 10              Chile                CHL  America/Santiago

# %% [markdown]
# 4)	Identify all venues and their timezones

# %%
sql_query = """SELECT 
    venue_name,
    venue_city_name,
    venue_country_name,
    venue_timezone
FROM 
    venues_table;"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('Cancha Central', 'Santiago', 'Chile', 'America/Santiago'),
#  ('Court One', 'Seville', 'Spain', 'Europe/Madrid'),
#  ('TC Dynamo', 'Saint Petersburg', 'Russia', 'Europe/Moscow'),
#  ('Campo 8', 'Oeiras', 'Portugal', 'Europe/Lisbon'),
#  ('Court 2', 'Ostrava', 'Czechia', 'Europe/Prague'),
#  ('Table 8', 'Varazdin', 'Croatia', 'Europe/Zagreb'),
#  ('Court 3', 'Montpellier', 'France', 'Europe/Paris'),
#  ('Court 1', 'Orleans', 'France', 'Europe/Paris'),
#  ('Pista 4', 'Malaga', 'Spain', 'Europe/Madrid'),
#  ('Court 2', 'Sofia', 'Bulgaria', 'Europe/Sofia'),
#  ('Court 1', 'Rouen', 'France', 'Europe/Paris'),
#  ('Cancha 3', 'Temuco', 'Chile', 'America/Santiago'),
#  ('Court 12', 'Lyon', 'France', 'Europe/Paris'),
#  ('Court 2', 'Orleans', 'France', 'Europe/Paris'),
#  ('Campo Arpex', 'Andria', 'Italy', 'Europe/Rome'),
#  ('Court TCSB', 'Saint-Brieuc', 'France', 'Europe/Paris'),
#  ('Court Limak Enerji', 'Istanbul', 'Turkiye', 'Europe/Istanbul'),
#  ('Court 2', 'Stuttgart', 'Germany', 'Europe/Berlin'),
#  ('Centre Court', 'Rotterdam', 'Netherlands', 'Europe/Brussels'),
#  ('Centre Court', 'London', 'England', 'Europe/London'),
#  ('Court 1', 'Bol', 'Croatia', 'Europe/Zagreb'),
#  ('Court 4', 'Monterrey', 'Mexico', 'America/Mexico_City'),
#  ('Court 2', 'Paris', 'France', 'Europe/Paris'),
#  ('Next Gen Arena', 'Umag', 'Croatia', 'Europe/Zagreb'),
#  ('Sportzentrum 3', 'Gstaad', 'Switzerland', 'Europe/Zurich'),
#  ('Court 9', 'Marbella', 'Spain', 'Europe/Madrid'),
#  ('Indoor Court 3', 'Astana', 'Kazakhstan', 'Asia/Almaty'),
#  ('Court 2', 'Canberra', 'Australia', 'Australia/ACT'),
#  ('Court 2', 'Cluj Napoca', 'Romania', 'Europe/Bucharest'),
#  ('Campo 2', 'Genoa', 'Italy', 'Europe/Rome'),
#  ('Centre Court', 'Stuttgart', 'Germany', 'Europe/Berlin'),
#  ('Court 4', 'Copenhagen', 'Denmark', 'Europe/Copenhagen'),
#  ('Court 8', 'Taipei', 'Chinese Taipei', 'Asia/Taipei'),
#  ('Court 4', 'Kallang', 'Singapore', 'Asia/Singapore'),
#  ('Court 2', 'Marseille', 'France', 'Europe/Paris'),
#  ('Court Central', 'Madrid', 'Spain', 'Europe/Madrid'),
#  ('Court 5', 'London', 'England', 'Europe/London'),
#  ('Court Simonne Mathieu', 'Paris', 'France', 'Europe/Paris'),
#  ('Kia Arena', 'Melbourne', 'Australia', 'Australia/Melbourne'),
#  ('Indoor 1', 'Shanghai', 'China', 'Asia/Shanghai'),
#  ('Stadium', 'Winston Salem, NC', 'USA', 'America/New_York'),
#  ('Centre Court', 'Adelaide', 'Australia', 'Australia/South'),
#  ('AJC Grandstand Court', 'Atlanta, GA', 'USA', 'America/New_York'),
#  ('Center 2', 'Newport, Rhode Island', 'USA', 'America/New_York'),
#  ('Court 13', 'Quito', 'Ecuador', 'America/Guayaquil'),
#  ('Center Court', 'Zhuhai', 'China', 'Asia/Shanghai'),
#  ('Court Guillermo Villas',
#   'Buenos Aires',
#   'Argentina',
#   'America/Argentina/Buenos_Aires'),
#  ('Court 3', 'Delray Beach', 'USA', 'America/New_York'),
#  ('Stadium', 'Luxembourg', 'Luxembourg', 'Europe/Paris'),
#  ('Court 2', 'Moscow', 'Russia', 'Europe/Moscow'),
#  ('Court 9', 'Osaka', 'Japan', 'Asia/Tokyo'),
#  ('Court 7', 'Wuhan', 'China', 'Asia/Shanghai'),
#  ('Court 7', 'Guangzhou', 'China', 'Asia/Shanghai'),
#  ('Show Court 1', 'Sydney', 'Australia', 'Australia/Sydney'),
#  ('Indoor C2', 'Hong Kong', 'Hong Kong, China', 'Asia/Hong_Kong'),
#  ('Indoor 1', 'Tianjin', 'China', 'Asia/Shanghai'),
#  ('Indoor 2', 'Tashkent', 'Uzbekistan', 'Asia/Tashkent'),
#  ('Diamond', 'Beijing', 'China', 'Asia/Shanghai'),
#  ('Court 9', 'Osaka', 'Japan', 'Asia/Tokyo'),
#  ('Court 5', 'Copenhagen', 'Denmark', 'Europe/Copenhagen'),
#  ('Court G', 'New Haven, CT', 'USA', 'America/New_York'),
#  ('Cashmere Grandstand', 'Toronto, ON', 'Canada', 'Canada/Eastern'),
#  ('Court 10', 'Cincinnati, OH', 'USA', 'America/New_York'),
#  ('Indoor Court 1', 'Strasbourg', 'France', 'Europe/Paris'),
#  ('Indoor 6', 'Birmingham', 'England', 'Europe/London'),
#  ('Court 9', 'Marrakech', 'Morocco', 'Africa/Casablanca'),
#  ('Court 5', 'Nuremberg', 'Germany', 'Europe/Berlin'),
#  ('Court 12', 'Eastbourne', 'England', 'Europe/London'),
#  ('Practice Court 1', 'Prague', 'Czechia', 'Europe/Prague'),
#  ('Grandstand 4', 'Doha', 'Qatar', 'Asia/Qatar'),
#  ('Court 7', 'Monterrey', 'Mexico', 'America/Mexico_City'),
#  ('Central', 'Rio de Janeiro', 'Brazil', 'Brazil/East'),
#  ('Cancha 5', 'Acapulco', 'Mexico', 'America/Mexico_City'),
#  ('Court 20', 'Madrid', 'Spain', 'Europe/Madrid'),
#  ('Althea Gibson Club Court', 'Charleston, SC', 'USA', 'America/New_York'),
#  ('Court 6', 'Basel', 'Switzerland', 'Europe/Zurich'),
#  ('Grandstand', 'New York, NY', 'USA', 'America/New_York'),
#  ('Court 3', 'Bangkok', 'Thailand', 'Asia/Bangkok'),
#  ('Next Gen Court', 'Vienna', 'Austria', 'Europe/Vienna'),
#  ('Center Court', 'Shenzhen', 'China', 'Asia/Shanghai'),
#  ('Ct 15', 'Brisbane', 'Australia', 'Australia/Brisbane'),
#  ('Head Gravity Court', 'Hamburg', 'Germany', 'Europe/Berlin'),
#  ('ShowCourt', 'Stockholm', 'Sweden', 'Europe/Stockholm'),
#  ('Court Stadtwerke', 'Kitzbuhel', 'Austria', 'Europe/Vienna'),
#  ('Stadion', 'Halle', 'Germany', 'Europe/Berlin'),
#  ('Indoor 3', 'Nottingham', 'England', 'Europe/London'),
#  ('Centre Court', 'Bastad', 'Sweden', 'Europe/Stockholm'),
#  ('Court 12', 'Palermo', 'Italy', 'Europe/Rome'),
#  ('Court 4', 'Geneva', 'Switzerland', 'Europe/Zurich'),
#  ('Court 4', "'s-Hertogenbosch", 'Netherlands', 'Europe/Brussels'),
#  ('Court 9', 'Bucharest', 'Romania', 'Europe/Bucharest'),
#  ('Court 2', 'Munich', 'Germany', 'Europe/Berlin'),
#  ('Pista Andres Gimeno', 'Barcelona', 'Spain', 'Europe/Madrid'),
#  ('MKG 2', 'Cologne', 'Germany', 'Europe/Berlin'),
#  ('Indoor Court 19', 'Hiroshima', 'Japan', 'Asia/Tokyo'),
#  ('Court 23', 'Lyon', 'France', 'Europe/Paris'),
#  ('Center Court', 'Chengdu', 'China', 'Asia/Shanghai'),
#  ('Backer Mckenzie', 'Tiburon', 'USA', 'America/Los_Angeles'),
#  ('Cancha Central', 'Bogota', 'Colombia', 'America/Bogota'),
#  ('Swiss Tennis Arena', 'Biel', 'Switzerland', 'Europe/Zurich'),
#  ('Centre Court', 'Shenzhen', 'China', 'Asia/Shanghai'),
#  ('Yang-Ming Tennis Center - Court 8',
#   'Kaohsiung',
#   'Chinese Taipei',
#   'Asia/Taipei'),
#  ('Court A', 'Portoroz', 'Slovenia', 'Europe/Ljubljana'),
#  ('Grandstand', 'Mallorca', 'Spain', 'Europe/Madrid'),
#  ('Practice Court 1', 'Belgrade', 'Serbia', 'Europe/Belgrade'),
#  ('Indoor 2', 'Almaty', 'Kazakhstan', 'Asia/Almaty'),
#  ('Indoors', 'Campinas', 'Brazil', 'Brazil/East'),
#  ('Court 3', 'Prague', 'Czechia', 'Europe/Prague'),
#  ('Steffi Graf Stadion', 'Berlin', 'Germany', 'Europe/Berlin'),
#  ('Grand Court', 'Budapest', 'Hungary', 'Europe/Budapest'),
#  ('Table 1', 'Tokyo', 'Japan', 'Asia/Tokyo'),
#  ('Pista Pablo Andujar', 'Valencia', 'Spain', 'Europe/Madrid'),
#  ('Eve Zimmerman Tennis Center - Court 3',
#   'Stockton, CA',
#   'USA',
#   'America/Los_Angeles'),
#  ('Pista 2', 'Barcelona', 'Spain', 'Europe/Madrid'),
#  ('Court 5', 'Vina del Mar', 'Chile', 'America/Santiago'),
#  ('Estadio Brugal',
#   'Santo Domingo',
#   'Dominican Republic',
#   'America/Santo_Domingo'),
#  ('Court 3', 'Antwerp', 'Belgium', 'Europe/Brussels'),
#  ('Court 1', 'Ismaning', 'Germany', 'Europe/Berlin'),
#  ('Rogers Court', 'Calgary', 'Canada', 'America/Edmonton'),
#  ('Indoor court 9', 'Ningbo', 'China', 'Asia/Shanghai'),
#  ('Court 17', 'Lima', 'Peru', 'America/Lima'),
#  ('Court 5', 'Liuzhou', 'China', 'Asia/Shanghai'),
#  ('Brenda Meyers Court', 'Charlottesville, VA', 'USA', 'America/New_York'),
#  ('Court 10', 'Guayaquil', 'Ecuador', 'America/Guayaquil'),
#  ('Court Annexe', 'Mouilleron-le-Captif', 'France', 'Europe/Paris'),
#  ('Cancha 15', 'Montevideo', 'Uruguay', 'America/Montevideo'),
#  ('Stadium', 'Knoxville, TN', 'USA', 'America/New_York'),
#  ('Court 2', 'Limoges', 'France', 'Europe/Paris'),
#  ('Court C', 'Kobe', 'Japan', 'Asia/Tokyo'),
#  ('KSLTA Signature - Kingfisher Stadium',
#   'Bangalore',
#   'India',
#   'Asia/Kolkata'),
#  ('Cancha 7', 'Buenos Aires', 'Argentina', 'America/Argentina/Buenos_Aires'),
#  ('The Goldenberg Court', 'Champaign, IL', 'USA', 'America/Chicago'),
#  ('Indoor 2', 'Houston, TX', 'USA', 'America/Chicago'),
#  ('Court 5', 'Pune', 'India', 'Asia/Kolkata'),
#  ('Via Delle Querce', 'Andria', 'Italy', 'Europe/Rome'),
#  ('Indoor 6', 'Auckland', 'New Zealand', 'Pacific/Auckland'),
#  ('West Court', 'Hobart', 'Australia', 'Australia/Tasmania'),
#  ('Indoor Court 1', 'Columbus, OH', 'USA', 'America/New_York'),
#  ('Centre Court', 'Koblenz', 'Germany', 'Europe/Berlin'),
#  ('Court 8', 'Newport Beach', 'USA', 'America/Los_Angeles'),
#  ('West Park Oval', 'Burnie', 'Australia', 'Australia/Tasmania'),
#  ('Indoor 3', 'Lisbon', 'Portugal', 'Europe/Lisbon'),
#  ('Cancha 3', 'Punta del Este', 'Uruguay', 'America/Montevideo'),
#  ('Tennis Club De Bruz 5', 'Rennes', 'France', 'Europe/Paris'),
#  ('Court 8', 'Launceston', 'Australia', 'Australia/Tasmania'),
#  ('Court 1', 'Hua Hin', 'Thailand', 'Asia/Bangkok'),
#  ('Court Fred Le Bian', 'Quimper', 'France', 'Europe/Paris'),
#  ('Stadium', 'Cleveland, OH', 'USA', 'America/New_York'),
#  ('Infinity Arena', 'Montpellier', 'France', 'Europe/Paris'),
#  ('Cancha 3', 'Cordoba', 'Argentina', 'America/Argentina/Cordoba'),
#  ('Court 2', 'Dallas, TX', 'USA', 'America/Chicago'),
#  ('Temesvari Court', 'Budapest', 'Hungary', 'Europe/Budapest'),
#  ('Court 4', 'Chennai', 'India', 'Asia/Kolkata'),
#  ('Cancha 3', 'Medellin', 'Colombia', 'America/Bogota'),
#  ('Court 5', 'Cherbourg-Octeville', 'France', 'Europe/Paris'),
#  ('Court 2', 'Dubai', 'United Arab Emirates', 'Asia/Dubai'),
#  ('Cancha 2', 'Morelos', 'Mexico', 'America/Mexico_City'),
#  ('PC2', 'Indian Wells', 'USA', 'America/Los_Angeles'),
#  ('Indoors 2', 'Yokohama', 'Japan', 'Asia/Tokyo'),
#  ('Court 3', 'Pau', 'France', 'Europe/Paris'),
#  ('Court 11', 'Shenzhen', 'China', 'Asia/Shanghai'),
#  ('Court 1', 'Phoenix, AZ', 'USA', 'America/Phoenix'),
#  ('Butch Buchholz', 'Miami, FL', 'USA', 'America/New_York'),
#  ('Grandstand Caliente', 'Guadalajara', 'Mexico', 'America/Mexico_City'),
#  ('Campo Estadio', 'Bogota', 'Colombia', 'America/Bogota'),
#  ('Court 14', 'Prague', 'Czechia', 'Europe/Prague'),
#  ('Court 8', 'An-Ning', 'China', 'Asia/Shanghai'),
#  ('Court 3', 'Rabat', 'Morocco', 'Africa/Casablanca'),
#  ('Court 3', 'Madrid', 'Spain', 'Europe/Madrid'),
#  ('Court 11', 'Houston, TX', 'USA', 'America/Chicago'),
#  ('Court 3', 'Budapest', 'Hungary', 'Europe/Budapest'),
#  ('Court CTE', 'Estoril', 'Portugal', 'Europe/Lisbon'),
#  ('Court 3', 'Lyon', 'France', 'Europe/Paris'),
#  ('Colosseum', 'Stuttgart', 'Germany', 'Europe/Berlin'),
#  ('Court 10', 'London', 'England', 'Europe/London'),
#  ('Duygu Aksit Oal', 'Antalya', 'Turkiye', 'Europe/Istanbul'),
#  ('Court 1', 'Lille', 'France', 'Europe/Paris'),
#  ('Pista Carlos Alcaraz', 'Alicante', 'Spain', 'Europe/Madrid'),
#  ('Indoor 1', 'Sophia Antipolis', 'France', 'Europe/Paris'),
#  ('Stadium', 'Taipei', 'Chinese Taipei', 'Asia/Taipei'),
#  ('Altitud (C2)', 'Barletta', 'Italy', 'Europe/Rome'),
#  ('Pista 4', 'Murcia', 'Spain', 'Europe/Madrid'),
#  ('Grandstand', 'Bogota', 'Colombia', 'America/Bogota'),
#  ('Ed Smith Stadium', 'Sarasota', 'USA', 'America/New_York'),
#  ('Grandstand', 'San Luis de Potosi', 'Mexico', 'America/Mexico_City'),
#  ('Court 6', 'Tunis', 'Tunisia', 'Africa/Tunis'),
#  ('Court 6', 'Helsinki', 'Finland', 'Europe/Helsinki'),
#  ('Court 8', 'Gwangju', 'Republic of Korea', 'Asia/Seoul'),
#  ('Court 4', 'Samarkand', 'Uzbekistan', 'Asia/Tashkent'),
#  ('Court 4', 'Heilbronn', 'Germany', 'Europe/Berlin'),
#  ('Court 5', 'Washington, D.C.', 'USA', 'America/New_York'),
#  ('Estadio Pegaso', 'Los Cabos', 'Mexico', 'America/Mexico_City'),
#  ('Court 2', 'Lausanne', 'Switzerland', 'Europe/Zurich'),
#  ('Court 2', 'Karlsruhe', 'Germany', 'Europe/Berlin'),
#  ('Court 3', 'San Jose, CA', 'USA', 'America/Los_Angeles'),
#  ('Court Central', 'Montreal, QC', 'Canada', 'America/Toronto'),
#  ('Indoor 6', 'Vicenza', 'Italy', 'Europe/Rome'),
#  ('Pista Mercedes-Benz', 'Madrid', 'Spain', 'Europe/Madrid'),
#  ('Court 7', 'Fergana', 'Uzbekistan', 'Asia/Tashkent'),
#  ('Indoor 5', 'Blois', 'France', 'Europe/Paris'),
#  ('Court 2', 'Parma', 'Italy', 'Europe/Rome'),
#  ('Indoor Court 4', 'Ilkley', 'England', 'Europe/London'),
#  ('Court 10', 'Bratislava', 'Slovakia', 'Europe/Bratislava'),
#  ('Court 15', 'Milan', 'Italy', 'Europe/Rome'),
#  ('Court 2', 'Recanati', 'Italy', 'Europe/Rome'),
#  ('Court 6', 'New York, NY', 'USA', 'America/New_York'),
#  ('CC', 'Nanchang', 'China', 'Asia/Shanghai'),
#  ('Court 12', 'Zhengzhou', 'China', 'Asia/Shanghai'),
#  ('Court 2', 'Metz', 'France', 'Europe/Paris'),
#  ('Indoor 6', 'Tokyo', 'Japan', 'Asia/Tokyo'),
#  ('Indoor A3', 'Shanghai', 'China', 'Asia/Shanghai'),
#  ('Court 12', 'Seoul', 'Republic of Korea', 'Asia/Seoul'),
#  ('Court 2', 'Tashkent', 'Uzbekistan', 'Asia/Tashkent'),
#  ('Serena Maniva Centre', 'Cordenons', 'Italy', 'Europe/Rome'),
#  ('Capital Group Diamond', 'Beijing', 'China', 'Asia/Shanghai'),
#  ('La Foret 1', 'Orleans', 'France', 'Europe/Paris'),
#  ('Grandstand', 'Florence', 'Italy', 'Europe/Rome'),
#  ('Show Court', 'Linz', 'Austria', 'Europe/Vienna'),
#  ('Tad Taube Court', 'Fairfield, CT', 'USA', 'America/New_York'),
#  ('Luzhniki Stadium', 'Moscow', 'Russia', 'Europe/Moscow'),
#  ('Court 4', 'Ismaning', 'Germany', 'Europe/Berlin'),
#  ('Court 5', 'Playford City', 'Australia', 'Australia/Adelaide'),
#  ('Court 2', 'Eckental', 'Germany', 'Europe/Berlin'),
#  ('Cancha 3', 'Guayaquil', 'Ecuador', 'America/Guayaquil'),
#  ('Allianz Cloud Court', 'Milan', 'Italy', 'Europe/Rome'),
#  ('Court 4', 'Maia', 'Portugal', 'Europe/Lisbon'),
#  ('Court 9', 'Honolulu, HI', 'USA', 'Pacific/Honolulu'),
#  ('Court 2', 'Canberra', 'Australia', 'Australia/ACT'),
#  ('Court Hertz', 'Noumea', 'New Caledonia', 'Pacific/Noumea'),
#  ('Centre Court', 'Melbourne', 'Australia', 'Australia/Melbourne'),
#  ('Court Jaime Fillol', 'Santiago', 'Chile', 'America/Santiago'),
#  ('Campo 2', 'Cagliari', 'Italy', 'Europe/Rome'),
#  ('Court 2', 'Saint Petersburg', 'Russia', 'Europe/Moscow'),
#  ('Cancha Central', 'Cordoba', 'Argentina', 'America/Argentina/Cordoba'),
#  ('Cancha Central', 'Santa Cruz de la Sierra', 'Bolivia', 'America/La_Paz'),
#  ('Court 3', 'Istanbul', 'Turkiye', 'Europe/Istanbul'),
#  ('Court 17', 'Zagreb', 'Croatia', 'Europe/Zagreb'),
#  ('Cancha 4', 'Asuncion', 'Paraguay', 'America/Asuncion'),
#  ('Teren 10', 'Zajecar', 'Serbia', 'Europe/Belgrade'),
#  ('Pista 14', 'Castellon', 'Spain', 'Europe/Madrid'),
#  ('Court 9', 'Prague', 'Czechia', 'Europe/Prague'),
#  ('Center Court', 'Roehampton', 'England', 'Europe/London'),
#  ('Center Court', 'Lexington, KY', 'USA', 'America/New_York'),
#  ('Grandstand', 'Zhengzhou', 'China', 'Asia/Shanghai'),
#  ('Court 2', 'Bad Homburg', 'Germany', 'Europe/Berlin'),
#  ('Court 15', 'Rome', 'Italy', 'Europe/Rome'),
#  ('Court 5', 'Sardinia', 'Italy', 'Europe/Rome'),
#  ('Court 2', 'Antalya', 'Turkiye', 'Europe/Istanbul'),
#  ('ADCB Court 1', 'Abu Dhabi', 'United Arab Emirates', 'Asia/Dubai'),
#  ('Court 8', 'Potchefstroom', 'South Africa', 'Africa/Johannesburg'),
#  ('Jocker Court', 'Biella', 'Italy', 'Europe/Rome'),
#  ('Cancha 2', 'Concepcion', 'Chile', 'America/Santiago'),
#  ('Center Court', 'Kallang', 'Singapore', 'Asia/Singapore'),
#  ('Court 12', 'Lyon', 'France', 'Europe/Paris'),
#  ('Court 1', 'Parma', 'Italy', 'Europe/Rome'),
#  ('Indoor Ct3', 'Little Rock, AR', 'USA', 'America/Chicago'),
#  ('Central Eupago', 'Porto', 'Portugal', 'Europe/Lisbon'),
#  ('Center Court', 'Perugia', 'Italy', 'Europe/Rome'),
#  ('Center Court', 'Anif', 'Austria', 'Europe/Vienna'),
#  ('Court 12', 'Braunschweig', 'Germany', 'Europe/Berlin'),
#  ('Court 6', 'Iasi', 'Romania', 'Europe/Bucharest'),
#  ('Schoonderbeekbouw Court', 'Amersfoort', 'Netherlands', 'Europe/Brussels'),
#  ('Court 4', 'Todi', 'Italy', 'Europe/Rome'),
#  ('Court 2', 'Gydnia', 'Poland', 'Europe/Warsaw'),
#  ('Stadium CSC', 'Los Cabos', 'Mexico', 'America/Mexico_City'),
#  ('Studenac Arena', 'Umag', 'Croatia', 'Europe/Zagreb'),
#  ('Court 10', 'Cary, NC', 'USA', 'America/New_York'),
#  ('Center Court Giorgi', 'Trieste', 'Italy', 'Europe/Rome'),
#  ('Court 9', 'Trieste', 'Italy', 'Europe/Rome'),
#  ('Court 10', 'Giza', 'Egypt', 'Africa/Cairo'),
#  ('Court 7', 'Charleston, SC', 'USA', 'America/New_York'),
#  ('Sporting 2', 'Barletta', 'Italy', 'Europe/Rome'),
#  ('Court 2', 'Concord, MA', 'USA', 'America/New_York'),
#  ('INDOOR C', 'Liberec', 'Czechia', 'Europe/Prague'),
#  ('Court 3', 'San Marino', 'San Marino', 'Europe/San_Marino'),
#  ('Grandstand', 'Verona', 'Italy', 'Europe/Rome'),
#  ('Indoor 2', 'Luedenscheid', 'Germany', 'Europe/Berlin'),
#  ('Indoor 6', 'Chicago, IL', 'USA', 'America/Chicago'),
#  ('Indoor 2', 'Cleveland, OH', 'USA', 'America/New_York'),
#  ('Indoor 3', 'Warsaw', 'Poland', 'Europe/Warsaw'),
#  ('Court 1', 'Karlsruhe', 'Germany', 'Europe/Berlin'),
#  ('Court 1', 'Banja Luka', 'Bosnia & Herzegovina', 'Europe/Sarajevo'),
#  ('Court 2', 'Cassis', 'France', 'Europe/Paris'),
#  ('Court 11', 'Kiev', 'Ukraine', 'Europe/Kyiv'),
#  ('Pista 3', 'Seville', 'Spain', 'Europe/Madrid'),
#  ('Grandstand', 'Tulln', 'Austria', 'Europe/Berlin'),
#  ('Grand Tarabaya Court', 'Istanbul', 'Turkiye', 'Europe/Istanbul'),
#  ('Cancha 8', 'Quito', 'Ecuador', 'America/Guayaquil'),
#  ('Court 7', 'Szczecin', 'Poland', 'Europe/Warsaw'),
#  ('Court Saint Gregoire 1', 'Rennes', 'France', 'Europe/Paris'),
#  ('Match Court', 'Biel', 'Switzerland', 'Europe/Zurich'),
#  ('Cancha 4', 'Aguascalientes', 'Mexico', 'America/Mexico_City'),
#  ('Court 21', 'Heraklion', 'Greece', 'Europe/Athens'),
#  ('Court 9', 'Bucharest', 'Romania', 'Europe/Bucharest'),
#  ('Indoor 2', 'Braga', 'Portugal', 'Europe/Lisbon'),
#  ('Court 4', 'Ambato', 'Ecuador', 'America/Guayaquil'),
#  ('Court 7', 'Sibiu', 'Romania', 'Europe/Bucharest'),
#  ('Court 2', 'San Diego, CA', 'USA', 'America/Los_Angeles'),
#  ('Centre Court', 'Naples', 'Italy', 'Europe/Rome'),
#  ('Court 3', 'Naples, FL', 'USA', 'America/New_York'),
#  ('Court 6', 'Santa Cruz de Tenerife', 'Spain', 'Europe/Madrid'),
#  ('Tennis Centar Punta', 'Losinj', 'Croatia', 'Europe/Zagreb'),
#  ('Palaintred', 'Bergamo', 'Italy', 'Europe/Rome'),
#  ('Court 4', 'Midland, Michigan', 'USA', 'UTC'),
#  ('Court 1', 'Roanne', 'France', 'Europe/Paris'),
#  ('Centre Court', 'Turin', 'Italy', 'Europe/Rome'),
#  ('Indoor 4', 'Brasilia', 'Brazil', 'Brazil/East'),
#  ('Court 2', 'Manama', 'Bahrain', 'Asia/Bahrain'),
#  ('Indoor Court', 'Bari', 'Italy', 'Europe/Rome'),
#  ('Cancha Vino America', 'Puerto Vallarta', 'Mexico', 'America/Mexico_City'),
#  ('Gencom', 'Forli', 'Italy', 'Europe/Rome'),
#  ('Quadra 2', 'Sao Paulo', 'Brazil', 'America/Sao_Paulo'),
#  ('Court 24', 'Antalya', 'Turkiye', 'Europe/Istanbul'),
#  ('Court 6', 'Angers', 'France', 'Europe/Paris'),
#  ('Court 2', 'Rio de Janeiro', 'Brazil', 'Brazil/East'),
#  ('Court 1', 'Seoul', 'Republic of Korea', 'Asia/Seoul'),
#  ('Grandstand', 'Dallas, TX', 'USA', 'America/Chicago'),
#  ('Central Court', 'Moscow', 'Russia', 'Europe/Moscow'),
#  ('Court 1', 'Las Palmas de Gran Canaria', 'Spain', 'Europe/Madrid'),
#  ('Court 2', 'Split', 'Croatia', 'Europe/Zagreb'),
#  ('Gene Cox Stadium', 'Tallahassee, FL', 'USA', 'America/New_York'),
#  ('Campo 3', 'Turin', 'Italy', 'Europe/Rome'),
#  ('Court 9', 'Istanbul', 'Turkiye', 'Europe/Istanbul'),
#  ('Court B', 'Nonthaburi', 'Thailand', 'Asia/Bangkok'),
#  ('Court 3', 'Roseto Degli Abruzzi', 'Italy', 'Europe/Rome'),
#  ('Cancha 11', 'Santiago', 'Chile', 'America/Santiago'),
#  ('Cancha Santiago Giraldo', 'Pereira', 'Colombia', 'America/Bogota'),
#  ('Indoor 1', 'Lugano', 'Switzerland', 'Europe/Zurich'),
#  ('Court 4', 'Saint-Brieuc', 'France', 'Europe/Paris'),
#  ('Cancha 4', 'Mexico City', 'Mexico', 'America/Mexico_City'),
#  ('Cancha P. Segura', 'Salinas', 'Ecuador', 'America/Guayaquil'),
#  ('Campo 2', 'Sanremo', 'Italy', 'Europe/Rome'),
#  ('Court 13', 'Monte Carlo', 'Monaco', 'Europe/Paris'),
#  ('Court 10', 'Sarasota', 'USA', 'America/New_York'),
#  ('Court 4', 'Ostrava', 'Czechia', 'Europe/Prague'),
#  ('SICEurope Court', 'Rome', 'Italy', 'Europe/Rome'),
#  ('Atlantic Radiology Court', 'Savannah', 'USA', 'America/New_York'),
#  ('Indoor 2', 'Saint Malo', 'France', 'Europe/Paris'),
#  ('Stadium', 'Mauthausen', 'Austria', 'Europe/Vienna'),
#  ('Court Eiffage', 'Aix-en-Provence', 'France', 'Europe/Paris'),
#  ('Court 4', 'Salvador', 'Brazil', 'America/Bahia'),
#  ('COURT 11 OCI INFORMATIQUE', 'Bordeaux', 'France', 'Europe/Paris'),
#  ('Cancha 3', 'Coquimbo', 'Chile', 'America/Santiago'),
#  ('Court 1', 'Shymkent', 'Kazakhstan', 'Asia/Almaty'),
#  ('Court 3', 'Paris', 'France', 'Europe/Paris'),
#  ('Center Court', 'Francavilla al Mare', 'Italy', 'Europe/Rome'),
#  ('B and B Court', 'Troisdorf', 'Germany', 'Europe/Berlin'),
#  ('Court 11', 'Bratislava', 'Slovakia', 'Europe/Bratislava'),
#  ('Indoor 2', 'Orlando, FL', 'USA', 'America/New_York'),
#  ('Prostejov Arena', 'Prostejov', 'Czechia', 'Europe/Prague'),
#  ('Owl Arena', 'Halle', 'Germany', 'Europe/Berlin'),
#  ('Estadio Leonardo Mayer',
#   'Corrientes',
#   'Argentina',
#   'America/Argentina/Cordoba'),
#  ('Centre Court', 'Berlin', 'Germany', 'Europe/Berlin'),
#  ('Court 3', 'Gaiba', 'Italy', 'Europe/Rome'),
#  ('Cancha 3', 'Buenos Aires', 'Argentina', 'America/Argentina/Buenos_Aires'),
#  ('Court 11', 'London', 'England', 'Europe/London'),
#  ('Court 3', 'Malaga', 'Spain', 'Europe/Madrid'),
#  ('Court Amplitude', 'Troyes', 'France', 'US/Pacific'),
#  ('Court 3', 'Salzburg', 'Austria', 'Europe/Vienna'),
#  ('Court 4', 'Contrexeville', 'France', 'Europe/Paris'),
#  ('Court 5', 'Rome', 'USA', 'America/New_York'),
#  ('M5', 'Hamburg', 'Germany', 'Europe/Berlin'),
#  ('Court 4', 'Indianapolis, IN', 'USA', 'America/Indiana/Indianapolis'),
#  ('Center Court', 'Pozoblanco', 'Spain', 'Europe/Madrid'),
#  ('Court 3', 'Tampere', 'Finland', 'Europe/Helsinki'),
#  ('Campo 3', 'San Benedetto', 'Italy', 'Europe/Rome'),
#  ('Court 1', 'Winnipeg', 'Canada', 'America/Chicago'),
#  ('Tramondo Court 2', 'Zug', 'Switzerland', 'Europe/Zurich'),
#  ('Court 7', 'Lexington, KY', 'USA', 'America/New_York'),
#  ('Stadium 6', 'Iasi', 'Romania', 'Europe/Bucharest'),
#  ('Cancha 13', 'Lima', 'Peru', 'America/Lima'),
#  ('Polygon Court', 'West Vancouver', 'Canada', 'America/Vancouver'),
#  ('Indoor Court 2', 'Kozerki', 'Poland', 'Europe/Warsaw'),
#  ('Indoor 2', 'Granby', 'Canada', 'Canada/Eastern'),
#  ('Court 8', 'Prague', 'Czechia', 'Europe/Prague'),
#  ('Court 2', 'Banja Luka', 'Bosnia & Herzegovina', 'Europe/Sarajevo'),
#  ('TC Giussano Indoors 5', 'Como', 'Italy', 'Europe/Rome'),
#  ('Center Court', 'Mallorca', 'Spain', 'Europe/Madrid'),
#  ('Court 4', 'Toulouse', 'France', 'Europe/Paris'),
#  ('Tato Paride Court', 'Bari', 'Italy', 'Europe/Rome'),
#  ('Centre Court', 'Vilnius', 'Lithuania', 'Europe/Vilnius'),
#  ('Court 2', 'Taipei', 'Chinese Taipei', 'Asia/Taipei'),
#  ('Court 4', 'Columbus, OH', 'USA', 'America/New_York'),
#  ('Court Central', 'Villa Maria', 'Argentina', 'America/Argentina/Cordoba'),
#  ('Centre Court', 'Tel Aviv', 'Israel', 'Asia/Jerusalem'),
#  ('Court 8', 'Monastir', 'Tunisia', 'Africa/Tunis'),
#  ('Court 6', 'Saint-Tropez', 'France', 'Europe/Paris'),
#  ('Center Court', 'Busan', 'Republic of Korea', 'Asia/Seoul'),
#  ('Court 2', 'Hamburg', 'Germany', 'Europe/Berlin'),
#  ('Court 3', 'Ortisei', 'Italy', 'Europe/Rome'),
#  ('Estadio', 'Tampico', 'Mexico', 'America/Mexico_City'),
#  ('Center Court', 'Bergamo', 'Italy', 'Europe/Rome'),
#  ('Court Indoor 11', 'Matsuyama', 'Japan', 'Asia/Tokyo'),
#  ('Centre Marcel Dionne', 'Drummondville', 'Canada', 'America/Toronto'),
#  ('Indoor Court 15', 'Yokkaichi', 'Japan', 'Asia/Tokyo'),
#  ('Canary Islands Court', 'Maspalomas', 'Spain', 'Europe/Madrid'),
#  ('Club Nautico Hacoaj - Center Court',
#   'Tigre',
#   'Argentina',
#   'America/Argentina/Buenos_Aires'),
#  ('Indoor 4', 'Piracicaba', 'Brazil', 'America/Sao_Paulo'),
#  ('Court 1', 'Ottignies-Louvain-la-Neuve', 'Belgium', 'Europe/Brussels'),
#  ('Cancha 3', 'Concepcion', 'Chile', 'America/Santiago'),
#  ('Jean Jaures', 'Cherbourg-en-Cotentin', 'France', 'Europe/Paris'),
#  ('Court 3', 'Rome', 'USA', 'America/New_York'),
#  ('Court 3', 'Rovereto', 'Italy', 'Europe/Rome'),
#  ('Estadio Akron', 'Mérida', 'Mexico', 'America/Mexico_City'),
#  ('Grandstand', 'Waco, TX', 'USA', 'America/Chicago'),
#  ('Court 11', 'Austin, TX', 'USA', 'America/Chicago'),
#  ('12BET COURT', 'Birmingham', 'England', 'Europe/London'),
#  ('Pista 3', 'Les Franqueses Del Valles', 'Spain', 'Europe/Madrid'),
#  ('Court 2', 'Girona', 'Spain', 'Europe/Madrid'),
#  ('Court 1', 'Leon', 'Mexico', 'America/Mexico_City'),
#  ('Indoor Court', 'Split', 'Croatia', 'Europe/Zagreb'),
#  ('B&B Court', 'Troisdorf', 'Germany', 'Europe/Berlin'),
#  ('Pista Central', 'La Bisbal D Emporda', 'Spain', 'Europe/Madrid'),
#  ('Table 4', 'Tunis', 'Tunisia', 'Africa/Tunis'),
#  ('Court 3', 'Modena', 'Italy', 'Europe/Rome'),
#  ('Court 1', 'Bloomfield Hills', 'USA', 'UTC'),
#  ('Court 1', 'Nice', 'France', 'Europe/Paris'),
#  ('Pista 4', 'Segovia', 'Spain', 'Europe/Madrid'),
#  ('Estadio Mextenis', 'Los Cabos', 'Mexico', 'America/Mexico_City'),
#  ('Court 4', 'Stanford, CA', 'USA', 'America/Los_Angeles'),
#  ('Court 3', 'Winnipeg', 'Canada', 'America/Chicago'),
#  ('Court 4', 'Barranquilla', 'Colombia', 'America/Bogota'),
#  ('AO Arena', 'Manchester', 'England', 'Europe/London'),
#  ('Indoor 12', 'Zhangjiagang', 'China', 'Asia/Shanghai'),
#  ('Court 7', 'Ljubljana', 'Slovenia', 'Europe/Ljubljana'),
#  ('Indoor Court', 'Guangzhou', 'China', 'Asia/Shanghai'),
#  ('Cancha 2', 'Santa Cruz de la Sierra', 'Bolivia', 'America/La_Paz'),
#  ('Center Court', 'Szczecin', 'Poland', 'Europe/Warsaw'),
#  ('Court 3', 'Antofagasta', 'Chile', 'America/Santiago'),
#  ('Court 3', 'Bad Waltersdorf', 'Austria', 'Europe/Vienna'),
#  ('Court 3', 'Columbus, OH', 'USA', 'America/New_York'),
#  ('Court 4', 'Astana', 'Kazakhstan', 'Asia/Almaty'),
#  ('Court 3', 'Bogota', 'Colombia', 'America/Bogota'),
#  ('St Cyr En Val No.2', 'Orleans', 'France', 'Europe/Paris'),
#  ('Court 2', 'Playford City', 'Australia', 'Australia/Adelaide'),
#  ('Indoor 12', 'Curitiba', 'Brazil', 'Brazil/East'),
#  ('Stadium 1', 'Tampico', 'Mexico', 'America/Mexico_City'),
#  ('Huafa Center Court', 'Zhuhai', 'China', 'Asia/Shanghai'),
#  ('Estadio Paradisus', 'Cancun', 'Mexico', 'America/Mexico_City'),
#  ('Court 3', 'Sofia', 'Bulgaria', 'Europe/Sofia'),
#  ('Court 1', 'Danderyd', 'Sweden', 'Europe/Stockholm'),
#  ('Court C', 'Kobe', 'Japan', 'Asia/Tokyo'),
#  ('Grandstand', 'Colina', 'Chile', 'America/Santiago'),
#  ('Quadra 4', 'Brasilia', 'Brazil', 'Brazil/East'),
#  ('Indoor Court', 'Florianopolis', 'Brazil', 'America/Sao_Paulo'),
#  ('Platz 4', 'Baden-Wurttemberg', 'Germany', 'Europe/Berlin'),
#  ('Kurt 2', 'Prague', 'Czechia', 'Europe/Prague'),
#  ('Match Court', 'Trinec', 'Czechia', 'Europe/Prague'),
#  ('Cancha 2', 'Rosario', 'Argentina', 'America/Argentina/Buenos_Aires'),
#  ('Match Court 1', 'Linz', 'Austria', 'Europe/Vienna'),
#  ('Court 6', 'Guangzhou', 'China', 'Asia/Shanghai'),
#  ('Court 2', 'New Delhi', 'India', 'Asia/Kolkata'),
#  ('Court 2', 'Barcelona', 'Spain', 'Europe/Madrid'),
#  ('Center Court', 'Bucharest', 'Romania', 'Europe/Bucharest'),
#  ('Cancha 9',
#   'San Miguel de Tucuman',
#   'Argentina',
#   'America/Argentina/Cordoba'),
#  ('Estadio Arena GNP Seguros (Acapulco, MEXICO)',
#   'Acapulco',
#   'Mexico',
#   'America/Mexico_City'),
#  ('Court 2', 'Lleida', 'Spain', 'Europe/Madrid'),
#  ('Center Court', 'Wuxi', 'China', 'Asia/Shanghai'),
#  ('Indoor 1', 'Santos', 'Brazil', 'Brazil/East'),
#  ('Court 10', 'Oeiras', 'Portugal', 'Europe/Lisbon'),
#  ('Court 2', 'Kachreti', 'Georgia', 'Asia/Tbilisi'),
#  ('Court 8', 'Zagreb', 'Croatia', 'Europe/Zagreb'),
#  ('Court 4', 'Brasov', 'Romania', 'Europe/Bucharest'),
#  ('Grandstand', 'Verona', 'Italy', 'Europe/Rome'),
#  ('Court 2', 'Hong Kong', 'Hong Kong, China', 'Asia/Hong_Kong'),
#  ('Court 2', 'Bonn', 'Germany', 'Europe/Berlin'),
#  ('Court 5', 'Lincoln, NE', 'USA', 'America/Chicago'),
#  ('Court 3', 'Dobrich', 'Bulgaria', 'Europe/Sofia'),
#  ('Omega Sport - Court 3', 'Olomouc', 'Czechia', 'Europe/Prague'),
#  ('Court 1', 'Porto', 'Portugal', 'Europe/Lisbon'),
#  ('Court 1', 'Montreux', 'Switzerland', 'Europe/Zurich'),
#  ('Cancha 2', 'Santiago de Cali', 'Colombia', 'America/Bogota'),
#  ('Indoor 1', 'Jiujiang', 'China', 'Asia/Shanghai'),
#  ('Grandstand', 'Belgrade', 'Serbia', 'Europe/Belgrade'),
#  ('COURT 2', 'Decines-Charpieu', 'France', 'Europe/Paris'),
#  ('Cancha 3', 'Manzanillo', 'Mexico', 'America/Mexico_City'),
#  ('Headington Family Tennis Center - Court 6',
#   'Norman, OK',
#   'USA',
#   'America/Chicago'),
#  ('Royal SC Tennis - Court 01', 'Noda', 'Japan', 'Asia/Tokyo'),
#  ('LSU - Court 06', 'Baton Rouge, LA', 'USA', 'America/Chicago'),
#  ('Robson Tennis Center - Court 3', 'Tucson, AZ', 'USA', 'America/Phoenix'),
#  ('Wake Forest Tennis Center - Indoor - Court 05',
#   'Winston Salem, NC',
#   'USA',
#   'America/New_York'),
#  ('Court 4', 'Florida City (FL)', 'USA', 'America/Mexico_City'),
#  ('Tennis Courts of the SW University Neofit Rilski - Court 2',
#   'Blagoevgrad',
#   'Bulgaria',
#   'Europe/Sofia'),
#  ('Penina Hotel and Golf Resort - 1. Court Penina',
#   'Alvor',
#   'Portugal',
#   'Europe/Lisbon'),
#  ('Bloomington - Court 5',
#   'Bloomington, IN',
#   'USA',
#   'America/Indiana/Indianapolis'),
#  ('Atlantis The Palm - Court 4',
#   'Dubai',
#   'United Arab Emirates',
#   'Asia/Dubai'),
#  ('Court 1', 'Singapore City', 'Singapore', 'Asia/Singapore'),
#  ('KPI Park - Court 06', 'Yokohama', 'Japan', 'Asia/Tokyo'),
#  ('Green Tennis Plaza - Court 04', 'Kawaguchi', 'Japan', 'Asia/Tokyo'),
#  ('Georgia Gwinnett - Court 06',
#   'Lawrenceville, GA',
#   'USA',
#   'America/New_York'),
#  ('Sport Center Visnjik (Clay) - Court 2',
#   'Zadar',
#   'Croatia',
#   'Europe/Zagreb'),
#  ('Court Central', 'Thionville', 'France', 'Europe/Paris'),
#  ('Cancha 1', 'Cap Cana', 'Dominican Republic', 'America/Santo_Domingo'),
#  ('Manzanillo - Court 04', 'Manzanillo', 'Mexico', 'America/Mexico_City'),
#  ('Grandstand Pablo Arroyo', 'Morelia', 'Mexico', 'America/Mexico_City'),
#  ('Sheraton Buganvilias', 'Puerto Vallarta', 'Mexico', 'America/Mexico_City'),
#  ('Tennis Club Porto Rose - Court 2',
#   'Roseto Degli Abruzzi',
#   'Italy',
#   'Europe/Rome'),
#  ('C4 Skechers', 'Santiago', 'Chile', 'America/Santiago'),
#  ('Joma Court 3', 'Menorca', 'Spain', 'Europe/Madrid'),
#  ('Tenis Club Crvena Zvezda - Court 03',
#   'Belgrade',
#   'Serbia',
#   'Europe/Belgrade'),
#  ('Court 1', 'Monza', 'Italy', 'Europe/Rome'),
#  ('Carvoeiro Clube de Tenis - 08. Court Details',
#   'Carvoeiro',
#   'Portugal',
#   'Europe/Lisbon'),
#  ('Court 7', 'Sarasota', 'USA', 'America/New_York'),
#  ('Central KAYDAN', 'Abidjan', 'Cote d’Ivoire', 'Africa/Abidjan'),
#  ('Loughborough University - Court 05',
#   'Loughborough',
#   'England',
#   'Europe/London'),
#  ('Mitchell Tennis Center - Texas AM - Court 04',
#   'College Station, TX',
#   'USA',
#   'America/Chicago'),
#  ('National Tennis Center - Outdoor - Court 06',
#   'Bucharest',
#   'Romania',
#   'Europe/Bucharest'),
#  ('Court 2', 'Saint Malo', 'France', 'Europe/Paris'),
#  ('Court 3', 'Vic', 'Spain', 'Europe/Madrid')]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#                                        venue_name      venue_city_name  \
# 0                                  Cancha Central             Santiago
# 1                                       Court One              Seville
# 2                                       TC Dynamo     Saint Petersburg
# 3                                         Campo 8               Oeiras
# 4                                         Court 2              Ostrava
# ..                                            ...                  ...
# 504            Loughborough University - Court 05         Loughborough
# 505  Mitchell Tennis Center - Texas AM - Court 04  College Station, TX
# 506   National Tennis Center - Outdoor - Court 06            Bucharest
# 507                                       Court 2           Saint Malo
# 508                                       Court 3                  Vic
#
#     venue_country_name    venue_timezone
# 0                Chile  America/Santiago
# 1                Spain     Europe/Madrid
# 2               Russia     Europe/Moscow
# 3             Portugal     Europe/Lisbon
# 4              Czechia     Europe/Prague
# ..                 ...               ...
# 504            England     Europe/London
# 505                USA   America/Chicago
# 506            Romania  Europe/Bucharest
# 507             France      Europe/Paris
# 508              Spain     Europe/Madrid
#
# [509 rows x 4 columns]

# %% [markdown]
# 5)	Find complexes that have more than one venue

# %%
sql_query = """Select comp.complex_name, count(venue.venue_id) as venue_count
from complexes_table comp inner join venues_table venue on comp.complex_id = venue.complex_id 
group by comp.complex_name  having count(venue.venue_id)>1 order by complex_name asc"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('Am Rothenbaum', 2),
#  ('Baku Tennis Academy', 2),
#  ('Carrasco Lawn Tennis Club', 2),
#  ('Circolo del Tennis Firenze 1898', 2),
#  ('Clube de Ténis do Estoril', 2),
#  ('National Tennis Center', 5),
#  ('National Tennis Centre', 3),
#  ('Nice Lawn Tennis Club', 2),
#  ('Tennis Club Triestino', 2),
#  ('The Phoenix Country Club', 2),
#  ('True Arena Hua Hin', 2)]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#                        complex_name  venue_count
# 0                     Am Rothenbaum            2
# 1               Baku Tennis Academy            2
# 2         Carrasco Lawn Tennis Club            2
# 3   Circolo del Tennis Firenze 1898            2
# 4         Clube de Ténis do Estoril            2
# 5            National Tennis Center            5
# 6            National Tennis Centre            3
# 7             Nice Lawn Tennis Club            2
# 8             Tennis Club Triestino            2
# 9          The Phoenix Country Club            2
# 10               True Arena Hua Hin            2

# %% [markdown]
# 6)	List venues grouped by country

# %%
sql_query = """Select venue_country_name, count(*) as venue_count, String_agg (venue_name , ',') as venue_name
from venues_table
group by venue_country_name 
order by venue_country_name """

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('Argentina',
#   10,
#   'Court Guillermo Villas,Cancha 7,Cancha 3,Cancha Central,Estadio Leonardo Mayer,Cancha 3,Court Central,Club Nautico Hacoaj - Center Court,Cancha 2,Cancha 9'),
#  ('Australia',
#   12,
#   'Court 2,Kia Arena,Centre Court,Show Court 1,Ct 15,West Court,West Park Oval,Court 8,Court 5,Court 2,Centre Court,Court 2'),
#  ('Austria',
#   9,
#   'Next Gen Court,Court Stadtwerke,Show Court,Center Court,Grandstand,Stadium,Court 3,Court 3,Match Court 1'),
#  ('Bahrain', 1, 'Court 2'),
#  ('Belgium', 2, 'Court 3,Court 1'),
#  ('Bolivia', 2, 'Cancha Central,Cancha 2'),
#  ('Bosnia & Herzegovina', 2, 'Court 1,Court 2'),
#  ('Brazil',
#   11,
#   'Central,Indoors,Indoor 4,Quadra 2,Court 2,Court 4,Indoor 4,Indoor 12,Quadra 4,Indoor Court,Indoor 1'),
#  ('Bulgaria',
#   4,
#   'Court 2,Court 3,Court 3,Tennis Courts of the SW University Neofit Rilski - Court 2'),
#  ('Canada',
#   8,
#   'Cashmere Grandstand,Rogers Court,Court Central,Court 1,Polygon Court,Indoor 2,Centre Marcel Dionne,Court 3'),
#  ('Chile',
#   11,
#   'Cancha Central,Cancha 3,Court 5,Court Jaime Fillol,Cancha 2,Cancha 11,Cancha 3,Cancha 3,Court 3,Grandstand,C4 Skechers'),
#  ('China',
#   24,
#   'Indoor 1,Center Court,Court 7,Court 7,Indoor 1,Diamond,Center Court,Center Court,Centre Court,Indoor court 9,Court 5,Court 11,Court 8,CC,Court 12,Indoor A3,Capital Group Diamond,Grandstand,Indoor 12,Indoor Court,Huafa Center Court,Court 6,Center Court,Indoor 1'),
#  ('Chinese Taipei',
#   4,
#   'Court 8,Yang-Ming Tennis Center - Court 8,Stadium,Court 2'),
#  ('Colombia',
#   8,
#   'Cancha Central,Cancha 3,Campo Estadio,Grandstand,Cancha Santiago Giraldo,Court 4,Court 3,Cancha 2'),
#  ('Cote d’Ivoire', 1, 'Central KAYDAN'),
#  ('Croatia',
#   10,
#   'Table 8,Court 1,Next Gen Arena,Court 17,Studenac Arena,Tennis Centar Punta,Court 2,Indoor Court,Court 8,Sport Center Visnjik (Clay) - Court 2'),
#  ('Czechia',
#   12,
#   'Court 2,Practice Court 1,Court 3,Court 14,Court 9,INDOOR C,Court 4,Prostejov Arena,Court 8,Kurt 2,Match Court,Omega Sport - Court 3'),
#  ('Denmark', 2, 'Court 4,Court 5'),
#  ('Dominican Republic', 2, 'Estadio Brugal,Cancha 1'),
#  ('Ecuador',
#   6,
#   'Court 13,Court 10,Cancha 3,Cancha 8,Court 4,Cancha P. Segura'),
#  ('Egypt', 1, 'Court 10'),
#  ('England',
#   12,
#   'Centre Court,Court 5,Indoor 6,Court 12,Indoor 3,Court 10,Indoor Court 4,Center Court,Court 11,12BET COURT,AO Arena,Loughborough University - Court 05'),
#  ('Finland', 2, 'Court 6,Court 3'),
#  ('France',
#   44,
#   'Court 3,Court 1,Court 1,Court 12,Court 2,Court TCSB,Court 2,Court 2,Court Simonne Mathieu,Indoor Court 1,Court 23,Court Annexe,Court 2,Tennis Club De Bruz 5,Court Fred Le Bian,Infinity Arena,Court 5,Court 3,Court 3,Court 1,Indoor 1,Indoor 5,Court 2,La Foret 1,Court 12,Court 2,Court Saint Gregoire 1,Court 1,Court 6,Court 4,Indoor 2,Court Eiffage,COURT 11 OCI INFORMATIQUE,Court 3,Court Amplitude,Court 4,Court 4,Court 6,Jean Jaures,Court 1,St Cyr En Val No.2,COURT 2,Court Central,Court 2'),
#  ('Georgia', 1, 'Court 2'),
#  ('Germany',
#   27,
#   'Court 2,Centre Court,Court 5,Head Gravity Court,Stadion,Court 2,MKG 2,Steffi Graf Stadion,Court 1,Centre Court,Colosseum,Court 4,Court 2,Court 4,Court 2,Court 2,Court 12,Indoor 2,Court 1,B and B Court,Owl Arena,Centre Court,M5,Court 2,B&B Court,Platz 4,Court 2'),
#  ('Greece', 1, 'Court 21'),
#  ('Hong Kong, China', 2, 'Indoor C2,Court 2'),
#  ('Hungary', 3, 'Grand Court,Temesvari Court,Court 3'),
#  ('India', 4, 'KSLTA Signature - Kingfisher Stadium,Court 5,Court 4,Court 2'),
#  ('Israel', 1, 'Centre Court'),
#  ('Italy',
#   44,
#   'Campo Arpex,Campo 2,Court 12,Via Delle Querce,Altitud (C2),Indoor 6,Court 2,Court 15,Court 2,Serena Maniva Centre,Grandstand,Allianz Cloud Court,Campo 2,Court 15,Court 5,Jocker Court,Court 1,Center Court,Court 4,Center Court Giorgi,Court 9,Sporting 2,Grandstand,Centre Court,Palaintred,Centre Court,Indoor Court,Gencom,Campo 3,Court 3,Campo 2,SICEurope Court,Center Court,Court 3,Campo 3,TC Giussano Indoors 5,Tato Paride Court,Court 3,Center Court,Court 3,Court 3,Grandstand,Tennis Club Porto Rose - Court 2,Court 1'),
#  ('Japan',
#   13,
#   'Court 9,Court 9,Indoor Court 19,Table 1,Court C,Indoors 2,Indoor 6,Court Indoor 11,Indoor Court 15,Court C,Royal SC Tennis - Court 01,KPI Park - Court 06,Green Tennis Plaza - Court 04'),
#  ('Kazakhstan', 4, 'Indoor Court 3,Indoor 2,Court 1,Court 4'),
#  ('Lithuania', 1, 'Centre Court'),
#  ('Luxembourg', 1, 'Stadium'),
#  ('Mexico',
#   22,
#   'Court 4,Court 7,Cancha 5,Cancha 2,Grandstand Caliente,Grandstand,Estadio Pegaso,Stadium CSC,Cancha 4,Cancha Vino America,Cancha 4,Estadio,Estadio Akron,Court 1,Estadio Mextenis,Stadium 1,Estadio Paradisus,Estadio Arena GNP Seguros (Acapulco, MEXICO),Cancha 3,Manzanillo - Court 04,Grandstand Pablo Arroyo,Sheraton Buganvilias'),
#  ('Monaco', 1, 'Court 13'),
#  ('Morocco', 2, 'Court 9,Court 3'),
#  ('Netherlands', 3, 'Centre Court,Court 4,Schoonderbeekbouw Court'),
#  ('New Caledonia', 1, 'Court Hertz'),
#  ('New Zealand', 1, 'Indoor 6'),
#  ('Paraguay', 1, 'Cancha 4'),
#  ('Peru', 2, 'Court 17,Cancha 13'),
#  ('Poland', 5, 'Court 2,Indoor 3,Court 7,Indoor Court 2,Center Court'),
#  ('Portugal',
#   10,
#   'Campo 8,Indoor 3,Court CTE,Court 4,Central Eupago,Indoor 2,Court 10,Court 1,Penina Hotel and Golf Resort - 1. Court Penina,Carvoeiro Clube de Tenis - 08. Court Details'),
#  ('Qatar', 1, 'Grandstand 4'),
#  ('Republic of Korea', 4, 'Court 8,Court 12,Court 1,Center Court'),
#  ('Romania',
#   9,
#   'Court 2,Court 9,Court 6,Court 9,Court 7,Stadium 6,Center Court,Court 4,National Tennis Center - Outdoor - Court 06'),
#  ('Russia', 5, 'TC Dynamo,Court 2,Luzhniki Stadium,Court 2,Central Court'),
#  ('San Marino', 1, 'Court 3'),
#  ('Serbia',
#   4,
#   'Practice Court 1,Teren 10,Grandstand,Tenis Club Crvena Zvezda - Court 03'),
#  ('Singapore', 3, 'Court 4,Center Court,Court 1'),
#  ('Slovakia', 2, 'Court 10,Court 11'),
#  ('Slovenia', 2, 'Court A,Court 7'),
#  ('South Africa', 1, 'Court 8'),
#  ('Spain',
#   29,
#   'Court One,Pista 4,Court 9,Court Central,Court 20,Pista Andres Gimeno,Grandstand,Pista Pablo Andujar,Pista 2,Court 3,Pista Carlos Alcaraz,Pista 4,Pista Mercedes-Benz,Pista 14,Pista 3,Court 6,Court 1,Court 3,Center Court,Center Court,Canary Islands Court,Pista 3,Court 2,Pista Central,Pista 4,Court 2,Court 2,Joma Court 3,Court 3'),
#  ('Sweden', 3, 'ShowCourt,Centre Court,Court 1'),
#  ('Switzerland',
#   9,
#   'Sportzentrum 3,Court 6,Court 4,Swiss Tennis Arena,Court 2,Match Court,Indoor 1,Tramondo Court 2,Court 1'),
#  ('Thailand', 3, 'Court 3,Court 1,Court B'),
#  ('Tunisia', 3, 'Court 6,Court 8,Table 4'),
#  ('Turkiye',
#   7,
#   'Court Limak Enerji,Duygu Aksit Oal,Court 3,Court 2,Grand Tarabaya Court,Court 24,Court 9'),
#  ('Ukraine', 1, 'Court 11'),
#  ('United Arab Emirates',
#   3,
#   'Court 2,ADCB Court 1,Atlantis The Palm - Court 4'),
#  ('Uruguay', 2, 'Cancha 15,Cancha 3'),
#  ('USA',
#   63,
#   'Stadium,AJC Grandstand Court,Center 2,Court 3,Court G,Court 10,Althea Gibson Club Court,Grandstand,Backer Mckenzie,Eve Zimmerman Tennis Center - Court 3,Brenda Meyers Court,Stadium,The Goldenberg Court,Indoor 2,Indoor Court 1,Court 8,Stadium,Court 2,PC2,Court 1,Butch Buchholz,Court 11,Ed Smith Stadium,Court 5,Court 3,Court 6,Tad Taube Court,Court 9,Center Court,Indoor Ct3,Court 10,Court 7,Court 2,Indoor 6,Indoor 2,Court 2,Court 3,Court 4,Grandstand,Gene Cox Stadium,Court 10,Atlantic Radiology Court,Indoor 2,Court 5,Court 4,Court 7,Court 4,Court 3,Grandstand,Court 11,Court 1,Court 4,Court 3,Court 5,Headington Family Tennis Center - Court 6,LSU - Court 06,Robson Tennis Center - Court 3,Wake Forest Tennis Center - Indoor - Court 05,Court 4,Bloomington - Court 5,Georgia Gwinnett - Court 06,Court 7,Mitchell Tennis Center - Texas AM - Court 04'),
#  ('Uzbekistan', 4, 'Indoor 2,Court 4,Court 7,Court 2')]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#       venue_country_name  venue_count  \
# 0              Argentina           10
# 1              Australia           12
# 2                Austria            9
# 3                Bahrain            1
# 4                Belgium            2
# ..                   ...          ...
# 62               Ukraine            1
# 63  United Arab Emirates            3
# 64               Uruguay            2
# 65                   USA           63
# 66            Uzbekistan            4
#
#                                            venue_name
# 0   Court Guillermo Villas,Cancha 7,Cancha 3,Canch...
# 1   Court 2,Kia Arena,Centre Court,Show Court 1,Ct...
# 2   Next Gen Court,Court Stadtwerke,Show Court,Cen...
# 3                                             Court 2
# 4                                     Court 3,Court 1
# ..                                                ...
# 62                                           Court 11
# 63   Court 2,ADCB Court 1,Atlantis The Palm - Court 4
# 64                                 Cancha 15,Cancha 3
# 65  Stadium,AJC Grandstand Court,Center 2,Court 3,...
# 66                   Indoor 2,Court 4,Court 7,Court 2
#
# [67 rows x 3 columns]

# %% [markdown]
# 7)	Find all venues for a specific complex (e.g., Nacional)

# %%
sql_query = """Select 
  comp.complex_name,
  venue.venue_id,venue.venue_name,venue.venue_city_name,venue.venue_country_name,  venue.venue_country_code,  venue.venue_timezone 
  from complexes_table comp inner join venues_table venue 
  on comp.complex_id = venue.complex_id 
  where complex_name = 'Nacional'"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('Nacional',
#   'sr:venue:70045',
#   'Cancha Central',
#   'Santiago',
#   'Chile',
#   'CHL',
#   'America/Santiago')]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#   complex_name        venue_id      venue_name venue_city_name  \
# 0     Nacional  sr:venue:70045  Cancha Central        Santiago
#
#   venue_country_name venue_country_code    venue_timezone
# 0              Chile                CHL  America/Santiago

# %% [markdown]
# --COMPETITOR RANKINGS:

# %% [markdown]
# 1)	Get all competitors with their rank and points.

# %%
sql_query = """Select comp.competitor_name,comp_rank.competitor_rank,comp_rank.competitor_rank_points 
from competitors_table comp inner join competitor_rankings_table comp_rank
on comp_rank.competitor_id = comp.competitor_id
order by competitor_rank asc"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('Pavic, Mate', 1, 9950),
#  ('Siniakova, Katerina', 1, 10665),
#  ('Arevalo-Gonzalez, Marcelo', 1, 9950),
#  ('Townsend, Taylor', 2, 8620),
#  ('Routliffe, Erin', 3, 8125),
#  ('Heliovaara, Harri', 3, 7590),
#  ('Patten, Henry', 4, 7590),
#  ('Ostapenko, Jelena', 4, 6950),
#  ('Krawietz, Kevin', 5, 6180),
#  ('Dabrowski, Gabriela', 5, 6385),
#  ('Putz, Tim', 6, 6090),
#  ('Paolini, Jasmine', 6, 5465),
#  ('Errani, Sara', 6, 5465),
#  ('Granollers, Marcel', 7, 5675),
#  ('Zeballos, Horacio', 8, 5675),
#  ('Muhammad, Asia', 8, 4690),
#  ('Kichenok, Lyudmyla', 9, 4630),
#  ('Vavassori, Andrea', 9, 5580),
#  ('Bolelli, Simone', 10, 5520),
#  ('Zhang, Shuai', 10, 4523),
#  ('Thompson, Jordan', 11, 5460),
#  ('Hsieh, Su-Wei', 11, 4521),
#  ('Kudermetova, Veronika', 12, 4365),
#  ('Purcell, Max', 12, 4710),
#  ('Mektic, Nikola', 13, 4700),
#  ('Shnaider, Diana', 13, 4356),
#  ('Glasspool, Lloyd', 14, 4460),
#  ('Krawczyk, Desirae', 14, 4133),
#  ('Khromacheva, Irina', 15, 3968),
#  ('Cash, Julian', 15, 4325),
#  ('Chan, Hao-Ching', 16, 3945),
#  ('Venus, Michael', 16, 4000),
#  ('Skupski, Neal', 17, 3820),
#  ('Danilina, Anna', 17, 3913),
#  ('Andreeva, Mirra', 18, 3869),
#  ('King, Evan', 18, 3031),
#  ('Molteni, Andres', 19, 2955),
#  ('Perez, Ellen', 19, 3820),
#  ('Dolehide, Caroline', 20, 3780),
#  ('Harrison, Christian', 20, 2855),
#  ('Gonzalez, Maximo', 21, 2820),
#  ('Melichar-Martinez, Nicole', 21, 3650),
#  ('Gauff, Coco', 22, 3296),
#  ('Lammons, Nathaniel', 22, 2780),
#  ('Withrow, Jackson', 23, 2780),
#  ('Mladenovic, Kristina', 23, 3265),
#  ('Schuurs, Demi', 24, 3241),
#  ('Salisbury, Joe', 24, 2730),
#  ('Ram, Rajeev', 25, 2650),
#  ('Siegemund, Laura', 25, 3205),
#  ('Panova, Alexandra', 26, 3073),
#  ('Murray, Jamie', 26, 2640),
#  ('Mertens, Elise', 27, 2925),
#  ('Goransson, Andre', 27, 2520),
#  ('Bucsa, Cristina', 28, 2824),
#  ('Peers, John', 28, 2475),
#  ('Roger-Vasselin, Edouard', 29, 2430),
#  ('Jiang, Xinyu', 29, 2785),
#  ('Wu, Fang-Hsien', 30, 2756),
#  ('Verbeek, Sem', 30, 2430),
#  ('Fernandez, Leylah Annie', 31, 2686),
#  ('Galloway, Robert', 31, 2410),
#  ('Nicholls, Olivia', 32, 2676),
#  ('Matos, Rafael', 32, 2375),
#  ('Bopanna, Rohan', 33, 2360),
#  ('Kato, Miyu', 33, 2669),
#  ('Zielinski, Jan', 34, 2340),
#  ('Mihalikova, Tereza', 34, 2611),
#  ('Bhambri, Yuki', 35, 2325),
#  ('Babos, Timea', 35, 2534),
#  ('Kenin, Sofia', 36, 2461),
#  ('Nys, Hugo', 36, 2320),
#  ('Stefani, Luisa', 37, 2433),
#  ('Guinard, Manuel', 37, 2240),
#  ('Reboul, Fabien', 38, 2235),
#  ('Olmos, Giuliana', 38, 2324),
#  ('Ebden, Matthew', 39, 2227),
#  ('Mattek-Sands, Bethanie', 39, 2309),
#  ('Niculescu, Monica', 40, 2255),
#  ('Arends, Sander', 40, 2175),
#  ('Sutjiadi, Aldila', 41, 2203),
#  ('Gille, Sander', 41, 2130),
#  ('Guo, Hanyu', 42, 2066),
#  ('Johnson, Luke', 42, 2066),
#  ('Erler, Alexander', 43, 2024),
#  ('Xu, Yifan', 43, 2053),
#  ('Melo, Marcelo', 44, 1985),
#  ('Ruse, Elena-Gabriela', 44, 1994),
#  ('Haddad Maia, Beatriz', 45, 1981),
#  ('Frantzen, Constantin', 45, 1965),
#  ('Hozumi, Eri', 46, 1955),
#  ('Arneodo, Romain', 46, 1951),
#  ('Doumbia, Sadio', 47, 1935),
#  ('Wang, Xinyu', 47, 1950),
#  ('Kalinskaya, Anna', 48, 1930),
#  ('Gonzalez, Santiago', 48, 1805),
#  ('Kichenok, Nadiia', 49, 1921),
#  ('Andreozzi, Guido', 49, 1755),
#  ('Stollar, Fanny', 50, 1863),
#  ('Jebens, Hendrik', 50, 1720),
#  ('Cabral, Francisco', 51, 1695),
#  ('Piter, Katarzyna', 51, 1843),
#  ('Pavlasek, Adam', 52, 1680),
#  ('Eikeri, Ulrikke', 52, 1758),
#  ('Aoyama, Shuko', 53, 1752),
#  ('Behar, Ariel', 53, 1671),
#  ('Olivetti, Albano', 54, 1645),
#  ('Shibahara, Ena', 54, 1717),
#  ('Dodig, Ivan', 55, 1635),
#  ('Kostyuk, Marta', 55, 1711),
#  ('Miedler, Lucas', 56, 1635),
#  ('Samsonova, Liudmila', 56, 1701),
#  ('Arribage, Theo', 57, 1620),
#  ('Zheng, Saisai', 57, 1622),
#  ('Ninomiya, Makoto', 58, 1612),
#  ('Vliegen, Joran', 58, 1615),
#  ('Sizikova, Yana', 59, 1595),
#  ('Wallner, Mark', 59, 1570),
#  ('Schnaitter, Jakob', 59, 1570),
#  ('Alexandrova, Ekaterina', 60, 1568),
#  ('Pegula, Jessica', 61, 1556),
#  ('Romboli, Fernando', 61, 1461),
#  ('Smith, John-Patrick', 62, 1460),
#  ('Stearns, Peyton', 62, 1411),
#  ('Yuan, Yue', 63, 1386),
#  ('Jacq, Gregoire', 63, 1435),
#  ('Luz, Orlando', 64, 1433),
#  ('Noskova, Linda', 64, 1368),
#  ('Rikl, Patrik', 65, 1420),
#  ('Dart, Harriet', 65, 1340),
#  ('Barrientos, Nicolas', 66, 1404),
#  ('Siskova, Anna', 66, 1290),
#  ('Sorribes Tormo, Sara', 67, 1290),
#  ('Tracy, James', 67, 1362),
#  ('Balaji, N. Sriram', 68, 1340),
#  ('Moratelli, Angelica', 68, 1270),
#  ('Nouza, Petr', 69, 1340),
#  ('Krejcikova, Barbora', 69, 1257),
#  ('Santamaria, Sabrina', 70, 1247),
#  ('Rojer, Jean-Julien', 70, 1320),
#  ('Reyes-Varela, Miguel', 71, 1320),
#  ('Lumsden, Maia', 71, 1188),
#  ('Cash, Robert', 72, 1263),
#  ('Sherif Ahmed Abdelaziz, Maiar', 72, 1164),
#  ('Yang, Zhaoxuan', 73, 1150),
#  ('Krajicek, Austin', 73, 1260),
#  ('Romios, Matthew Christopher', 74, 1256),
#  ('Tang, Qianhui', 74, 1149),
#  ('Kalashnikova, Oksana', 75, 1148),
#  ('Mansouri, Skander', 75, 1227),
#  ('Rakhimova, Kamilla', 76, 1120),
#  ('Bollipalli, Rithvik Choudary', 76, 1185),
#  ('Putintseva, Yulia', 77, 1110),
#  ('Matuszewski, Piotr', 77, 1168),
#  ('Krueger, Ashlyn', 78, 1102),
#  ('Haase, Robin', 78, 1161),
#  ('Hidalgo, Diego', 79, 1145),
#  ('Krunic, Aleksandra', 79, 1085),
#  ('Bouzkova, Marie', 80, 1084),
#  ('Seggerman, Ryan', 80, 1135),
#  ('Cavalle-Reimers, Yvonne', 81, 1063),
#  ('McDonald, Mackenzie', 81, 1120),
#  ('Michelsen, Alex', 82, 1095),
#  ('Cirstea, Sorana', 82, 1055),
#  ('Gleason, Quinn', 83, 1042),
#  ('Drzewiecki, Karol', 83, 1080),
#  ('Neel, Ingrid', 84, 1034),
#  ('Escobar, Gonzalo', 84, 1055),
#  ('Detiuc, Anastasia', 85, 996),
#  ('Pel, David', 85, 1035),
#  ('Martinez, Pedro', 86, 1000),
#  ('Appleton, Emily', 86, 987),
#  ('Machac, Tomas', 87, 990),
#  ('Kempen, Magali', 87, 972),
#  ('Shelton, Ben', 88, 990),
#  ('Blinkova, Anna', 88, 968),
#  ('Wang, Yafan', 89, 923),
#  ('Stevens, Bart', 89, 981),
#  ('Paul, Jakub', 90, 955),
#  ('Martins, Ingrid', 90, 923),
#  ('Middelkoop, Matwe', 91, 953),
#  ('Pridankina, Elena', 91, 898),
#  ('Mies, Andreas', 92, 906),
#  ('Skoch, Miriam', 92, 887),
#  ('Zarazua, Renata', 93, 852),
#  ('Ho, Ray', 93, 878),
#  ('Trhac, Patrik', 94, 872),
#  ('Anshba, Amina', 94, 844),
#  ('Rosatello, Camilla', 95, 830),
#  ('Korda, Sebastian', 95, 870),
#  ('Demoliner, Marcelo', 96, 851),
#  ('Zimmermann, Kimberley', 96, 827),
#  ('Linette, Magda', 97, 823),
#  ('Harper, Cleeve', 97, 843),
#  ('Kirkov, Vasil', 98, 825),
#  ('Haverlag, Isabelle', 98, 811),
#  ('Chandrasekar, Anirudh', 99, 823),
#  ('Shymanovich, Iryna', 99, 811),
#  ('Parry, Diane', 100, 793),
#  ('Cervantes, Inigo', 100, 822),
#  ('Munar, Jaume', 101, 820),
#  ('Chwalinska, Maja', 101, 789),
#  ('Jorge, Francisca', 102, 785),
#  ('Borges, Nuno', 102, 810),
#  ('Hibino, Nao', 103, 745),
#  ('Zormann, Marcelo', 103, 808),
#  ('Cornea, Victor', 104, 800),
#  ('Jorge, Matilde', 104, 740),
#  ('Aney, Jessie', 105, 735),
#  ('Prashanth, N. Vijay Sundar', 105, 795),
#  ('Soto, Matias', 106, 793),
#  ('Zantedeschi, Aurora', 106, 734),
#  ('Corley, Carmen', 107, 732),
#  ('Tsitsipas, Petros', 107, 793),
#  ('Gadecki, Olivia', 108, 731),
#  ('Willis, Marcus', 108, 788),
#  ('Bortolotti, Marco', 109, 784),
#  ('Cristian, Jaqueline', 109, 725),
#  ('Nedunchezhiyan, Jeevan', 110, 779),
#  ('Vedder, Eva', 110, 719),
#  ('Strakhova, Valeriya', 111, 708),
#  ('Kadhe, Arjun', 111, 777),
#  ('Salden, Lara', 112, 693),
#  ('Stevenson, David', 112, 760),
#  ('Molchanov, Denys', 113, 759),
#  ('Brooks, Madeleine', 113, 677),
#  ('Pigossi, Laura', 114, 669),
#  ('Stalder, Reese', 114, 752),
#  ('Arseneault, Ariana', 115, 664),
#  ('Paris, Joshua', 115, 741),
#  ('Draxl, Liam', 116, 725),
#  ('Watson, Heather', 116, 654),
#  ('Gomez, Federico Agustin', 117, 702),
#  ('Silva, Eden', 117, 644),
#  ('Hilderbrand, Trey', 118, 701),
#  ('Uchijima, Moyuka', 118, 640),
#  ('Wang, Xiyu', 119, 640),
#  ('Veldheer, Mick', 119, 696),
#  ('Tabilo, Alejandro', 120, 690),
#  ('Maleckova, Jesika', 120, 638),
#  ('Tikhonova, Anastasia', 121, 636),
#  ('Nedovyesov, Aleksandr', 121, 676),
#  ('Zhang, Zhizhen', 122, 675),
#  ('Stojanovic, Nina', 122, 635),
#  ('Blancaneaux, Geoffrey', 123, 674),
#  ('Kulambayeva, Zhibek', 123, 626),
#  ('Hule, Petra', 124, 618),
#  ('Hijikata, Rinky', 124, 662),
#  ('Liutarevich, Ivan', 125, 658),
#  ('Kozyreva, Maria', 125, 616),
#  ('Yuzuki, Takeru', 126, 655),
#  ('Kubka, Martyna', 126, 614),
#  ('Bublik, Alexander', 127, 630),
#  ('Chong, Eudice', 127, 613),
#  ('Fossa Huergo, Nicole', 128, 609),
#  ('Darderi, Luciano', 128, 630),
#  ('Bayldon, Blake', 129, 622),
#  ('Brancaccio, Nuria', 129, 606),
#  ('Tauson, Clara', 130, 605),
#  ('Cukierman, Daniel', 130, 619),
#  ('Saville, Luke', 131, 616),
#  ('Chang, Sophie', 131, 599),
#  ('Ramanathan, Ramkumar', 132, 602),
#  ('Romero Gormaz, Leyre', 132, 592),
#  ('Bondar, Anna', 133, 591),
#  ('Eysseric, Jonathan', 133, 602),
#  ('Lechemia, Elixane', 134, 587),
#  ('Vega, David', 134, 599),
#  ('Martinez, Luis David', 135, 596),
#  ('Stephens, Sloane', 135, 585),
#  ('Baptiste, Hailey', 136, 584),
#  ('Martos Gornes, Sergio', 136, 587),
#  ('Goldhoff, George', 137, 586),
#  ('Bolsova, Aliona', 137, 584),
#  ('Hach Verdugo, Hans', 138, 580),
#  ('Kawa, Katarzyna', 138, 577),
#  ('Zheng, Wushuang', 139, 567),
#  ('Sachko, Vitaliy', 139, 575),
#  ('Rus, Arantxa', 140, 564),
#  ('Oberleitner, Neil', 140, 569),
#  ('Uesugi, Kaito', 141, 567),
#  ('Navarro, Emma', 141, 560),
#  ('Fancutt, Thomas', 142, 562),
#  ('Naef, Celine', 142, 559),
#  ('McNally, Catherine', 143, 557),
#  ('Ingildsen, Johannes', 143, 561),
#  ('Zvonareva, Vera', 144, 552),
#  ('Navone, Mariano', 144, 560),
#  ('Reynolds, Finn', 145, 555),
#  ('Failla, Jessica', 145, 550),
#  ('Shimizu, Ayano', 146, 550),
#  ('Merino, Alexander', 146, 551),
#  ('Cocciaretto, Elisabetta', 147, 542),
#  ('Negritu, Christoph', 147, 551),
#  ('Kiger, Mac', 148, 549),
#  ('Fourlis, Jaimee', 148, 539),
#  ('Nam, Ji Sung', 149, 547),
#  ('Bara, Irina Maria', 149, 538),
#  ('Popyrin, Alexei', 150, 545),
#  ('Kobori, Momoko', 150, 538),
#  ('Khachanov, Karen', 151, 540),
#  ('Cascino, Estelle', 151, 531),
#  ('Walkow, Szymon', 152, 537),
#  ('Thombare, Prarthana', 152, 529),
#  ('Herrero Linana, Alicia', 153, 529),
#  ('Watanabe, Seita', 153, 528),
#  ('Sabanov, Matej', 154, 527),
#  ('Smith, Alana', 154, 521),
#  ('Kaliyanda Poonacha, Niki', 155, 526),
#  ('Joint, Maya', 155, 509),
#  ('Azarenka, Victoria', 156, 498),
#  ('Jecan, Alexandru', 156, 524),
#  ('Van de Zandschulp, Botic', 157, 520),
#  ('Rogers, Anna', 157, 498),
#  ('McAdoo, Rasheeda', 158, 492),
#  ('Pichler, David', 158, 511),
#  ('Barnett, Alicia', 159, 490),
#  ('Griekspoor, Tallon', 159, 510),
#  ('Karol, Milos', 160, 501),
#  ('Monnet, Carole', 160, 490),
#  ('Mikulskyte, Justina', 161, 489),
#  ('Herbert, Pierre-Hugues', 161, 500),
#  ('Tsao, Chia Yi', 162, 488),
#  ('Niklas-Salminen, Patrik', 162, 496),
#  ('Tsitsipas, Stefanos', 163, 495),
#  ('Cross, Kayla', 163, 486),
#  ('Murray Sharan, Samantha', 164, 480),
#  ('Isaro, Pruchya', 164, 495),
#  ('Vocel, Matej', 165, 494),
#  ('Sakellaridi, Sapfo', 165, 478),
#  ('Parks, Alycia', 166, 476),
#  ('Broom, Charles', 166, 481),
#  ('Semenistaja, Darja', 167, 476),
#  ('Spizzirri, Eliot', 167, 479),
#  ('Papadakis, Lena', 168, 476),
#  ('Vrbensky, Michael', 168, 468),
#  ('Martin, Fabrice', 169, 461),
#  ('Kucmova, Aneta', 169, 474),
#  ('Noha Akugue, Noma', 170, 463),
#  ('Added, Dan', 170, 461),
#  ('Ricca, Giorgio', 171, 451),
#  ('Ibbou, Ines', 171, 460),
#  ('Hon, Priscilla', 172, 458),
#  ('Harper, Patrick', 172, 447),
#  ('Lock, Courtney John', 173, 444),
#  ('Kessler, McCartney', 173, 454),
#  ('Potapova, Anastasia', 174, 452),
#  ('Kestelboim, Mariano', 174, 443),
#  ('Plipuech, Peangtarn', 175, 452),
#  ('Rincon, Daniel', 175, 441),
#  ('Zeballos, Federico', 176, 435),
#  ('Fernandez, Bianca Jolie', 176, 451),
#  ('Perrin, Conny', 177, 448),
#  ('Noguchi, Rio', 177, 434),
#  ('Rosca, Christina', 178, 445),
#  ('Britto, Luis', 178, 432),
#  ('Badosa, Paula', 179, 444),
#  ('Sanchez, Luca', 179, 431),
#  ('Jones, Makenna', 180, 444),
#  ('Ellis, Blake', 180, 429),
#  ('Shimizu, Yuta', 181, 428),
#  ('Karatancheva, Lia', 181, 444),
#  ('Wuerth, Tara', 182, 438),
#  ('Hassan, Benjamin', 182, 426),
#  ('Yashina, Ekaterina', 183, 435),
#  ('Walton, Adam', 183, 425),
#  ('Erjavec, Veronika', 184, 432),
#  ('Bonzi, Benjamin', 184, 421),
#  ('Cho, Yi Tsen', 185, 429),
#  ('Cho, I-Hsuan', 185, 429),
#  ('Bergevi, Filip', 185, 420),
#  ('Wang, Aoran', 186, 418),
#  ('Begemann, Andre', 187, 415),
#  ('Carle, Maria', 187, 428),
#  ('Feng, Shuo', 188, 428),
#  ('Duran, Guillermo', 188, 413),
#  ('Rodriguez, Cristian', 189, 411),
#  ('Osorio, Camila', 189, 424),
#  ('Charlton, Joshua', 190, 407),
#  ('Kupres, Mia', 190, 422),
#  ('Fils, Arthur', 191, 405),
#  ('Kolb, Nadia', 191, 421),
#  ('Bektas, Emina', 192, 420),
#  ('Cobolli, Flavio', 192, 405),
#  ('Falkowska, Weronika', 193, 420),
#  ('Barnat, Jiri', 193, 404),
#  ('Banthia, Siddhant', 194, 403),
#  ('Tran, Lian', 194, 416),
#  ('Kym, Jerome', 195, 402),
#  ('Waltert, Simona', 195, 411),
#  ('Aiava, Destanee', 196, 411),
#  ('Alves, Mateus', 196, 398),
#  ('Zaar, Lisa', 197, 411),
#  ('Sabanov, Ivan', 197, 397),
#  ('Hewitt, Dalayna', 198, 410),
#  ('Schoolkate, Tristan', 198, 391),
#  ('Wagner, Anita', 199, 408),
#  ('Donski, Alexander', 199, 379),
#  ('Lock, Benjamin', 200, 373),
#  ('Grey, Sarah Beth', 200, 408),
#  ('Gorgodze, Ekaterine', 201, 407),
#  ('Myneni, Saketh', 201, 372),
#  ('Huertas Del Pino, Connor', 202, 372),
#  ('Papamichail, Despina', 202, 401),
#  ('Lawson, Alex', 203, 367),
#  ('Wong, Hong Yi Cody', 203, 401),
#  ('Hermans, Mats', 204, 365),
#  ('Karamoko, Naima', 204, 400),
#  ('Kuwata, Hiroko', 205, 398),
#  ('Uchida, Kaichi', 205, 361),
#  ('Draper, Jack', 206, 360),
#  ('Ibragimova, Alevtina', 206, 398),
#  ('Jarry, Nicolas', 207, 360),
#  ('Preston, Taylah', 207, 396),
#  ('Christofi, Eleni', 208, 395),
#  ('Mpetshi Perricard, Giovanni', 208, 360),
#  ('Raina, Ankita', 209, 393),
#  ('Etcheverry, Tomas Martin', 209, 360),
#  ('Giavara, Haley', 210, 387),
#  ('Pereira, Tiago', 210, 355),
#  ('Sato, Naho', 211, 387),
#  ('Pokorny, Lukas', 211, 354),
#  ('Duda, Filip', 212, 352),
#  ('Schoofs, Bibiane', 212, 385),
#  ('Abbagnato, Anastasia', 213, 385),
#  ('Watt, James', 213, 349),
#  ('Sun, Fajing', 214, 347),
#  ('Hartono, Arianne', 214, 384),
#  ('Kononova, Maria', 215, 384),
#  ('Jones, Ben', 215, 338),
#  ('Romano, Filippo', 216, 338),
#  ('Cabrera, Lizette', 216, 380),
#  ('Arias, Boris', 217, 335),
#  ('Moore, Tara', 217, 377),
#  ('Villanueva, Gonzalo', 218, 334),
#  ('Rosolska, Alicja', 218, 373),
#  ('Montgomery, Robin', 219, 366),
#  ('Tu, Li', 219, 333),
#  ('Ngounoue, Clervie', 220, 365),
#  ('Lehecka, Jiri', 220, 330),
#  ('Osborne, Alexandra', 221, 364),
#  ('Saraiva Dos Santos, Paulo Andre', 221, 329),
#  ('Sheehy, Joshua', 222, 324),
#  ('Bhosale, Rutuja', 222, 363),
#  ('Ponchet, Jessika', 223, 359),
#  ('Delaney, Jake', 223, 323),
#  ('Kolb, Maryna', 224, 358),
#  ('Matsui, Toshihide', 224, 320),
#  ('Alcantara, Francis Casey', 225, 320),
#  ('Krywoj, Melany Solange', 225, 357),
#  ('Micic, Elena', 226, 355),
#  ('Puttergill, Calum', 226, 319),
#  ('Kolar, Zdenek', 227, 317),
#  ('Falkner, Ziva', 227, 353),
#  ('Zamarripa, Maribella', 228, 353),
#  ('Rodionov, Jurij', 228, 316),
#  ('McDonald, Ella', 229, 350),
#  ('Safiullin, Roman', 229, 315),
#  ('Gimbrere, Jasmijn', 230, 350),
#  ('Baez, Sebastian', 230, 315),
#  ('Cerundolo, Francisco', 231, 315),
#  ('Perez Garcia, Maria Paulina', 231, 348),
#  ('Charaeva, Alina', 232, 347),
#  ('Grevelius, Erik', 232, 306),
#  ('Stricker, Dominic', 233, 303),
#  ('Hunter, Storm', 233, 346),
#  ('Christie, Freya', 234, 345),
#  ('Mena, Facundo', 234, 301),
#  ('Bayerlova, Michaela', 235, 345),
#  ('Fritz, Taylor', 235, 300),
#  ('Corley, Ivana', 236, 342),
#  ('Wehnelt, Kai', 236, 298),
#  ('Sato, Hikaru', 237, 340),
#  ('Zink, Tyler', 237, 296),
#  ('Kuzmova, Katarina', 238, 338),
#  ('Heinonen, Adam', 238, 295),
#  ('Aguilar, Juan Carlos', 239, 294),
#  ('Rakotomanga Rajaonah, Tiantsoa Sarah', 239, 336),
#  ('Osuigwe, Whitney', 240, 335),
#  ('Sigouin, Benjamin', 240, 294),
#  ('Stevenson, Kelsey', 241, 292),
#  ('Tig, Patricia Maria', 241, 329),
#  ('Jacquemot, Elsa', 242, 328),
#  ('Aboian, Leonardo', 242, 287),
#  ('Matsuda, Ryuki', 243, 286),
#  ('Burrage, Jodie', 243, 324),
#  ('Liang, En-Shuo', 244, 324),
#  ('Maginley, Jody', 244, 286),
#  ('Roca Batalla, Oriol', 245, 285),
#  ('Riera, Julia', 245, 321),
#  ('Fita Boluda, Angela', 246, 321),
#  ('Nava, Emilio', 246, 282),
#  ('Park, Sohyun', 247, 319),
#  ('Duncan, Scott', 247, 282),
#  ('Simakin, Ilia', 248, 281),
#  ('Li, Yu-Yun', 248, 319),
#  ('Jermar, Jan', 249, 281),
#  ('Belgraver, Julie', 249, 318),
#  ('Makarova, Ekaterina', 250, 317),
#  ('Boyer, Tristan', 250, 280),
#  ('Anderson, Robin', 251, 316),
#  ('Trotter, James Kent', 251, 278),
#  ('Pera, Bernarda', 252, 315),
#  ('Loof, Thijmen', 252, 278),
#  ('Pearson, Kody', 253, 278),
#  ('Xiao, Zhenghua', 253, 315),
#  ('Nakashima, Brandon', 254, 275),
#  ('Bains, Naiktha', 254, 314),
#  ('Schachter, Noah', 255, 274),
#  ('Radisic, Nika', 255, 313),
#  ('Delaney, Jesse', 256, 272),
#  ('Rajecki, Amelia', 256, 310),
#  ('Zeballos Melgar, Noelia', 257, 308),
#  ('Reymond, Arthur', 257, 271),
#  ('Mateas, Maria', 258, 306),
#  ('Eubanks, Christopher', 258, 270),
#  ('Zverev, Alexander', 259, 270),
#  ('Kung, Leonie', 259, 306),
#  ('Hsu, Yu Hsiou', 260, 269),
#  ('Samson, Laura', 260, 305),
#  ('Yamazaki, Ikumi', 261, 304),
#  ('Aboian, Valerio', 261, 269),
#  ('Reyngold, Ekaterina', 262, 303),
#  ('Agafonov, Egor', 262, 266),
#  ('Latinovic, Stefan', 263, 266),
#  ('Barry, Monique', 263, 299),
#  ('Ruehl. Tim', 264, 264),
#  ('Bhatia, Riya', 264, 298),
#  ('Vargova, Nina', 265, 298),
#  ('Whiting, Tennyson', 265, 262),
#  ('Ito, Aoi', 266, 297),
#  ('Cadenasso, Gianluca', 266, 261),
#  ('Marino, Rebecca', 267, 296),
#  ('Andrade, Andres', 267, 260),
#  ('Miyazaki, Yuriko Lily', 268, 296),
#  ('Poljak, David', 268, 257),
#  ('Rodriguez, Victoria', 269, 295),
#  ('Ouakaa, Aziz', 269, 257),
#  ('Kielan, Szymon', 270, 257),
#  ('Sanchez, Ana Sofia', 270, 294),
#  ('Huesler, Marc-Andrea', 271, 255),
#  ('Portillo Ramirez, Maria Jose', 271, 294),
#  ('Nahimana, Sada', 272, 292),
#  ('Rodriguez Taverna, Santiago', 272, 254),
#  ('Masur, Daniel', 273, 252),
#  ('Morisaki, Kanako', 273, 290),
#  ('Marcinkevica, Diana', 274, 289),
#  ('Hulme, Matt', 274, 252),
#  ('Li, Zongyu', 275, 287),
#  ('Pieczonka, Filip', 275, 252),
#  ('Kecmanovic, Miomir', 276, 250),
#  ('Szabo, Briana', 276, 286),
#  ('Visscher, Stephanie Judith', 277, 286),
#  ('Denolly, Corentin', 277, 250),
#  ('Genov, Anthony', 278, 250),
#  ('Hutchinson, Holly', 278, 286),
#  ('Sinclair, Colin', 279, 249),
#  ('Naito, Yuki', 279, 286),
#  ('Zelnickova, Radka', 280, 286),
#  ('Dutra Da Silva, Daniel', 280, 249),
#  ('Pujol Navarro, Bruno', 281, 249),
#  ('Safarova, Lucie', 281, 284),
#  ('Tomova, Viktoriya', 282, 283),
#  ('Habib, Hady', 282, 242),
#  ('Pavel, Bogdan', 283, 242),
#  ('Loeb, Jamie', 283, 283),
#  ('Daniell, Marcus', 284, 241),
#  ('Imamura, Saki', 284, 283),
#  ('TE, Rigele', 285, 240),
#  ('Bronzetti, Lucia', 285, 281),
#  ('Dev, S D Prajwal', 286, 236),
#  ('Kalinina, Anhelina', 286, 280),
#  ('Harrison, Catherine', 287, 280),
#  ('Urrea, Andres', 287, 235),
#  ('Whitehouse, Mark', 288, 235),
#  ('Bhamidipaty, Shrivalli Rashmikaa', 288, 280),
#  ('Ishii, Sayaka', 289, 275),
#  ('Hands, Tom', 289, 231),
#  ('Jang, Su Jeong', 290, 273),
#  ('Nesterov, Pyotr', 290, 230),
#  ('Kumar, Pranav', 291, 230),
#  ('Korneeva, Alina', 291, 272),
#  ('Imamura, Masamichi', 292, 229),
#  ('Grammatikopoulou, Valentini', 292, 272),
#  ('Virgili, Augusto', 293, 228),
#  ('Hosogi, Sakura', 293, 272),
#  ('Omae, Akiko', 294, 271),
#  ('Huertas Del Pino Cordova, Arklon', 294, 226),
#  ('Hanfmann, Yannick', 295, 225),
#  ('Koepfer, Dominik', 295, 225),
#  ('Xu, Mingge', 295, 269),
#  ('Sebestova, Ivana', 296, 269),
#  ('Tona, Miriana', 297, 269),
#  ('Brown, Dustin', 297, 225),
#  ('Kalyanpur, Adil', 298, 225),
#  ('Dartron, Emeline', 298, 268),
#  ('Wendelken, Harry', 299, 223),
#  ('Hietaranta, Laura', 299, 267),
#  ('Pacheco Mendez, Rodrigo', 300, 222),
#  ('Struplova, Julie', 300, 266),
#  ('Kubanova, Karolina', 301, 264),
#  ('Meligeni Alves, Felipe', 301, 221),
#  ('Weissborn, Tristan-Samuel', 302, 220),
#  ('Jakupovic, Dalila', 302, 263),
#  ('Carou, Ignacio', 303, 219),
#  ('Abe, Hiromi', 303, 262),
#  ('Guo, Meiqi', 304, 262),
#  ('Orlov, Vladyslav', 304, 219),
#  ('Dellien, Murkel', 305, 218),
#  ('Morderger, Yana', 305, 261),
#  ('Pavlyuchenkova, Anastasia', 306, 260),
#  ('De Jong, Jesper', 306, 217),
#  ('Yastremska, Dayana', 307, 258),
#  ('Martineau, Matteo', 307, 217),
#  ('Reese, Hunter', 308, 216),
#  ('Salkova, Dominika', 308, 258),
#  ('Sharma, Astra', 309, 257),
#  ('Dzumhur, Damir', 309, 215),
#  ('Bertola, Remy', 310, 215),
#  ('Lansere, Sofya', 310, 257),
#  ('Laboutkova, Aneta', 311, 257),
#  ('Moreno de Alboran, Nicolas', 311, 211),
#  ('Fery, Arthur', 312, 208),
#  ('Bozovic, Alexandra', 312, 256),
#  ('Shelbayh, Abdullah', 313, 208),
#  ('Tkacheva, Mariia', 313, 254),
#  ('Matsuda, Misaki', 314, 254),
#  ('Roveri Sidney, Gabriel', 314, 208),
#  ('Mackinlay, James', 315, 208),
#  ('Zidansek, Tamara', 315, 253),
#  ('Huang, Tsung-Hao', 316, 207),
#  ('Okuwaki, Rinon', 316, 253),
#  ('Perez, Alfredo', 317, 205),
#  ('Drazic, Mariana', 317, 251),
#  ('Gibson, Talia', 318, 250),
#  ('Agostini, Simone', 318, 202),
#  ('Stepanov, Roy', 319, 202),
#  ('Da Silva Fick, Gabriella', 319, 248),
#  ('Barrere, Gregoire', 320, 200),
#  ('Lemaitre, Tiphanie', 320, 248),
#  ('Todoni, Anca Alexia', 321, 246),
#  ('Vukic, Aleksandar', 321, 200),
#  ('Hobgarski, Katharina', 322, 246),
#  ('Poljicak, Mili', 322, 197),
#  ('Birrell, Kimberly', 323, 244),
#  ('Reis Da Silva, Joao Lucas', 323, 197),
#  ('Oradini, Giovanni', 324, 197),
#  ('Chang, Hanna', 324, 244),
#  ('Roncadelli, Franco', 325, 192),
#  ('Shimizu, Eri', 325, 244),
#  ('Krutykh, Oleksii', 326, 191),
#  ('Iatcenko, Polina', 326, 242),
#  ('Toth, Amarissa Kiara', 327, 241),
#  ('Mahut, Nicolas', 327, 190),
#  ('Ofner, Sebastian', 328, 190),
#  ('Garcia, Caroline', 328, 240),
#  ('Zhukayev, Beibit', 329, 189),
#  ('Sema, Erika', 329, 240),
#  ('Geerts, Michael', 330, 189),
#  ('Sasnovich, Aliaksandra', 330, 238),
#  ('Sun, Lulu', 331, 232),
#  ('Lanik, Tomas', 331, 187),
#  ('Taguchi, Ryotaro', 332, 186),
#  ('Gureva, Anastasiia', 332, 230),
#  ('Montes-de la Torre, Inaki', 333, 185),
#  ('Lin, Fang An', 333, 229),
#  ('Barreiros Reyes, Mateo', 334, 183),
#  ('Morderger, Tayisiya', 334, 229),
#  ('Hindova, Denisa', 335, 227),
#  ('Isomura, Kokoro', 335, 182),
#  ('Jabeur, Ons', 336, 226),
#  ('Vanshelboim, Eric', 336, 182),
#  ('Duerst, Jenny', 337, 225),
#  ('Ganta, Sai Karteek Reddy', 337, 182),
#  ('Laskutova, Ksenia', 338, 225),
#  ('Sharipov, Marat', 338, 181),
#  ('Medvedev, Daniil', 339, 180),
#  ('Berrettini, Matteo', 339, 180),
#  ('Yuan, Chengyiyi', 339, 225),
#  ('Inglis, Maddison', 340, 224),
#  ('Pouille, Lucas', 341, 180),
#  ('Lee, Ya-Hsin', 341, 224),
#  ('Sinner, Jannik', 342, 180),
#  ('Parnaby, Alana', 342, 223),
#  ('Struff, Jan-Lennard', 343, 180),
#  ('Ye, Qiu Yu', 343, 222),
#  ('Musetti, Lorenzo', 344, 180),
#  ('Daniel, Jaeda', 344, 220),
#  ('de Minaur, Alex', 345, 180),
#  ('Aksu, Ayla', 345, 218),
#  ('Sonego, Lorenzo', 346, 180),
#  ('Shi, Han', 346, 218),
#  ('Shinde, Vasanti', 347, 217),
#  ('Rocha, Henrique', 347, 180),
#  ('Nagy, Adrienn', 348, 217),
#  ('Debru, Gabriel', 348, 180),
#  ('Minnen, Greet', 349, 216),
#  ('Lomakin, Grigoriy', 349, 180),
#  ('Araujo, Pedro', 350, 178),
#  ('van Emst, Sarah', 350, 215),
#  ('Kusuhara, Yusuke', 351, 177),
#  ('Chaudhari, Vaidehi', 351, 215),
#  ('In-Albon, Ylena', 352, 214),
#  ('Bakshi, Aleksandre', 352, 177),
#  ('Marrero Curbelo, Ivan', 353, 177),
#  ('Ovcharenko, Ekaterina', 353, 214),
#  ('Kulikov, Angela', 354, 211),
#  ('Holmgren, August', 354, 176),
#  ('Bass, Finn', 355, 176),
#  ('Huang, Yujia', 355, 209),
#  ('Vondrousova, Marketa', 356, 207),
#  ('Rai, Ajeet', 356, 176),
#  ('Seidel, Ella', 357, 207),
#  ('Halys, Quentin', 357, 175),
#  ('Stewart, Hamish', 358, 175),
#  ('Ortenzi, Jazmin', 358, 207),
#  ('Nijboer, Ryan', 359, 171),
#  ('Kovapitukted, Punnin', 359, 206),
#  ('Novak, Kristina', 360, 205),
#  ('Clarke, Jay', 360, 171),
#  ('Heide, Gustavo', 361, 170),
#  ('Ambrosio, Silvia', 361, 205),
#  ('Kuczer, Daria', 362, 205),
#  ('Olivo, Renzo', 362, 169),
#  ('Barroso Campos, Alberto', 363, 169),
#  ('Rouvroy, Margaux', 363, 204),
#  ('Karlovskiy, Evgeny', 364, 169),
#  ('Mansouri, Yasmine', 364, 203),
#  ('Zakharova, Anastasia', 365, 202),
#  ('Mejia, Nicolas', 365, 168),
#  ('Mansilla Diez, Mario', 366, 166),
#  ('Zhu, Lin', 366, 198),
#  ('Cretu, Cezar (2001)', 367, 164),
#  ('Urgesi, Federica', 367, 197),
#  ('Maestrelli, Francesco', 368, 164),
#  ('Labrana, Fernanda', 368, 196),
#  ('Uzhylovskyi, Volodoymyr', 369, 164),
#  ('Prisacariu, Andreea', 369, 196),
#  ('Bondioli, Federico', 370, 163),
#  ('Amariei, Ilinca Dalina', 370, 194),
#  ('Polmans, Marc', 371, 162),
#  ('Wang, Meiling', 371, 191),
#  ('Agamenone, Franco', 372, 162),
#  ('Hruncakova, Viktoria', 372, 190),
#  ('Okalova, Martina', 373, 189),
#  ('Davis, James', 373, 161),
#  ('Brace, Cadence', 374, 189),
#  ('Kaukovalta, Patrick', 374, 161),
#  ('Mandlik, Elizabeth', 375, 187),
#  ('Tajima, Naoki', 375, 161),
#  ('Forejtek, Jonas', 376, 158),
#  ('Benoit, Marie', 376, 187),
#  ('Hipfl, Nico', 377, 158),
#  ('Perez Alarcon, Lucciana', 377, 186),
#  ('Sakatsume, Himeno', 378, 186),
#  ('Zahraj, Patrick', 378, 158),
#  ('Candiotto, Ana', 379, 185),
#  ('Vavassori, Matteo', 379, 156),
#  ('Gueymard Wayenburg, Sascha', 380, 155),
#  ('Rogers, Shelby', 380, 184),
#  ('Chopra, Keshav', 381, 155),
#  ('Kawamura, Mana', 381, 184),
#  ('Seeman, Johannes', 382, 154),
#  ('Kudermetova, Polina', 382, 183),
#  ('Pedretti, Thaisa Grana', 383, 182),
#  ('Vasa, Eero', 383, 153),
#  ('Durasovic, Viktor', 384, 153),
#  ('Ozeki, Michika', 384, 182),
#  ('Jeanjean, Leolia', 385, 181),
#  ('Hudd, Emile', 385, 152),
#  ('Tang, Sheng', 386, 152),
#  ('Glushko, Lina', 386, 181),
#  ('Serban, Raluca Georgiana', 387, 180),
#  ('Izquierdo Luque, Rafael', 387, 151),
#  ('Jeong, Yeongseok', 388, 151),
#  ('Zolotareva, Anastasia', 388, 180),
#  ('Lizarazo, Yuliana', 389, 179),
#  ('Mensik, Jakub', 389, 150),
#  ('Akli, Ayana', 390, 179),
#  ('Humbert, Ugo', 390, 150),
#  ('Maklakova, Ekaterina', 391, 179),
#  ('Rublev, Andrey', 391, 150),
#  ('Perfetti, Noah', 392, 150),
#  ('Osuigwe, Victoria', 392, 179),
#  ('Webley-Smith, Emily', 393, 179),
#  ('Monday, Johannus', 393, 149),
#  ('Milev, Yanaki', 394, 149),
#  ('Hourigan, Paige Mary', 394, 178),
#  ('Nugroho, Priska Madelyn', 395, 178),
#  ('Rocha, Francisco', 395, 149),
#  ('Kopp, Sandro', 396, 148),
#  ('Stoiber, Ranah Akua', 396, 178),
#  ('Saigo, Yukina', 397, 178),
#  ('Shin, Woobin', 397, 148),
#  ('Fontenel, Chelsea', 398, 177),
#  ('Hrazdil, Jan', 398, 147),
#  ('Visker, Niels', 399, 146),
#  ('Shapatava, Sofia', 399, 175),
#  ('Sakellaridis, Dimitris', 400, 146),
#  ('Gasanova, Anastasia', 400, 175),
#  ('Quinn, Ethan', 401, 144),
#  ('Xun, Fang Ying', 401, 175),
#  ('Sharan, Divij', 402, 144),
#  ('Cayetano, Eryn', 402, 174),
#  ('van Wyk, Kris', 403, 144),
#  ('Shinikova, Isabella', 403, 174),
#  ('Adams, Julia', 404, 174),
#  ('Summers, Matthew', 404, 143),
#  ('Saritas, Gokberk', 405, 143),
#  ('Radivojevic, Lola', 405, 173),
#  ('Paulson, Andrew', 406, 142),
#  ('Golubic, Viktorija', 406, 171),
#  ('Pellegrino, Andrea', 407, 142),
#  ('Pereira, Rebeca', 407, 171),
#  ('Lazaro Garcia, Andrea', 408, 171),
#  ('Catini, Niccolo', 408, 142),
#  ('Back, Dayeon', 409, 171),
#  ('Oswald, Philipp', 409, 141),
#  ('Woodall, William', 410, 141),
#  ('Bolkvadze, Mariam', 410, 169),
#  ('La Serna, Juan Manuel', 411, 141),
#  ('Ccuno, Romina', 411, 169),
#  ('Barton, Hynek', 412, 140),
#  ('Nagata, Anri', 412, 168),
#  ('Bojica, Stefania', 413, 166),
#  ('Hignett, Liam', 413, 139),
#  ('Kingsley, Cannon', 414, 138),
#  ('Avdeeva, Julia', 414, 165),
#  ('Dittmann, Gina Marie', 415, 164),
#  ('Basel, Valentin', 415, 138),
#  ('Engel, Justin', 416, 137),
#  ('Romero, Camila', 416, 164),
#  ('Nakagawa, Shunsuke', 417, 137),
#  ('Lamens, Suzan', 417, 163),
#  ('Diatchenko, Vitalia', 418, 163),
#  ('Casanova, Hernan', 418, 136),
#  ('Chidekh, Clement', 419, 136),
#  ('Avanesyan, Elina', 419, 161),
#  ('Klein, Lukas', 420, 135),
#  ('Rehberg, Max Hans', 420, 135),
#  ('Simunyu, Celine', 420, 161),
#  ('Schmidt, Antonia', 421, 160),
#  ('Pavlova, Kira', 422, 160),
#  ('Kovalik, Jozef', 422, 135),
#  ('Kozaki, Funa', 423, 160),
#  ('Coria, Federico', 423, 135),
#  ('Nanda, Govind', 424, 135),
#  ('Kawaguchi, Natsumi', 424, 159),
#  ('Couacaud, Enzo', 425, 134),
#  ('Kraus, Sinja', 425, 158),
#  ('Hayashi, Erina', 426, 157),
#  ('Shah, Aryan', 426, 134),
#  ('Arutiunian, Erik', 427, 133),
#  ('Yoshioka, Kisa', 427, 157),
#  ('Mochizuki, Shintaro', 428, 132),
#  ('Katsumi, Nanari', 428, 157),
#  ('Ayukawa, Mana', 429, 157),
#  ('Schwaerzler, Joel', 429, 131),
#  ('Dinu, Cristina', 430, 156),
#  ('Sanchez Izquierdo, Nikolas', 430, 131),
#  ('Corley, Paris', 431, 156),
#  ('Yevseyev, Denis', 431, 130),
#  ('Ebeling Koning, Loes', 432, 156),
#  ('Somani, Parikshit', 432, 130),
#  ('Verbin, Pavel', 433, 130),
#  ('Robbe, Alice', 433, 156),
#  ('Bianchi, Juan Jose', 434, 130),
#  ('McHale, Christina', 434, 155),
#  ('Hatouka, Yuliya', 435, 152),
#  ('Garcian, Axel', 435, 129),
#  ('Kopriva, Vit', 436, 128),
#  ('Ryser, Valentina', 436, 152),
#  ('Smith, Alicia', 437, 152),
#  ('Shin, Sanhui', 437, 128),
#  ('Pace, Francesca', 438, 151),
#  ('Beckley, Alec', 438, 128),
#  ('Tsygourova, Katerina', 439, 151),
#  ('Turker, Mert Naci', 439, 128),
#  ('Boulter, Katie', 440, 150),
#  ('Vallejo, Adolfo Daniel', 440, 127),
#  ('Bax, Florent', 441, 127),
#  ('Teichmann, Jil', 441, 150),
#  ('Park, Uisung', 442, 127),
#  ('Falei, Aliona', 442, 150),
#  ('Bittoun Kouzmine, Constantin', 443, 127),
#  ('Marcinko, Petra', 443, 150),
#  ('Kim, Na Ri', 444, 148),
#  ('Poling, Karl', 444, 126),
#  ('Lalami Laaroussi, Younes', 445, 126),
#  ('Rencheli, Abigail', 445, 147),
#  ('Korokozidi, Elena', 446, 147),
#  ('Prado Angelo, Juan Carlos', 446, 125),
#  ('Allen, Kolie', 447, 147),
#  ('Barranco Cosano, Javier', 447, 125),
#  ('Lamasine, Tristan', 448, 125),
#  ('Costoulas, Sofia', 448, 146),
#  ('Vasilescu, Arina Gabriela', 449, 145),
#  ('Javia, Dev', 449, 125),
#  ('Kazionova, Ekaterina', 450, 145),
#  ('Nikles, Johan', 450, 124),
#  ('Naklo, Thasaporn', 451, 144),
#  ('Hazawa, Shinji', 451, 124),
#  ('Thamchaiwat, Bunyawi', 452, 144),
#  ('Suresh, Dhakshineswar', 452, 123),
#  ('Krueger, Mitchell', 453, 123),
#  ('Hinojosa Gomez, Jessica', 453, 144),
#  ('Ichikawa, Taisei', 454, 123),
#  ('Chiesa, Enola', 454, 144),
#  ('Vance, Jamie', 455, 123),
#  ('Bartone, Kamilla', 455, 144),
#  ('Eala, Alexandra', 456, 143),
#  ('Gea, Arthur', 456, 122),
#  ('Gamiz, Andrea', 457, 143),
#  ('Pavlovic, Luka', 457, 122),
#  ('Rodriguez Rodriguez, Johan Alexander', 458, 122),
#  ('Malygina, Elena', 458, 143),
#  ('Sinha, Nitin Kumar', 459, 122),
#  ('Sramkova, Rebecca', 459, 142),
#  ('Fedorova, Aglaya', 460, 142),
#  ('Bueno Gil, Alvaro', 460, 122),
#  ('Weckerle, Marie', 461, 142),
#  ('Barrios Vera, Marcelo Tomas', 461, 121),
#  ('Vale, Duarte', 462, 121),
#  ('Sandberg, Vivien', 462, 142),
#  ('Bassols Ribera, Marina', 463, 141),
#  ('Kikuchi, Yuta', 463, 121),
#  ('Ricci, Beatrice', 464, 141),
#  ('Schell, Niklas', 464, 121),
#  ('Pawlikowska,  Zuzanna', 465, 141),
#  ('Erel, Yanki', 465, 120),
#  ('Collins, Danielle', 466, 140),
#  ('Bobrov, Bogdan', 466, 120),
#  ('Boulais, Justin', 467, 119),
#  ('Arakawa, Haruna', 467, 140),
#  ('Boehner, Laura', 468, 140),
#  ('Neuchrist, Maximilian', 468, 119),
#  ('McPhee, Kaylah', 469, 139),
#  ('Colson, Tibo', 469, 118),
#  ('Firman, Anastasiia', 470, 139),
#  ('Hellum Lilleengen, Lukas', 470, 118),
#  ('Matoula, Martha', 471, 139),
#  ('Popko, Dmitry', 471, 118),
#  ('Marques, Diogo', 472, 118),
#  ('Vismane, Daniela', 472, 138),
#  ('Giovannini, Luisina', 473, 137),
#  ('Escoffier, Antoine', 473, 117),
#  ('Milovanovic, Elena', 474, 137),
#  ('Wenger, Damien', 474, 117),
#  ('Singh, Karan (IND)', 475, 116),
#  ('Bossi, Camilla', 475, 137),
#  ('Stakusic, Marina', 476, 136),
#  ('Lobanov, Aleksandr', 476, 116),
#  ('Bernet, Henry', 477, 115),
#  ('Shubladze, Alexandra', 477, 136),
#  ('Zhou, Yi', 478, 115),
#  ('Okutoyi, Angella', 478, 136),
#  ('Barrera Aguirre, Isabella', 479, 135),
#  ('Istomin, Denis', 479, 115),
#  ('Herazo Gonzalez, Maria Fernanda', 480, 134),
#  ('Story, James', 480, 115),
#  ('Kawachi, Kazuma', 481, 114),
#  ('Sawangkaew, Mananchaya', 481, 134),
#  ('Zheng, Zhan', 482, 114),
#  ('Crawley, Fiona', 482, 134),
#  ('Freund, Simon', 483, 113),
#  ('Stankovic, Anja', 483, 134),
#  ('Oz, Ipek', 484, 132),
#  ('Flores, Jesse', 484, 113),
#  ('Moreno, Daniel', 485, 113),
#  ('Tran, Demi', 485, 132),
#  ('Monzon, Ignacio', 486, 112),
#  ('Martic, Petra', 486, 131),
#  ('Thayne, Wally', 487, 112),
#  ('Iliev, Sarah', 487, 131),
#  ('Shalimova, Ekaterina', 488, 131),
#  ('Falabella, Lautaro Agustin', 488, 112),
#  ('van Den Broek, Isis Louise', 489, 131),
#  ('Yang, Zijiang', 489, 112),
#  ('Lee, Eunhye (2000)', 490, 131),
#  ('Perez, Brandon', 490, 112),
#  ('Mayot, Harold', 491, 111),
#  ('Rocchetti, Sofia', 491, 131),
#  ('Rodriguez, Lorenzo Joaquin', 492, 111),
#  ('de Stefano, Samira', 492, 131),
#  ('Volynets, Katie', 493, 130),
#  ('Okonkwo, Oliver', 493, 111),
#  ('Djokovic, Novak', 494, 110),
#  ('Knutson, Gabriela', 494, 130),
#  ('Duckworth, James', 495, 110),
#  ('Zaytseva, Ksenia', 495, 129),
#  ('Kuramochi, Miho', 496, 129),
#  ('Del Pino, Mateo', 496, 110),
#  ('Farjat, Tomas', 497, 110),
#  ('Desai, Zeel', 497, 129),
#  ('Prozorova, Tatiana', 498, 128),
#  ('Ambrogi, Luciano Emanuel', 498, 108),
#  ('Kirkin, Ergi', 499, 108),
#  ('Walker, Brandy', 499, 128),
#  ('Guillen Meza, Alvaro', 500, 108),
#  ('Lene, Emma', 500, 126)]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#                competitor_name  competitor_rank  competitor_rank_points
# 0                  Pavic, Mate                1                    9950
# 1          Siniakova, Katerina                1                   10665
# 2    Arevalo-Gonzalez, Marcelo                1                    9950
# 3             Townsend, Taylor                2                    8620
# 4              Routliffe, Erin                3                    8125
# ..                         ...              ...                     ...
# 995   Ambrogi, Luciano Emanuel              498                     108
# 996               Kirkin, Ergi              499                     108
# 997             Walker, Brandy              499                     128
# 998       Guillen Meza, Alvaro              500                     108
# 999                 Lene, Emma              500                     126
#
# [1000 rows x 3 columns]

# %% [markdown]
# 2)	Find competitors ranked in the top 5

# %%
sql_query = """Select comp.competitor_name,comp_rank.competitor_rank,comp_rank.competitor_rank_points 
from competitors_table comp inner join competitor_rankings_table comp_rank
on comp_rank.competitor_id = comp.competitor_id
where competitor_rank <=5 order by competitor_rank asc"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('Pavic, Mate', 1, 9950),
#  ('Arevalo-Gonzalez, Marcelo', 1, 9950),
#  ('Siniakova, Katerina', 1, 10665),
#  ('Townsend, Taylor', 2, 8620),
#  ('Routliffe, Erin', 3, 8125),
#  ('Heliovaara, Harri', 3, 7590),
#  ('Patten, Henry', 4, 7590),
#  ('Ostapenko, Jelena', 4, 6950),
#  ('Krawietz, Kevin', 5, 6180),
#  ('Dabrowski, Gabriela', 5, 6385)]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#              competitor_name  competitor_rank  competitor_rank_points
# 0                Pavic, Mate                1                    9950
# 1  Arevalo-Gonzalez, Marcelo                1                    9950
# 2        Siniakova, Katerina                1                   10665
# 3           Townsend, Taylor                2                    8620
# 4            Routliffe, Erin                3                    8125
# 5          Heliovaara, Harri                3                    7590
# 6              Patten, Henry                4                    7590
# 7          Ostapenko, Jelena                4                    6950
# 8            Krawietz, Kevin                5                    6180
# 9        Dabrowski, Gabriela                5                    6385

# %% [markdown]
# 3)	List competitors with no rank movement (stable rank)

# %%
sql_query = """Select comp.competitor_name,
comp_rank.competitor_rank,comp_rank.competitor_rank_points,comp_rank.competitor_rank_movement
from competitors_table comp inner join competitor_rankings_table comp_rank
on comp_rank.competitor_id = comp.competitor_id where competitor_rank_movement = 0"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('Pavic, Mate', 1, 9950, 0),
#  ('Arevalo-Gonzalez, Marcelo', 1, 9950, 0),
#  ('Heliovaara, Harri', 3, 7590, 0),
#  ('Patten, Henry', 4, 7590, 0),
#  ('Purcell, Max', 12, 4710, 0),
#  ('Mektic, Nikola', 13, 4700, 0),
#  ('Glasspool, Lloyd', 14, 4460, 0),
#  ('Cash, Julian', 15, 4325, 0),
#  ('Venus, Michael', 16, 4000, 0),
#  ('Skupski, Neal', 17, 3820, 0),
#  ('Dodig, Ivan', 55, 1635, 0),
#  ('Miedler, Lucas', 56, 1635, 0),
#  ('Schnaitter, Jakob', 59, 1570, 0),
#  ('Wallner, Mark', 59, 1570, 0),
#  ('Jacq, Gregoire', 63, 1435, 0),
#  ('Reyes-Varela, Miguel', 71, 1320, 0),
#  ('Krajicek, Austin', 73, 1260, 0),
#  ('Bollipalli, Rithvik Choudary', 76, 1185, 0),
#  ('Matuszewski, Piotr', 77, 1168, 0),
#  ('McDonald, Mackenzie', 81, 1120, 0),
#  ('Michelsen, Alex', 82, 1095, 0),
#  ('Trhac, Patrik', 94, 872, 0),
#  ('Harper, Cleeve', 97, 843, 0),
#  ('Zormann, Marcelo', 103, 808, 0),
#  ('Soto, Matias', 106, 793, 0),
#  ('Blancaneaux, Geoffrey', 123, 674, 0),
#  ('Merino, Alexander', 146, 551, 0),
#  ('Negritu, Christoph', 147, 551, 0),
#  ('Duda, Filip', 212, 352, 0),
#  ('Sun, Fajing', 214, 347, 0),
#  ('Aguilar, Juan Carlos', 239, 294, 0),
#  ('Sigouin, Benjamin', 240, 294, 0),
#  ('Sinclair, Colin', 279, 249, 0),
#  ('Daniell, Marcus', 284, 241, 0),
#  ('Moreno de Alboran, Nicolas', 311, 211, 0),
#  ('Berrettini, Matteo', 339, 180, 0),
#  ('Sinner, Jannik', 342, 180, 0),
#  ('Struff, Jan-Lennard', 343, 180, 0),
#  ('Vavassori, Matteo', 379, 156, 0),
#  ('Sakellaridis, Dimitris', 400, 146, 0),
#  ('Schwaerzler, Joel', 429, 131, 0),
#  ('Del Pino, Mateo', 496, 110, 0),
#  ('Siniakova, Katerina', 1, 10665, 0),
#  ('Townsend, Taylor', 2, 8620, 0),
#  ('Routliffe, Erin', 3, 8125, 0),
#  ('Ostapenko, Jelena', 4, 6950, 0),
#  ('Dabrowski, Gabriela', 5, 6385, 0),
#  ('Errani, Sara', 6, 5465, 0),
#  ('Paolini, Jasmine', 6, 5465, 0),
#  ('Muhammad, Asia', 8, 4690, 0),
#  ('Kichenok, Lyudmyla', 9, 4630, 0),
#  ('Zhang, Shuai', 10, 4523, 0),
#  ('Hsieh, Su-Wei', 11, 4521, 0),
#  ('Shnaider, Diana', 13, 4356, 0),
#  ('Khromacheva, Irina', 15, 3968, 0),
#  ('Chan, Hao-Ching', 16, 3945, 0),
#  ('Danilina, Anna', 17, 3913, 0),
#  ('Andreeva, Mirra', 18, 3869, 0),
#  ('Schuurs, Demi', 24, 3241, 0),
#  ('Wu, Fang-Hsien', 30, 2756, 0),
#  ('Mihalikova, Tereza', 34, 2611, 0),
#  ('Sizikova, Yana', 59, 1595, 0),
#  ('Pegula, Jessica', 61, 1556, 0),
#  ('Yuan, Yue', 63, 1386, 0),
#  ('Siskova, Anna', 66, 1290, 0),
#  ('Moratelli, Angelica', 68, 1270, 0),
#  ('Yang, Zhaoxuan', 73, 1150, 0),
#  ('Zantedeschi, Aurora', 106, 734, 0),
#  ('Vedder, Eva', 110, 719, 0),
#  ('Wang, Xiyu', 119, 640, 0),
#  ('Tikhonova, Anastasia', 121, 636, 0),
#  ('Chang, Sophie', 131, 599, 0),
#  ('Romero Gormaz, Leyre', 132, 592, 0),
#  ('Kawa, Katarzyna', 138, 577, 0),
#  ('Navarro, Emma', 141, 560, 0),
#  ('Failla, Jessica', 145, 550, 0),
#  ('Cocciaretto, Elisabetta', 147, 542, 0),
#  ('Fourlis, Jaimee', 148, 539, 0),
#  ('Bara, Irina Maria', 149, 538, 0),
#  ('Smith, Alana', 154, 521, 0),
#  ('Kessler, McCartney', 173, 454, 0),
#  ('Cho, I-Hsuan', 185, 429, 0),
#  ('Cho, Yi Tsen', 185, 429, 0),
#  ('Waltert, Simona', 195, 411, 0),
#  ('Sato, Naho', 211, 387, 0),
#  ('Rosolska, Alicja', 218, 373, 0),
#  ('Kolb, Maryna', 224, 358, 0),
#  ('Riera, Julia', 245, 321, 0),
#  ('Fita Boluda, Angela', 246, 321, 0),
#  ('Hosogi, Sakura', 293, 272, 0),
#  ('Xu, Mingge', 295, 269, 0),
#  ('Sebestova, Ivana', 296, 269, 0),
#  ('Aksu, Ayla', 345, 218, 0),
#  ('Chaudhari, Vaidehi', 351, 215, 0),
#  ('In-Albon, Ylena', 352, 214, 0),
#  ('Prisacariu, Andreea', 369, 196, 0),
#  ('Perez Alarcon, Lucciana', 377, 186, 0),
#  ('Pace, Francesca', 438, 151, 0)]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#               competitor_name  competitor_rank  competitor_rank_points  \
# 0                 Pavic, Mate                1                    9950
# 1   Arevalo-Gonzalez, Marcelo                1                    9950
# 2           Heliovaara, Harri                3                    7590
# 3               Patten, Henry                4                    7590
# 4                Purcell, Max               12                    4710
# ..                        ...              ...                     ...
# 93         Chaudhari, Vaidehi              351                     215
# 94            In-Albon, Ylena              352                     214
# 95        Prisacariu, Andreea              369                     196
# 96    Perez Alarcon, Lucciana              377                     186
# 97            Pace, Francesca              438                     151
#
#     competitor_rank_movement
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ..                       ...
# 93                         0
# 94                         0
# 95                         0
# 96                         0
# 97                         0
#
# [98 rows x 4 columns]

# %% [markdown]
# 4)	Get the total points of competitors from a specific country (e.g., Croatia)

# %%
sql_query = """Select sum (comp_rank.competitor_rank_points) as croatia_country_total_points,
String_agg(comp.competitor_name, ',') as competitiors
from competitors_table comp inner join competitor_rankings_table comp_rank
on comp_rank.competitor_id = comp.competitor_id where comp.competitor_country = 'Croatia'"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [(17452,
#   'Pavic, Mate,Mektic, Nikola,Dodig, Ivan,Poljicak, Mili,Wuerth, Tara,Drazic, Mariana,Marcinko, Petra,Martic, Petra')]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#    croatia_country_total_points  \
# 0                         17452
#
#                                         competitiors
# 0  Pavic, Mate,Mektic, Nikola,Dodig, Ivan,Poljica...

# %% [markdown]
# 5)	Count the number of competitors per country

# %%
sql_query = """Select count(*) as no_of_competitiors,competitor_country from competitors_table 
group by competitor_country 
order by competitor_country asc"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [(1, 'Algeria'),
#  (1, 'Antigua and Barbuda'),
#  (32, 'Argentina'),
#  (1, 'Armenia'),
#  (47, 'Australia'),
#  (13, 'Austria'),
#  (1, 'Belarus'),
#  (11, 'Belgium'),
#  (5, 'Bolivia'),
#  (2, 'Bosnia & Herzegovina'),
#  (23, 'Brazil'),
#  (7, 'Bulgaria'),
#  (1, 'Burundi'),
#  (15, 'Canada'),
#  (5, 'Chile'),
#  (31, 'China'),
#  (13, 'Chinese Taipei'),
#  (9, 'Colombia'),
#  (1, 'Costa Rica'),
#  (8, 'Croatia'),
#  (1, 'Cyprus'),
#  (38, 'Czechia'),
#  (3, 'Denmark'),
#  (5, 'Ecuador'),
#  (1, 'Egypt'),
#  (1, 'El Salvador'),
#  (3, 'Estonia'),
#  (5, 'Finland'),
#  (54, 'France'),
#  (5, 'Georgia'),
#  (31, 'Germany'),
#  (51, 'Great Britain'),
#  (9, 'Greece'),
#  (2, 'Hong Kong, China'),
#  (5, 'Hungary'),
#  (30, 'India'),
#  (2, 'Indonesia'),
#  (1, 'Ireland'),
#  (3, 'Israel'),
#  (40, 'Italy'),
#  (1, 'Jamaica'),
#  (58, 'Japan'),
#  (1, 'Jordan'),
#  (9, 'Kazakhstan'),
#  (1, 'Kenya'),
#  (5, 'Latvia'),
#  (2, 'Lebanon'),
#  (1, 'Lithuania'),
#  (1, 'Luxembourg'),
#  (11, 'Mexico'),
#  (2, 'Monaco'),
#  (1, 'Morocco'),
#  (29, 'Netherlands'),
#  (61, 'Neutral'),
#  (9, 'New Zealand'),
#  (1, 'Northern Mariana Islands'),
#  (3, 'Norway'),
#  (1, 'Paraguay'),
#  (5, 'Peru'),
#  (2, 'Philippines'),
#  (15, 'Poland'),
#  (10, 'Portugal'),
#  (10, 'Republic of Korea'),
#  (17, 'Romania'),
#  (1, 'Russia'),
#  (10, 'Serbia'),
#  (12, 'Slovakia'),
#  (6, 'Slovenia'),
#  (2, 'South Africa'),
#  (27, 'Spain'),
#  (6, 'Sweden'),
#  (20, 'Switzerland'),
#  (6, 'Thailand'),
#  (3, 'Tunisia'),
#  (6, 'Turkiye'),
#  (15, 'Ukraine'),
#  (3, 'Uruguay'),
#  (103, 'USA'),
#  (1, 'Uzbekistan'),
#  (4, 'Venezuela'),
#  (2, 'Zimbabwe')]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#     no_of_competitiors   competitor_country
# 0                    1              Algeria
# 1                    1  Antigua and Barbuda
# 2                   32            Argentina
# 3                    1              Armenia
# 4                   47            Australia
# ..                 ...                  ...
# 76                   3              Uruguay
# 77                 103                  USA
# 78                   1           Uzbekistan
# 79                   4            Venezuela
# 80                   2             Zimbabwe
#
# [81 rows x 2 columns]

# %% [markdown]
# 6)	Find competitors with the highest points in the current week

# %%
sql_query = """SELECT comp.competitor_name,comp_rank.competitor_rank_points FROM competitors_table comp JOIN 
    competitor_rankings_table comp_rank
    ON comp.competitor_id = comp_rank.competitor_id 
	where  comp_rank.competitor_rank_points = (SELECT MAX(competitor_rank_points)
        FROM competitor_rankings_table)"""

#execute:
mycursor.execute(sql_query)
fetching_data = mycursor.fetchall()
fetching_data
# Out:
# [('Siniakova, Katerina', 10665)]

# %%
#To fetch column names:
a = mycursor.description

# Create an empty list to store column names
column_names = []

# Loop through each tuple and extract the first item
for col in a:
    column_names.append(col[0])
    
# Create DataFrame
df = pd.DataFrame(fetching_data, columns=column_names)

# Display the DataFrame
print(df)
# Out:
#        competitor_name  competitor_rank_points
# 0  Siniakova, Katerina                   10665

# %%
mycursor.close()
my_db_connection.close()
